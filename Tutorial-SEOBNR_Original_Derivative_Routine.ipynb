# %% [markdown]
# # Symbolic Partial Derivative Routine
#
# ## Authors: Zach Etienne & Tyler Knowles
#
# ## This module contains a routine for computing partial derivatives of a mathematical expression that is written as several subexpressions.
#
# **Notebook Status:** <font color='green'><b> Validated </b></font>
#
# **Validation Notes:** This tutorial notebook has been confirmed to be self-consistent with its corresponding NRPy+ module, as documented [below](#code_validation). Additionally, this notebook has been validated by checking that results are consistent with exact derivative expressions used in the SEOBNRv3_opt approixment of [LALSuite](https://git.ligo.org/lscsoft/lalsuite).
#
# ### NRPy+ Source Code for this module: [SEOBNR_Derivative_Routine.py](../edit/SEOBNR/SEOBNR_Derivative_Routine.py)
#
# ## Introduction
# $$\label{intro}$$
#
# This notebook documents the symbolic partial derivative routine used to generate analytic derivatives of the [SEOBNRv3](https://git.ligo.org/lscsoft/lalsuite) Hamiltonian (documented [here](../Tutorial-SEOBNR_v3_Hamiltonian.ipynb)) and described in [this article](https://arxiv.org/abs/1803.06346).  In general, this notebook takes as input a file of inter-dependent mathematical expressions (in SymPy syntax), a file listing the names of values within those expressions, and a file listing all variables with which to take partial derivatives of each expression.  The output is a text file containing the original expression and those for each partial derivative computation.  The intention is to perform CSE on these expressions to create efficient partial derivative code!

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# This notebook is organized as follows
#
# 1. [Step 1](#initializenrpy): Initialize core Python/NRPy+ modules
# 1. [Step 2:](#read_expressions) Read in Hamiltonian expressions from `Hamstring.txt`
# 1. [Step 3:](#list_constants) Specify constants and variables in Hamiltonian expression
# 1. [Step 4:](#list_free_symbols) Extract free symbols
# 1. [Step 5:](#convert_to_func) Convert variables to function notation; e.g., `var` goes to `var(xx)`
# 1. [Step 6:](#differentiate) Differentiate with respect to `xx`
# 1. [Step 7:](#remove_zeros) Remove derivatives (of constants) that evaluate to zero, simplifying derivative expressions
# 1. [Step 8:](#partial_derivative) Simplify derivatives with respect to a specific variable
# 1. [Step 9:](#store_results) Store partial derivatives to SymPy notebook `partial_derivatives.txt-VALIDATION.txt`
# 1. [Step 10:](#code_validation) Validate against LALSuite and trusted `SEOBNR_Derivative_Routine` NRPy+ module
# 1. [Step 11:](#latex_pdf_output) Output this notebook to $\LaTeX$-formatted PDF file

# %% [markdown]
# <a id='initializenrpy'></a>
#
# # Step 1: Initialize core Python/NRPy+ modules \[Back to [top](#toc)\]
# $$\label{initializenrpy}$$
#
# Let's start by importing all the needed modules from Python/NRPy+ and creating the output directory (if it does not already exist):

# %%
# Step 1.a: import all needed modules from Python/NRPy+:
import sympy as sp
from sympy.codegen.cfunctions import log1p # SymPy: The Python computer algebra package upon which NRPy+ depends
import sys, os     # Standard Python modules for multiplatform OS-level functions
sys.path.append('../')

from outputC import superfast_uniq, lhrh      # Remove duplicate entries from a Python array; store left- and right-
                                              #   hand sides of mathematical expressions

# As of April 2021, "sp.sympify("Q+1")" fails because Q is a reserved keyword.
#   This is the workaround, courtesy Ken Sible.
custom_global_dict = {}
exec('from sympy import *', custom_global_dict)
del custom_global_dict['Q']

# Step 1.b: Check for a sufficiently new version of SymPy (for validation)
# Ignore the rc's and b's for release candidates & betas.
sympy_version = sp.__version__.replace('rc', '...').replace('b', '...')
sympy_version_decimal = float(int(sympy_version.split(".")[0]) + int(sympy_version.split(".")[1])/10.0)
if sympy_version_decimal > 1.2:
    custom_parse_expr = lambda expr: sp.parse_expr(expr, global_dict=custom_global_dict)
else:
    custom_parse_expr = lambda expr: sp.sympify(expr)

if sympy_version_decimal < 1.2:
    print('Error: NRPy+ does not support SymPy < 1.2')
    sys.exit(1)

# Step 1.c: Name of the directory containing the input file
inputdir = "Hamiltonian"

# %% [markdown]
# <a id='read_expressions'></a>
#
# # Step 2: Read in Hamiltonian expressions from `Hamstring.txt` \[Back to [top](#toc)\]
# $$\label{read_expressions}$$
#
# We read in the expressions of which we will compute partial derivatives in a single large string before splitting the string by line (carriage return) and by "=".  Doing so allows us to manipulate the right- and left-hand sides of the expressions appropriately.  We store the left- and right-hand sides in the array `lr`, which consists of `lhrh` arrays with left-hand sides `lhs` and right-hand sides `rhs`.  Note that `Lambda` is a protected keyword in Python, so the variable $\Lambda$ in the Hamiltonian is renamed `Lamb`.

# %%
# Step 2.a: Read in expressions as a (single) string
with open(os.path.join(inputdir,'Sympy_Hreal_on_Bottom.txt'), 'r') as file:
    expressions_as_lines = file.readlines()

#print(expressions_as_lines)
# Step 2.b: Create and populate the "lr" array, which separates each line into left- and right-hand sides
#   Each entry is a string of the form lhrh(lhs='',rhs='')
lr = []

for i in range(len(expressions_as_lines)):
    # Ignore lines with 2 or fewer characters and those starting with #
    if len(expressions_as_lines[i]) > 2 and expressions_as_lines[i][0] != "#":
        # Split each line by its equals sign
        split_line = expressions_as_lines[i].split("=")
        #print(split_line)
        # Append the line to "lr", removing spaces, "sp." prefixes, and replacing Lambda->Lamb
        #   (Lambda is a protected keyword):
        lr.append(lhrh(lhs=split_line[0].replace(" ","").replace("Lambda","Lamb"),
                       rhs=split_line[1].replace(" ","").replace("sp.","").replace("Lambda","Lamb")))

# Step 2.c: Separate and sympify right- and left-hand sides into separate arrays
lhss = []
rhss = []
for i in range(len(lr)):
    #print(lr[i].rhs)
    lhss.append(custom_parse_expr(lr[i].lhs))
    rhss.append(custom_parse_expr(lr[i].rhs))

print(lhss)
print(rhss)
# Out:
# [EMgamma, M, mu, eta, r, u, sigmastar3, sigmastar2, sigmastar1, sigma3, sigma2, sigma1, Skerr3, Skerr2, Skerr1, Skerrmag, Skerrhat3, Skerrhat2, Skerrhat1, a, L3, L2, L1, Lnorm, Lhat3, Lhat2, Lhat1, S2dotLhat, S1dotLhat, S1perp3, S1perp2, S1perp1, S2perp3, S2perp2, S2perp1, Sperp3, Sperp2, Sperp1, n3, n2, n1, e33, e32, e31, xi3, xi2, xi1, v3, v2, v1, costheta, sin2theta, xisq, w2, Sigma, Dinv, omegatilde, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, Delta4, Delta5, Delta5l, logarg, Deltaucalib, Deltaucalibprime, Deltaubar, Deltaubarprime, Deltau, Deltauprime, Deltatprime, Deltat, Deltar, Lambt, csi, csi1, csi2, prT, phat3, phat2, phat1, pdotxir, pdotn, pdotvr, pphi, Qcoeff2, Qcoeff1, DrSipn2, Q, Qminus1, Jtilde, exp2mu, expmu, Brtilde, Btilde, exp2nu, expnu, omega, omegatildeprime, Lambtprime, mucostheta, nucostheta, omegacostheta, mur, nur, omegar, dSO, sigmacoeffTerm3, sigmacoeffTerm2, sigmacoeffTerm1, sigmacoeff, sigmastarcoeffTerm2, sigmastarcoeffTerm1, sigmastarcoeff, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S3, S2, S1, Sstardotn, SdotSkerrhat, Sdotn, Sdotv, Sdotxi, HdsumTerm2, HdsumTerm1, Hdsum, Hdcoeff, Q4, gammappsum, Hnsradicand, alpha, betapsum, HssTerm3, HssTerm3coeff, HssTerm2, HssTerm2coeff, HssTerm1, Hss, HsoTerm2c, HsoTerm2b, HsoTerm2a, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hso, Hd, Hns, Hs, dSS, Heff, Hreal]
# [0.577215664901532860606512090082402431, m1 + m2, m1*m2/M, mu/M, sqrt(x**2 + y**2 + z**2), 1/r, S1z*m2/m1 + S2z*m1/m2, S1y*m2/m1 + S2y*m1/m2, S1x*m2/m1 + S2x*m1/m2, S1z + S2z, S1y + S2y, S1x + S2x, sigma3, sigma2, sigma1, sqrt(Skerr1**2 + Skerr2**2 + Skerr3**2), Skerr3/Skerrmag, Skerr2/Skerrmag, Skerr1/Skerrmag, Skerrmag, -p1*y + p2*x, p1*z - p3*x, -p2*z + p3*y, sqrt(L1**2 + L2**2 + L3**2), L3/Lnorm, L2/Lnorm, L1/Lnorm, Lhat1*S2x + Lhat2*S2y + Lhat3*S2z, Lhat1*S1x + Lhat2*S1y + Lhat3*S1z, -Lhat3*S1dotLhat + S1z, -Lhat2*S1dotLhat + S1y, -Lhat1*S1dotLhat + S1x, -Lhat3*S2dotLhat + S2z, -Lhat2*S2dotLhat + S2y, -Lhat1*S2dotLhat + S2x, S1perp3 + S2perp3, S1perp2 + S2perp2, S1perp1 + S2perp1, z/r, y/r, x/r, Skerrhat3, Skerrhat2, Skerrhat1, e31*n2 - e32*n1, -e31*n3 + e33*n1, e32*n3 - e33*n2, n1*xi2 - n2*xi1, -n1*xi3 + n3*xi1, n2*xi3 - n3*xi2, e31*n1 + e32*n2 + e33*n3, 1 - costheta**2, sin2theta, a**2 + r**2, a**2*costheta**2 + r**2, log(eta*u**3*(52 - 6*eta) + 6*eta*u**2 + 1) + 1, 2*a*r, (Lhat1*Skerr1 + Lhat2*Skerr2 + Lhat3*Skerr3)/(1 - 2*eta) + (Skerr1*Sperp1/2 + Skerr2*Sperp2/2 + Skerr3*Sperp3/2)/(Skerrmag*(1.0 - 2.0*eta)), 267.788*eta**3 - 126.687*eta**2 + 10.2573*eta + 1.7336, Kchi0 - 59.1658*chi**3*eta**3 - 0.426958*chi**3*eta + 1.43659*chi**3 + 31.1746*chi**2*eta**3 + 6.16466*chi**2*eta**2 - 1.38086*chi**2 - 27.5201*chi*eta**3 + 17.3736*chi*eta**2 + 2.26831*chi*eta - 1.62045*chi, K*eta - 1, K*(K*eta - 2), -2*etaKminus1*(Delta0 + K), -Delta0*a**2*etaKminus1**2 + Delta1*(Delta1 - 4*etaKminus1)/2, -Delta1**3/3 + Delta1**2*etaKminus1 + Delta1*Delta2 - Delta1*a**2*etaKminus1**2 - 2*etaKminus1*(Delta2 - etaKminus1), Delta1**4/4 - 2*Delta1**3*etaKminus1/3 - Delta1**2*Delta2 + Delta1*(24*Delta2*etaKminus1 + 12*Delta3)/12 + Delta2**2/2 - 2*Delta3*etaKminus1 + a**2*etaKminus1**2*(Delta1**2 - 2*Delta2)/2 + etaKminus1**2*(376 - 123*pi**2/8)/12, etaKminus1**2*(128*EMgamma/5 - a**2*(Delta1**3 - 3*Delta1*Delta2 + 3*Delta3)/3 + eta*(-221/6 + 41*pi**2/32) - 4237/60 + 256*log(2)/5 + 2275*pi**2/512 + (Delta1**4 - 4*Delta1**2*Delta2 + 4*Delta1*Delta3 + 2*Delta2**2 - 4*Delta4)/(2*etaKminus1) - (Delta1**5 - 5*Delta1**3*Delta2 + 5*Delta1**2*Delta3 + 5*Delta1*Delta2**2 - 5*Delta1*Delta4 - 5*Delta2*Delta3)/(5*etaKminus1**2)), 64*etaKminus1**2/5, u*(Delta1 + u*(Delta2 + u*(Delta3 + u*(Delta4 + u*(Delta5 + Delta5l*log(u)))))), eta*(Delta0 + log(logarg + 1)) + 1, -eta*u**2*(Delta1 + u*(2*Delta2 + u*(3*Delta3 + u*(4*Delta4 + u*(5*Delta5 + 5*Delta5l*log(u))))))/(logarg + 1), a**2*u**2 + (2*u + 1/etaKminus1)/etaKminus1, -2*a**2*u**3 - 2*u**2/etaKminus1, Deltaubar*Deltaucalib, Deltaubar*Deltaucalibprime + Deltaubarprime*Deltaucalib, 2*Deltau*r + Deltauprime*r**2, Deltau*r**2, Deltat*Dinv, -Deltat*a**2*sin2theta + w2**2, sqrt(Deltar*Deltat)/w2, (1 - Abs(tortoise - 1))*(csi - 1) + 1, (1/2 - sign(3/2 - tortoise)/2)*(csi - 1) + 1, csi2*(n1*p1 + n2*p2 + n3*p3), -n3*prT*(1 - 1/csi1) + p3, -n2*prT*(1 - 1/csi1) + p2, -n1*prT*(1 - 1/csi1) + p1, r*(phat1*xi1 + phat2*xi2 + phat3*xi3), n1*phat1 + n2*phat2 + n3*phat3, r*(phat1*v1 + phat2*v2 + phat3*v3), pdotxir, 1/(Sigma*sin2theta), Sigma/(Lambt*sin2theta), Deltar*pdotn**2/Sigma, DrSipn2 + Qcoeff1*pdotxir**2 + Qcoeff2*pdotvr**2 + 1, Q - 1, sqrt(Deltar), Sigma, sqrt(exp2mu), (sqrt(Deltar)*Deltatprime - 2*Deltat)/(2*sqrt(Deltar*Deltat)), sqrt(Deltat), Deltat*Sigma/Lambt, sqrt(exp2nu), omegatilde/Lambt, 2*a, -2*Deltatprime*a**2*sin2theta + r*(4*a**2 + 4*r**2), a**2*costheta/Sigma, a**2*costheta*w2*(-Deltat + w2)/(Lambt*Sigma), -2*Deltat*a**2*costheta*omegatilde/Lambt**2, r/Sigma - 1/sqrt(Deltar), r/Sigma + w2*(-4*Deltat*r + Deltatprime*w2)/(2*Deltat*Lambt), (Lambt*omegatildeprime - Lambtprime*omegatilde)/Lambt**2, 147.481*chi**3*eta**2 - 568.651*chi**3*eta + 66.1987*chi**3 - 343.313*chi**2*eta + 2495.29*chi*eta**2 - 44.5324, dSO*eta*u**3, eta*(eta*(r*(-882*DrSipn2 + 204*Qminus1 + r*(810*DrSipn2**2 - 234*DrSipn2*Qminus1)) - 336) + r*(-96*DrSipn2 - 436*Qminus1 + r*(36*DrSipn2*Qminus1 - 45*Qminus1**2)) - 896)/(144*r**2), eta*(-3 ...

# %% [markdown]
# <a id='list_constants'></a>
#
# # Step 3: Specify constants and variables in Hamiltonian expression \[Back to [top](#toc)\]
# $$\label{list_constants}$$
#
# We read in and declare as SymPy symbols the constant values; derivatives with respect to these variables will be set to zero.  We then read in the variables with respect to which we want to take derivatives and declare those as SymPy variables as well.

# %%
# Step 3.a: Create `input_constants` array and populate with SymPy symbols
m1,m2,tortoise,eta,KK,k0,k1,EMgamma,d1v2,dheffSSv2 = sp.symbols('m1 m2 tortoise eta KK k0 k1 EMgamma d1v2 dheffSSv2',
                                                                real=True)
input_constants = [m1,m2,tortoise,eta,KK,k0,k1,EMgamma,d1v2,dheffSSv2]

# Step 3.b: Create `dynamic_variables` array and populate with SymPy symbols
x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols('x y z p1 p2 p3 S1x S1y S1z S2x S2y S2z', real=True)
dynamic_variables = [x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z]

# %% [markdown]
# <a id='list_free_symbols'></a>
#
# # Step 4: Extract free symbols \[Back to [top](#toc)\]
# $$\label{list_free_symbols}$$
#
# By ''free symbols'' we mean the variables in the right-hand sides.  We first create a list of all such terms (using SymPy's built-in free_symbol attribute), including duplicates, and then strip the duplicates.  We then remove input constants from the symbol list.

# %%
# Step 4.a: Prepare array of "free symbols" in the right-hand side expressions
full_symbol_list_with_dups = []
for i in range(len(lr)):
    for variable in rhss[i].free_symbols:
        full_symbol_list_with_dups.append(variable)

print(full_symbol_list_with_dups)
# Step 4.b: Remove duplicate free symbols
full_symbol_list = superfast_uniq(full_symbol_list_with_dups)
print(full_symbol_list)
# Step 4.c: Remove input constants from symbol list
for inputconst in input_constants:
    for symbol in full_symbol_list:
        if str(symbol) == str(inputconst):
            full_symbol_list.remove(symbol)
print(full_symbol_list)
# Out:
# [m2, m1, m2, m1, M, mu, M, y, z, x, r, S2z, m2, m1, S1z, S1y, m2, m1, S2y, S1x, S2x, m2, m1, S2z, S1z, S1y, S2y, S2x, S1x, sigma3, sigma2, sigma1, Skerr3, Skerr1, Skerr2, Skerr3, Skerrmag, Skerrmag, Skerr2, Skerr1, Skerrmag, Skerrmag, y, p1, x, p2, x, p3, z, p1, p3, y, z, p2, L2, L3, L1, Lnorm, L3, Lnorm, L2, Lnorm, L1, S2z, S2y, Lhat1, Lhat3, S2x, Lhat2, S1x, S1y, Lhat1, S1z, Lhat3, Lhat2, Lhat3, S1dotLhat, S1z, S1dotLhat, S1y, Lhat2, Lhat1, S1x, S1dotLhat, S2z, S2dotLhat, Lhat3, Lhat2, S2dotLhat, S2y, S2x, S2dotLhat, Lhat1, S2perp3, S1perp3, S2perp2, S1perp2, S1perp1, S2perp1, z, r, y, r, x, r, Skerrhat3, Skerrhat2, Skerrhat1, n2, e31, e32, n1, e33, n3, n1, e31, n3, e33, e32, n2, n2, n1, xi1, xi2, n3, n1, xi1, xi3, n3, n2, xi2, xi3, n1, e33, n2, n3, e31, e32, costheta, sin2theta, a, r, a, r, costheta, u, eta, a, r, Sperp2, Sperp3, Lhat1, Skerr3, Skerrmag, Lhat2, Sperp1, eta, Skerr2, Lhat3, Skerr1, eta, eta, chi, Kchi0, eta, K, eta, K, etaKminus1, Delta0, K, Delta0, Delta1, etaKminus1, a, Delta1, etaKminus1, a, Delta2, Delta1, Delta3, etaKminus1, a, Delta2, Delta1, EMgamma, Delta4, Delta3, Delta2, eta, etaKminus1, a, etaKminus1, Delta1, Delta4, Delta5l, Delta3, Delta2, u, Delta5, Delta0, logarg, eta, Delta1, Delta4, Delta5l, Delta3, Delta2, logarg, eta, u, Delta5, u, etaKminus1, a, u, etaKminus1, a, Deltaubar, Deltaucalib, Deltaubar, Deltaucalib, Deltaubarprime, Deltaucalibprime, Deltauprime, Deltau, r, Deltau, r, Dinv, Deltat, w2, sin2theta, a, Deltat, w2, Deltat, Deltar, tortoise, csi, tortoise, csi, n1, n2, n3, csi2, p3, p1, p2, n3, p3, prT, csi1, prT, n2, csi1, p2, prT, n1, csi1, p1, xi1, phat2, phat1, r, xi3, xi2, phat3, phat2, n1, phat1, n3, n2, phat3, phat2, phat1, r, v1, v3, v2, phat3, pdotxir, Sigma, sin2theta, Sigma, sin2theta, Lambt, Sigma, pdotn, Deltar, Qcoeff2, pdotxir, DrSipn2, Qcoeff1, pdotvr, Q, Deltar, Sigma, exp2mu, Deltar, Deltatprime, Deltat, Deltat, Sigma, Lambt, Deltat, exp2nu, omegatilde, Lambt, a, r, sin2theta, a, Deltatprime, Sigma, a, costheta, w2, Lambt, Sigma, a, Deltat, costheta, omegatilde, Lambt, a, Deltat, costheta, Sigma, Deltar, r, w2, Lambt, r, Sigma, Deltatprime, Deltat, omegatilde, Lambt, Lambtprime, omegatildeprime, chi, eta, u, dSO, eta, eta, r, DrSipn2, Qminus1, DrSipn2, Qminus1, eta, r, sigmacoeffTerm3, sigmacoeffTerm2, sigmacoeffTerm1, eta, r, DrSipn2, Qminus1, DrSipn2, Qminus1, eta, r, sigmastarcoeffTerm2, sigmastarcoeffTerm1, sigma3, sigmacoeff, sigmastar3, sigmastarcoeff, sigma2, sigmacoeff, sigmastar2, sigmastarcoeff, sigmacoeff, sigma1, sigmastar1, sigmastarcoeff, Deltasigmastar3, sigmastar3, Deltasigmastar2, sigmastar2, sigmastar1, Deltasigmastar1, Sstar3, Sstar2, Sstar1, Sstar2, Sstar3, n1, n3, n2, Sstar1, S3, S2, Skerrhat3, Skerrhat2, Skerrhat1, S1, n1, S3, n2, n3, S2, S1, S3, v1, v3, S2, v2, S1, S3, xi3, S2, xi2, xi1, S1, Sstardotn, Sstar2, Sstar3, Sstar1, HdsumTerm1, HdsumTerm2, r, prT, u, eta, Deltar, pdotvr, pdotxir, Lambt, Sigma, sin2theta, pdotn, Q4, gammappsum, Sigma, Lambt, Deltat, Lambt, omegatilde, pphi, expmu, Sdotn, expnu, Q, pdotvr, xisq, Sdotv, exp2mu, Sdotxi, pdotxir, Jtilde, pdotn, Btilde, exp2mu, expmu, omegacostheta, expnu, Q, Btilde, exp2nu, expmu, expnu, Sdotn, Q, pdotvr, xisq, Sdotv, exp2mu, Sdotxi, pdotxir, Jtilde, pdotn, Btilde, exp2mu, expmu, expnu, Jtilde, omegar, Q, xisq, Btilde, omega, SdotSkerrhat, HssTerm2coeff, HssTerm3, HssTerm1, HssTerm3coeff, HssTerm2, Sdotv, pdotxir, expmu, expnu, Jtilde, Q, Brtilde, expmu, expnu, Sdotn, Q, nucostheta, xisq, Sdotv, nur, pdotxir, Jtilde, Btilde, mur, Q, pdotvr, nucostheta, xisq, nur, mucostheta, Sdotxi, Jtilde, pdotn, Btilde, HsoTerm2c, HsoTerm2a, HsoTerm2b, exp2mu, expnu, Q, xisq, Btilde, exp2nu, expmu, expnu, Q, xisq, pdotxir, SdotSkerrhat, Btilde, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hdsum, Hdcoeff, alpha, betapsum, Hnsradicand, Hso, Hss, chi, eta, dSS, S1x, S2x, S2y, Hs, S2z, eta, Hd, S1y, u, Hns, S1z, Heff, eta]
# [m2, m1, M, mu, y, z, x, r, S2z, S1z, S1y, S2y, S1x, S2x, sigma3, sigma2, sigma1, Skerr3, Skerr1, Skerr2, Skerrmag, p1, p2, p3, L2, L3, L1, Lnorm, Lhat1, Lhat3, Lhat2, S1dotLhat, S2dotLhat, S2perp3, S1perp3, S2perp2, S1perp2, S1perp1, S2perp1, Skerrhat3, Skerrhat2, Skerrhat1, n2, e31, e32, n1, e33, n3, xi1, xi2, xi3, costheta, sin2theta, a, u, eta, Sperp2, Sperp3, Sperp1, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, EMgamma, Delta4, Delta5l, Delta5, logarg, Deltaubar, Deltaucalib, Deltaubarprime, Deltaucalibprime, Deltauprime, Deltau, Dinv, Deltat, w2, Deltar, tortoise, csi, csi2, prT, csi1, phat2, phat1, phat3, v1, v3, v2, pdotxir, Sigma, Lambt, pdotn, Qcoeff2, DrSipn2, Qcoeff1, pdotvr, Q, exp2mu, Deltatprime, exp2nu, omegatilde, Lambtprime, omegatildeprime, dSO, Qminus1, sigmacoeffTerm3, sigmacoeffTerm2, sigmacoeffTerm1, sigmastarcoeffTerm2, sigmastarcoeffTerm1, sigmacoeff, sigmastar3, sigmastarcoeff, sigmastar2, sigmastar1, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S3, S2, S1, Sstardotn, HdsumTerm1, HdsumTerm2, Q4, gammappsum, pphi, expmu, Sdotn, expnu, xisq, Sdotv, Sdotxi, Jtilde, Btilde, omegacostheta, omegar, omega, SdotSkerrhat, HssTerm2coeff, HssTerm3, HssTerm1, HssTerm3coeff, HssTerm2, Brtilde, nucostheta, nur, mur, mucostheta, HsoTerm2c, HsoTerm2a, HsoTerm2b, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hdsum, Hdcoeff, alpha, betapsum, Hnsradicand, Hso, Hss, dSS, Hs, Hd, Hns, Heff]
# [M, mu, y, z, x, r, S2z, S1z, S1y, S2y, S1x, S2x, sigma3, sigma2, sigma1, Skerr3, Skerr1, Skerr2, Skerrmag, p1, p2, p3, L2, L3, L1, Lnorm, Lhat1, Lhat3, Lhat2, S1dotLhat, S2dotLhat, S2perp3, S1perp3, S2perp2, S1perp2, S1perp1, S2perp1, Skerrhat3, Skerrhat2, Skerrhat1, n2, e31, e32, n1, e33, n3, xi1, xi2, xi3, costheta, sin2theta, a, u, Sperp2, Sperp3, Sperp1, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, Delta4, Delta5l, Delta5, logarg, Deltaubar, Deltaucalib, Deltaubarprime, Deltaucalibprime, Deltauprime, Deltau, Dinv, Deltat, w2, Deltar, csi, csi2, prT, csi1, phat2, phat1, phat3, v1, v3, v2, pdotxir, Sigma, Lambt, pdotn, Qcoeff2, DrSipn2, Qcoeff1, pdotvr, Q, exp2mu, Deltatprime, exp2nu, omegatilde, Lambtprime, omegatildeprime, dSO, Qminus1, sigmacoeffTerm3, sigmacoeffTerm2, sigmacoeffTerm1, sigmastarcoeffTerm2, sigmastarcoeffTerm1, sigmacoeff, sigmastar3, sigmastarcoeff, sigmastar2, sigmastar1, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S3, S2, S1, Sstardotn, HdsumTerm1, HdsumTerm2, Q4, gammappsum, pphi, expmu, Sdotn, expnu, xisq, Sdotv, Sdotxi, Jtilde, Btilde, omegacostheta, omegar, omega, SdotSkerrhat, HssTerm2coeff, HssTerm3, HssTerm1, HssTerm3coeff, HssTerm2, Brtilde, nucostheta, nur, mur, mucostheta, HsoTerm2c, HsoTerm2a, HsoTerm2b, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hdsum, Hdcoeff, alpha, betapsum, Hnsradicand, Hso, Hss, dSS, Hs, Hd, Hns, Heff]

# %% [markdown]
# <a id='convert_to_func'></a>
#
# # Step 5: Convert variables to function notation; e.g., `var` goes to `var(xx)` \[Back to [top](#toc)\]
# $$\label{convert_to_func}$$
#
# In order to compute the partial derivative of each right-hand side, we mark each variable (left-hand side) and each free symbol (in right-hand sides) as a function with argument $\texttt{xx}$.

# %%
# Step 5.a: Convert each left-hand side to function notation
#   while separating and simplifying left- and right-hand sides
xx = sp.Symbol('xx',real=True)
func = []
for i in range(len(lr)):
    func.append(sp.sympify(sp.Function(lr[i].lhs,real=True)(xx)))
print(func)
# Step 5.b: Mark each free variable as a function with argument xx
full_function_list = []
for symb in full_symbol_list:
    func = sp.sympify(sp.Function(str(symb),real=True)(xx))
    full_function_list.append(func)
    for i in range(len(rhss)):
        for var in rhss[i].free_symbols:
            if str(var) == str(symb):
                rhss[i] = rhss[i].subs(var,func)
print(func)
print(rhss)
# Out:
# [EMgamma(xx), M(xx), mu(xx), eta(xx), r(xx), u(xx), sigmastar3(xx), sigmastar2(xx), sigmastar1(xx), sigma3(xx), sigma2(xx), sigma1(xx), Skerr3(xx), Skerr2(xx), Skerr1(xx), Skerrmag(xx), Skerrhat3(xx), Skerrhat2(xx), Skerrhat1(xx), a(xx), L3(xx), L2(xx), L1(xx), Lnorm(xx), Lhat3(xx), Lhat2(xx), Lhat1(xx), S2dotLhat(xx), S1dotLhat(xx), S1perp3(xx), S1perp2(xx), S1perp1(xx), S2perp3(xx), S2perp2(xx), S2perp1(xx), Sperp3(xx), Sperp2(xx), Sperp1(xx), n3(xx), n2(xx), n1(xx), e33(xx), e32(xx), e31(xx), xi3(xx), xi2(xx), xi1(xx), v3(xx), v2(xx), v1(xx), costheta(xx), sin2theta(xx), xisq(xx), w2(xx), Sigma(xx), Dinv(xx), omegatilde(xx), chi(xx), Kchi0(xx), K(xx), etaKminus1(xx), Delta0(xx), Delta1(xx), Delta2(xx), Delta3(xx), Delta4(xx), Delta5(xx), Delta5l(xx), logarg(xx), Deltaucalib(xx), Deltaucalibprime(xx), Deltaubar(xx), Deltaubarprime(xx), Deltau(xx), Deltauprime(xx), Deltatprime(xx), Deltat(xx), Deltar(xx), Lambt(xx), csi(xx), csi1(xx), csi2(xx), prT(xx), phat3(xx), phat2(xx), phat1(xx), pdotxir(xx), pdotn(xx), pdotvr(xx), pphi(xx), Qcoeff2(xx), Qcoeff1(xx), DrSipn2(xx), Q(xx), Qminus1(xx), Jtilde(xx), exp2mu(xx), expmu(xx), Brtilde(xx), Btilde(xx), exp2nu(xx), expnu(xx), omega(xx), omegatildeprime(xx), Lambtprime(xx), mucostheta(xx), nucostheta(xx), omegacostheta(xx), mur(xx), nur(xx), omegar(xx), dSO(xx), sigmacoeffTerm3(xx), sigmacoeffTerm2(xx), sigmacoeffTerm1(xx), sigmacoeff(xx), sigmastarcoeffTerm2(xx), sigmastarcoeffTerm1(xx), sigmastarcoeff(xx), Deltasigmastar3(xx), Deltasigmastar2(xx), Deltasigmastar1(xx), Sstar3(xx), Sstar2(xx), Sstar1(xx), S3(xx), S2(xx), S1(xx), Sstardotn(xx), SdotSkerrhat(xx), Sdotn(xx), Sdotv(xx), Sdotxi(xx), HdsumTerm2(xx), HdsumTerm1(xx), Hdsum(xx), Hdcoeff(xx), Q4(xx), gammappsum(xx), Hnsradicand(xx), alpha(xx), betapsum(xx), HssTerm3(xx), HssTerm3coeff(xx), HssTerm2(xx), HssTerm2coeff(xx), HssTerm1(xx), Hss(xx), HsoTerm2c(xx), HsoTerm2b(xx), HsoTerm2a(xx), HsoTerm2(xx), HsoTerm2coeff(xx), HsoTerm1(xx), Hso(xx), Hd(xx), Hns(xx), Hs(xx), dSS(xx), Heff(xx), Hreal(xx)]
# Heff(xx)
# [0.577215664901532860606512090082402431, m1 + m2, m1*m2/M(xx), mu(xx)/M(xx), sqrt(x(xx)**2 + y(xx)**2 + z(xx)**2), 1/r(xx), m1*S2z(xx)/m2 + m2*S1z(xx)/m1, m1*S2y(xx)/m2 + m2*S1y(xx)/m1, m1*S2x(xx)/m2 + m2*S1x(xx)/m1, S1z(xx) + S2z(xx), S1y(xx) + S2y(xx), S1x(xx) + S2x(xx), sigma3(xx), sigma2(xx), sigma1(xx), sqrt(Skerr1(xx)**2 + Skerr2(xx)**2 + Skerr3(xx)**2), Skerr3(xx)/Skerrmag(xx), Skerr2(xx)/Skerrmag(xx), Skerr1(xx)/Skerrmag(xx), Skerrmag(xx), -p1(xx)*y(xx) + p2(xx)*x(xx), p1(xx)*z(xx) - p3(xx)*x(xx), -p2(xx)*z(xx) + p3(xx)*y(xx), sqrt(L1(xx)**2 + L2(xx)**2 + L3(xx)**2), L3(xx)/Lnorm(xx), L2(xx)/Lnorm(xx), L1(xx)/Lnorm(xx), Lhat1(xx)*S2x(xx) + Lhat2(xx)*S2y(xx) + Lhat3(xx)*S2z(xx), Lhat1(xx)*S1x(xx) + Lhat2(xx)*S1y(xx) + Lhat3(xx)*S1z(xx), -Lhat3(xx)*S1dotLhat(xx) + S1z(xx), -Lhat2(xx)*S1dotLhat(xx) + S1y(xx), -Lhat1(xx)*S1dotLhat(xx) + S1x(xx), -Lhat3(xx)*S2dotLhat(xx) + S2z(xx), -Lhat2(xx)*S2dotLhat(xx) + S2y(xx), -Lhat1(xx)*S2dotLhat(xx) + S2x(xx), S1perp3(xx) + S2perp3(xx), S1perp2(xx) + S2perp2(xx), S1perp1(xx) + S2perp1(xx), z(xx)/r(xx), y(xx)/r(xx), x(xx)/r(xx), Skerrhat3(xx), Skerrhat2(xx), Skerrhat1(xx), e31(xx)*n2(xx) - e32(xx)*n1(xx), -e31(xx)*n3(xx) + e33(xx)*n1(xx), e32(xx)*n3(xx) - e33(xx)*n2(xx), n1(xx)*xi2(xx) - n2(xx)*xi1(xx), -n1(xx)*xi3(xx) + n3(xx)*xi1(xx), n2(xx)*xi3(xx) - n3(xx)*xi2(xx), e31(xx)*n1(xx) + e32(xx)*n2(xx) + e33(xx)*n3(xx), 1 - costheta(xx)**2, sin2theta(xx), a(xx)**2 + r(xx)**2, a(xx)**2*costheta(xx)**2 + r(xx)**2, log(eta*(52 - 6*eta)*u(xx)**3 + 6*eta*u(xx)**2 + 1) + 1, 2*a(xx)*r(xx), (Lhat1(xx)*Skerr1(xx) + Lhat2(xx)*Skerr2(xx) + Lhat3(xx)*Skerr3(xx))/(1 - 2*eta) + (Skerr1(xx)*Sperp1(xx)/2 + Skerr2(xx)*Sperp2(xx)/2 + Skerr3(xx)*Sperp3(xx)/2)/((1.0 - 2.0*eta)*Skerrmag(xx)), 267.788*eta**3 - 126.687*eta**2 + 10.2573*eta + 1.7336, -59.1658*eta**3*chi(xx)**3 + 31.1746*eta**3*chi(xx)**2 - 27.5201*eta**3*chi(xx) + 6.16466*eta**2*chi(xx)**2 + 17.3736*eta**2*chi(xx) - 0.426958*eta*chi(xx)**3 + 2.26831*eta*chi(xx) + Kchi0(xx) + 1.43659*chi(xx)**3 - 1.38086*chi(xx)**2 - 1.62045*chi(xx), eta*K(xx) - 1, (eta*K(xx) - 2)*K(xx), -2*(Delta0(xx) + K(xx))*etaKminus1(xx), (Delta1(xx) - 4*etaKminus1(xx))*Delta1(xx)/2 - Delta0(xx)*a(xx)**2*etaKminus1(xx)**2, -2*(Delta2(xx) - etaKminus1(xx))*etaKminus1(xx) - Delta1(xx)**3/3 + Delta1(xx)**2*etaKminus1(xx) + Delta1(xx)*Delta2(xx) - Delta1(xx)*a(xx)**2*etaKminus1(xx)**2, (24*Delta2(xx)*etaKminus1(xx) + 12*Delta3(xx))*Delta1(xx)/12 + (Delta1(xx)**2 - 2*Delta2(xx))*a(xx)**2*etaKminus1(xx)**2/2 + Delta1(xx)**4/4 - 2*Delta1(xx)**3*etaKminus1(xx)/3 - Delta1(xx)**2*Delta2(xx) + Delta2(xx)**2/2 - 2*Delta3(xx)*etaKminus1(xx) + (376 - 123*pi**2/8)*etaKminus1(xx)**2/12, (128*EMgamma/5 + eta*(-221/6 + 41*pi**2/32) - (Delta1(xx)**3 - 3*Delta1(xx)*Delta2(xx) + 3*Delta3(xx))*a(xx)**2/3 + (Delta1(xx)**4 - 4*Delta1(xx)**2*Delta2(xx) + 4*Delta1(xx)*Delta3(xx) + 2*Delta2(xx)**2 - 4*Delta4(xx))/(2*etaKminus1(xx)) - (Delta1(xx)**5 - 5*Delta1(xx)**3*Delta2(xx) + 5*Delta1(xx)**2*Delta3(xx) + 5*Delta1(xx)*Delta2(xx)**2 - 5*Delta1(xx)*Delta4(xx) - 5*Delta2(xx)*Delta3(xx))/(5*etaKminus1(xx)**2) - 4237/60 + 256*log(2)/5 + 2275*pi**2/512)*etaKminus1(xx)**2, 64*etaKminus1(xx)**2/5, (((((Delta5(xx) + Delta5l(xx)*log(u(xx)))*u(xx) + Delta4(xx))*u(xx) + Delta3(xx))*u(xx) + Delta2(xx))*u(xx) + Delta1(xx))*u(xx), eta*(Delta0(xx) + log(logarg(xx) + 1)) + 1, -eta*(((((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*u(xx) + 3*Delta3(xx))*u(xx) + 2*Delta2(xx))*u(xx) + Delta1(xx))*u(xx)**2/(logarg(xx) + 1), (2*u(xx) + 1/etaKminus1(xx))/etaKminus1(xx) + a(xx)**2*u(xx)**2, -2*a(xx)**2*u(xx)**3 - 2*u(xx)**2/etaKminus1(xx), Deltaubar(xx)*Deltaucalib(xx), Deltaubar(xx)*Deltaucalibprime(xx) + Deltaubarprime(xx)*Deltaucalib(xx), 2*Deltau(xx)*r(xx) + Deltauprime(xx)*r(xx)**2, Deltau(xx)*r(xx)**2, Deltat(xx)*Dinv(xx), -Deltat(xx)*a(xx)**2*sin2theta(xx) + w2(xx)**2, sqrt(Deltar(xx)*Deltat(xx))/w2(xx), (1 - Abs(tortoise - 1))*(csi(xx) - 1) + 1, (1/2 - sign(3/2 - tortoise)/2)*(csi(xx) - 1) + 1, ...

# %% [markdown]
# <a id='differentiate'></a>
#
# # Step 6: Differentiate with respect to `xx` \[Back to [top](#toc)\]
# $$\label{differentiate}$$
#
# Now we differentiate the right-hand expressions with respect to `xx`.  We use the SymPy $\texttt{diff}$ command, differentiating with respect to $\texttt{xx}$.  After so doing, we remove $\texttt{(xx)}$ and "Derivative" (which is output by $\texttt{diff}$), and use "prm" suffix to denote the derivative with respect to $\texttt{xx}$.

# %%
# Step 6: Use SymPy's diff function to differentiate right-hand sides with respect to xx
#   and append "prm" notation to left-hand sides
lhss_deriv = []
rhss_deriv = []
for i in range(len(rhss)):
    lhss_deriv.append(custom_parse_expr(str(lhss[i])+"prm"))
    newrhs = custom_parse_expr(str(sp.diff(rhss[i],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
    rhss_deriv.append(newrhs)

# %% [markdown]
# <a id='remove_zeros'></a>
#
# # Step 7: Remove derivatives (of constants) that evaluate to zero, simplifying derivative expressions \[Back to [top](#toc)\]
# $$\label{remove_zeros}$$
#
# We declare a function to simply the derivative expressions.  In particular, we want to remove terms equal to zero.

# %%
# Step 7.a: Define derivative simplification function
def simplify_deriv(lhss_deriv,rhss_deriv):
    # Copy expressions into another array
    lhss_deriv_simp = []
    rhss_deriv_simp = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_simp.append(lhss_deriv[i])
        rhss_deriv_simp.append(rhss_deriv[i])
    # If a right-hand side is 0, substitute value 0 for the corresponding left-hand side in later terms
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == 0:
            for j in range(i+1,len(rhss_deriv_simp)):
                for var in rhss_deriv_simp[j].free_symbols:
                    if str(var) == str(lhss_deriv_simp[i]):
                        rhss_deriv_simp[j] = rhss_deriv_simp[j].subs(var,0)
    zero_elements_to_remove = []
    # Create array of indices for expressions that are zero
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == sp.sympify(0):
            zero_elements_to_remove.append(i)

    # When removing terms that are zero, we need to take into account their new index (after each removal)
    count = 0
    for i in range(len(zero_elements_to_remove)):
        del lhss_deriv_simp[zero_elements_to_remove[i]+count]
        del rhss_deriv_simp[zero_elements_to_remove[i]+count]
        count -= 1
    return lhss_deriv_simp,rhss_deriv_simp

# Step 7.b: Call the simplication function and then copy results
lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv,rhss_deriv)
lhss_deriv = lhss_deriv_simp
rhss_deriv = rhss_deriv_simp

# %% [markdown]
# <a id='partial_derivative'></a>
#
# # Step 8: Simplify derivatives with respect to a specific variable \[Back to [top](#toc)\]
# $$\label{partial_derivative}$$
#
# In [Step 6](#differentiate) we took a generic derivative of each expression, assuming all variables were functions of `xx`.  We now define a function that will select a specific dynamic variable (element of `dynamic_variables`) and set the derivative of the variable to 1 and all others to 0.

# %%
# Step 8.a: Define onevar derivative function
def deriv_onevar(lhss_deriv,rhss_deriv,variable_list,index):
    # Denote each variable with prm
    variableprm_list = []
    for variable in variable_list:
        variableprm_list.append(str(variable)+"prm")

    # Copy expressions into another array
    lhss_deriv_new = []
    rhss_deriv_new = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_new.append(lhss_deriv[i])
        rhss_deriv_new.append(rhss_deriv[i])
    # For each free symbol's derivative, replace it with:
    #   1, if we are differentiating with respect to the variable, or
    #   0, if we are note differentiating with respect to that variable
    for i in range(len(rhss_deriv_new)):
        for var in variableprm_list:
            if variableprm_list.index(str(var))==index:
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,1)
            else:
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,0)
    # Simplify derivative expressions again
    lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv_new,rhss_deriv_new)
    return lhss_deriv_simp,rhss_deriv_simp

# Step 8.b: Call the derivative function and populate dictionaries with the result
lhss_derivative = {}
rhss_derivative = {}
for index in range(len(dynamic_variables)):
    lhss_temp,rhss_temp = deriv_onevar(lhss_deriv,rhss_deriv,dynamic_variables,index)
    lhss_derivative[dynamic_variables[index]] = lhss_temp
    rhss_derivative[dynamic_variables[index]] = rhss_temp

# %% [markdown]
# <a id='store_results'></a>
#
# # Step 9: Store partial derivatives to SymPy notebook `partial_derivatives.txt-VALIDATION.txt` \[Back to [top](#toc)\]
# $$\label{store_results}$$
#
# We write the resulting derivatives in SymPy syntax.  Each partial derivative is output in its own file, in a similar format to the input expressions.

# %%
# Step 9: Output original expression and each partial derivative expression in SymPy snytax
with open(os.path.join(inputdir,'partial_derivatives.txt-VALIDATION'), 'w') as output:
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(")
        output.write(str(lr[i].lhs)+" = "+right_side_in_sp)
    for var in dynamic_variables:
        for i in range(len(lhss_derivative[var])):
            right_side = str(rhss_derivative[var][i])
            right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
                                                "prm_"+str(var))
            output.write(str(lhss_derivative[var][i]).replace("prm","prm_"+str(var))+" = "+right_side_in_sp+"\n")

# %% [markdown]
# <a id='code_validation'></a>
#
# # Step 10: Validate against LALSuite and trusted `SEOBNR_Derivative_Routine` NRPy+ module \[Back to [top](#toc)\]
# $$\label{code_validation}$$
#
# We validate the output of this notebook against known LALSuite values of the Hamiltonian partial derivatives and the output of the `SEOBNR_Derivative_Routine` NRPy+ module.  We note that due to cancellations in the deriavtive terms, various versions of SymPy may result in relative errors that differ as much as an order of magnitude.  Furthermore, even changing the set of input pararameters can affect the relative error by as many as two orders of magnitude.  Therefore we look for agreement with LALSuite to at least 10 significant digits.
#
# When comparing the notebook output to that of the NRPy+ module, we compare term-by-term using SymPy to check that each right-hand side side is equivalent.

# %%
# Numerically evaluate right-hand sides using input values
def evaluate_expression(left_sides,right_sides,input_values):
    new_right_sides = []
    for i in range(len(right_sides)):
        term = custom_parse_expr(str(right_sides[i]).replace("(xx)",""))
        # Only look for the free variables in each expression to reduce computation time
        free_vars = term.free_symbols
        for variable in free_vars:
            term = term.subs(variable, input_values[str(variable)])
        # Evaluate each term to reduce computation time
        new_right_sides.append(sp.sympify(term.evalf()))
        # Store each subexpression in values numerically
        input_values[str(left_sides[i])] = new_right_sides[i]
    # Return the input values dictionary with all numerical right-hand added
    return input_values

# %%
##hard validation against lalsuite integration
import numpy as np

Derivativedir = 'Derivatives'
var_index = ['x', 'y', 'z', 'p1', 'p2', 'p3', 'S1x', 'S1y', 'S1z', 'S2x', 'S2y', 'S2z']

for index in range(1):
    validationfile = 'outputv4Pindex'+str(index)+'.txt'
    validationfile_pert = 'outputv4Pindex'+str(index)+'pert.txt'
    with open(os.path.join(Derivativedir,validationfile)) as file1, open(os.path.join(Derivativedir,validationfile_pert)) as file2:
        file1_lines = file1.readlines()
        file2_lines = file2.readlines()
        for i in range(len(file2_lines)//3):
            valuepairs = file1_lines[3*i].strip('{}\n').split(',')
            valuepairspert = file2_lines[3*i].strip('{}\n').split(',')
            derivpairs = file1_lines[3*i+1].strip('{}\n').split(',')
            derivpairspert = file2_lines[3*i+1].strip('{}\n').split(',')
            values = dict()
            derivs = dict()
            valuespert = dict()
            derivspert = dict()
            for j in range(len(valuepairs)):
                pair = valuepairs[j].split(': ')
                pairpert = valuepairspert[j].split(': ')
                values[pair[0].strip(" ''")] = float(pair[1])
                valuespert[pairpert[0].strip(" ''")] = float(pairpert[1])
            for j in range(len(derivpairs)):
                pair = derivpairs[j].split(': ')
                pairpert = derivpairspert[j].split(': ')
                derivs[pair[0].strip(" ''")] = float(pair[1])
                derivspert[pairpert[0].strip(" ''")] = float(pairpert[1]) 
            values = evaluate_expression(lhss,rhss,values)
            eta = values['eta']
            #Hreal = values['Hreal']
            #LAL_Hreal = derivs['Hreal']
            #LAL_Hreal_pert = derivspert['Hreal']
            #Erel = abs((Hreal-LAL_Hreal)/LAL_Hreal)
            #Erelpert = abs((LAL_Hreal-LAL_Hreal_pert)/LAL_Hreal)
            #if Erel > Erelpert:
            #    print("Line %d: Erel in Hamiltonian is %.2e, allowed is %.2e"%(i,Erel,Erelpert))
            for k in range(len(var_index)):
                values = evaluate_expression(lhss_derivative[dynamic_variables[k]],rhss_derivative[dynamic_variables[k]],values)
                Hrealprm = values['Hrealprm']/eta
                #if var_index[k][0] != 'S':
                #    Hrealprm /= eta
                LAL_Hrealprm = derivs['dHreal_d'+var_index[k]]
                LAL_Hreal_pertprm = derivspert['dHreal_d'+var_index[k]]
                Erel = abs((Hrealprm-LAL_Hrealprm)/LAL_Hrealprm)
                Erelpert = abs((LAL_Hrealprm-LAL_Hreal_pertprm)/LAL_Hrealprm)
                if Erel > Erelpert:
                    print("Line %d: Erel in %s derivative is %.2e, allowed is %.2e"%(i,var_index[k],Erel,Erelpert))
                    if Erel > 1:
                        print(var_index[k])
                        valuekeys = list(values.keys())
                        valueterms = list(values.values())
                        prmvar = False
                        for l in range(len(valuekeys)):
                            prmvar = ('prm' in valuekeys[l])
                            if prmvar:
                                print(valuekeys[l]," : ","%.16e"%(valueterms[l]/eta))
                            else:
                                print(valuekeys[l]," : ","%.16e"%valueterms[l])
                        sys.exit(1)
# Out:
# Line 0: Erel in y derivative is 1.28e-03, allowed is 2.11e-05
# Line 0: Erel in z derivative is 1.96e-07, allowed is 1.01e-07
# Line 0: Erel in p1 derivative is 2.52e-06, allowed is 0.00e+00
# Line 0: Erel in p3 derivative is 6.26e-09, allowed is 2.79e-09
# Line 0: Erel in S1y derivative is 1.19e-06, allowed is 4.73e-08
# Line 0: Erel in S2x derivative is 1.26e-07, allowed is 6.32e-08
# Line 0: Erel in S2y derivative is 1.77e-06, allowed is 1.57e-06
# Line 1: Erel in x derivative is 3.16e-10, allowed is 1.56e-10
# Line 1: Erel in y derivative is 1.15e-03, allowed is 1.48e-04
# Line 1: Erel in p2 derivative is 2.47e-11, allowed is 2.57e-12
# Line 1: Erel in S1y derivative is 1.19e-06, allowed is 1.58e-07
# Line 2: Erel in x derivative is 2.40e-10, allowed is 4.25e-11
# Line 2: Erel in y derivative is 1.28e-03, allowed is 2.11e-05
# Line 2: Erel in p1 derivative is 2.50e-06, allowed is 0.00e+00
# Line 2: Erel in S1y derivative is 1.21e-06, allowed is 7.44e-08
# Line 2: Erel in S1z derivative is 6.56e-10, allowed is 1.31e-10
# Line 2: Erel in S2x derivative is 1.91e-07, allowed is 6.32e-08
# Line 2: Erel in S2y derivative is 1.76e-06, allowed is 1.44e-15
# Line 2: Erel in S2z derivative is 5.89e-10, allowed is 3.15e-10
# Line 3: Erel in x derivative is 6.06e-10, allowed is 3.52e-10
# Line 3: Erel in y derivative is 1.30e-03, allowed is 0.00e+00
# Line 3: Erel in p1 derivative is 1.24e-04, allowed is 1.22e-04
# Line 3: Erel in p2 derivative is 9.82e-11, allowed is 9.63e-12
# Line 3: Erel in p3 derivative is 2.66e-09, allowed is 1.27e-09
# Line 3: Erel in S1y derivative is 1.24e-06, allowed is 6.96e-08
# Line 3: Erel in S2y derivative is 1.81e-06, allowed is 1.37e-06
# Line 6: Erel in x derivative is 3.16e-10, allowed is 1.56e-10
# Line 6: Erel in y derivative is 1.15e-03, allowed is 1.48e-04
# Line 6: Erel in p2 derivative is 2.47e-11, allowed is 2.57e-12
# Line 6: Erel in S1y derivative is 1.19e-06, allowed is 1.58e-07
# Line 7: Erel in x derivative is 2.40e-10, allowed is 4.25e-11
# Line 7: Erel in y derivative is 1.28e-03, allowed is 2.11e-05
# Line 7: Erel in p1 derivative is 2.50e-06, allowed is 0.00e+00
# Line 7: Erel in S1y derivative is 1.21e-06, allowed is 7.44e-08
# Line 7: Erel in S1z derivative is 6.56e-10, allowed is 1.31e-10
# Line 7: Erel in S2x derivative is 1.91e-07, allowed is 6.32e-08
# Line 7: Erel in S2y derivative is 1.76e-06, allowed is 1.44e-15
# Line 7: Erel in S2z derivative is 5.89e-10, allowed is 3.15e-10
# Line 8: Erel in x derivative is 6.06e-10, allowed is 3.52e-10
# Line 8: Erel in y derivative is 1.30e-03, allowed is 0.00e+00
# Line 8: Erel in p1 derivative is 1.24e-04, allowed is 1.22e-04
# Line 8: Erel in p2 derivative is 9.82e-11, allowed is 9.63e-12
# Line 8: Erel in p3 derivative is 2.66e-09, allowed is 1.27e-09
# Line 8: Erel in S1y derivative is 1.24e-06, allowed is 6.96e-08
# Line 8: Erel in S2y derivative is 1.81e-06, allowed is 1.37e-06
# Line 21: Erel in y derivative is 8.01e-04, allowed is 3.85e-04
# Line 22: Erel in y derivative is 7.59e-04, allowed is 0.00e+00
# Line 22: Erel in p1 derivative is 4.74e-05, allowed is 0.00e+00
# Line 23: Erel in y derivative is 7.68e-04, allowed is 6.24e-05
# Line 27: Erel in y derivative is 7.09e-04, allowed is 4.40e-04
# Line 28: Erel in y derivative is 7.27e-04, allowed is 3.52e-04
# Line 29: Erel in y derivative is 7.14e-04, allowed is 7.71e-05
# Line 30: Erel in y derivative is 7.22e-04, allowed is 7.71e-05
# Line 30: Erel in S1y derivative is 2.77e-06, allowed is 2.62e-06
# Line 31: Erel in y derivative is 7.93e-04, allowed is 0.00e+00
# Line 32: Erel in y derivative is 8.08e-04, allowed is 5.17e-04
# Line 35: Erel in y derivative is 7.09e-04, allowed is 4.40e-04
# Line 36: Erel in y derivative is 7.27e-04, allowed is 4.30e-04
# Line 37: Erel in y derivative is 7.87e-04, allowed is 2.20e-05
# Line 37: Erel in p1 derivative is 1.49e-04, allowed is 1.29e-04
# Line 38: Erel in y derivative is 8.15e-04, allowed is 1.10e-05
# Line 39: Erel in y derivative is 8.02e-04, allowed is 8.81e-05
# Line 39: Erel in p1 derivative is 4.48e-05, allowed is 1.43e-05
# Line 40: Erel in y derivative is 8.10e-04, allowed is 1.10e-05
# Line 42: Erel in x derivative is 2.00e-06, allowed is 1.22e-06
# Line 42: Erel in y derivative is 2.03e+00, allowed is 1.33e+00
# y
# m1  :  2.3000000000000000e+01
# m2  :  1.0000000000000000e+01
# x  :  2.1296906518814026e+01
# y  :  0.0000000000000000e+00
# z  :  0.0000000000000000e+00
# S1x  :  4.8576675849403119e-03
# S1y  :  -9.7079697966884933e-03
# S1z  :  -1.4577910316013127e-02
# S2x  :  3.6730945821854912e-03
# S2y  :  -4.5941518126922558e-03
# S2z  :  5.5073210271731048e-03
# p1  :  1.0000000000000000e-03
# p2  :  2.3354022716130973e-01
# p3  :  1.3552527156068805e-20
# tortoise  :  1.0000000000000000e+00
# EMgamma  :  5.7721566490153287e-01
# M  :  3.3000000000000000e+01
# mu  :  6.9696969696969697e+00
# eta  :  2.1120293847566576e-01
# r  :  2.1296906518814026e+01
# u  :  4.6955176288940560e-02
# sigmastar3  :  6.3286164859706964e-03
# sigmastar2  :  -1.4787405602535011e-02
# sigmastar1  :  1.0560146923783287e-02
# sigma3  :  -9.0705892888400218e-03
# sigma2  :  -1.4302121609380748e-02
# sigma1  :  8.5307621671258035e-03
# Skerr3  :  -9.0705892888400218e-03
# Skerr2  :  -1.4302121609380748e-02
# Skerr1  :  8.5307621671258035e-03
# Skerrmag  :  1.8963126739237918e-02
# Skerrhat3  :  -4.7832772588454187e-01
# Skerrhat2  :  -7.5420693043132159e-01
# Skerrhat1  :  4.4986052587383774e-01
# a  :  1.8963126739237918e-02
# L3  :  4.9736843862370055e+00
# L2  :  -2.8862690393648586e-19
# L1  :  0.0000000000000000e+00
# Lnorm  :  4.9736843862370055e+00
# Lhat3  :  1.0000000000000000e+00
# Lhat2  :  -5.8030804032351447e-20
# Lhat1  :  0.0000000000000000e+00
# S2dotLhat  :  5.5073210271731048e-03
# S1dotLhat  :  -1.4577910316013127e-02
# S1perp3  :  0.0000000000000000e+00
# S1perp2  :  -9.7079697966884933e-03
# S1perp1  :  4.8576675849403119e-03
# S2perp3  :  0.0000000000000000e+00
# S2perp2  :  -4.5941518126922558e-03
# S2perp1  :  3.6730945821854912e-03
# Sperp3  :  0.0000000000000000e+00
# Sperp2  :  -1.4302121609380748e-02
# Sperp1  :  8.5307621671258035e-03
# n3  :  0.0000000000000000e+00
# n2  :  0.0000000000000000e+00
# n1  :  1.0000000000000000e+00
# e33  :  -4.7832772588454187e-01
# e32  :  -7.5420693043132159e-01
# e31  :  4.4986052587383774e-01
# xi3  :  7.5420693043132159e-01
# xi2  :  -4.7832772588454187e-01
# xi1  :  0.0000000000000000e+00
# v3  :  -4.7832772588454187e-01
# v2  :  -7.5420693043132159e-01
# v1  :  0.0000000000000000e+00
# costheta  :  4.4986052587383774e-01
# sin2theta  :  7.9762550726051418e-01
# xisq  :  7.9762550726051418e-01
# w2  :  4.5355858687127909e+02
# Sigma  :  4.5355830004500649e+02
# Dinv  :  1.0038956237435721e+00
# omegatilde  :  8.0771187493994512e-01
# chi  :  -3.0443230333122157e-03
# Kchi0  :  7.7173266789507089e-01
# K  :  7.7362984847331051e-01
# etaKminus1  :  -8.3660710270995275e-01
# Delta0  :  -1.4208540745745066e+00
# Delta1  :  -1.0829447692044261e+00
# Delta2  :  -1.2252562726285736e+00
# Delta3  :  1.1906508914537328e-01
# Delta4  :  1.2753515157277532e+01
# Delta5  :  1.9577595351464307e+01
# Delta5l  :  8.9588664871006909e+00
# logarg  :  -5.3478756982847576e-02
# Deltaucalib  :  6.8830333694930346e-01
# Deltaucalibprime  :  5.8648955665444068e-04
# Deltaubar  :  1.3165015294900622e+00
# Deltaubarprime  :  5.2707117305850759e-03
# Deltau  :  9.0615239584687157e-01
# Deltauprime  :  4.3999628706250654e-03
# Deltatprime  :  4.0592125091959751e+01
# Deltat  :  4.1099287429777019e+02
# Deltar  :  4.1259394789732352e+02
# Lambt  :  2.0571527384111742e+05
# csi  :  9.0791497478977867e-01
# csi1  :  9.0791497478977867e-01
# csi2  :  1.0000000000000000e+00
# prT  :  1.0000000000000000e-03
# phat3  :  1.3552527156068805e-20
# phat2  :  2.3354022716130973e-01
# phat1  :  1.1014247234236256e-03
# pdotxir  :  -2.3790511417362001e+00
# pdotn  :  1.1014247234236256e-03
# pdotvr  :  -3.7511872338780035e+00
# pphi  :  -2.3790511417362001e+00
# Qcoeff2  :  2.7641897187281701e-03
# Qcoeff1  :  2.7641878066286792e-03
# DrSipn2  :  1.1035687041355446e-06
# Q  :  1.0545421216978319e+00
# Qminus1  :  5.4542121697831902e-02
# Jtilde  :  2.0312408717267470e+01
# exp2mu  :  4.5355830004500649e+02
# expmu  :  2.1296908227369684e+01
# Brtilde  :  3.0817537415861141e-03
# Btilde  :  2.0272959189466402e+01
# exp2nu  :  9.0615162363237745e-01
# expnu  :  9.5191996703104065e-01
# omega  :  3.9263583099997484e-06
# omegatildeprime  :  3.7926253478475835e-02
# Lambtprime  :  3.8637556015836213e+04
# mucostheta  :  3.5666842419475101e-07
# nucostheta  :  3.3472752512275870e-08
# omegacostheta  :  -2.5379640225328730e-12
# mur  :  -2.2758217159261143e-03
# nur  :  2.4278686074956576e-03
# omegar  :  -5.5308793332603707e-07
# dSO  :  -4.4871923931643266e+01
# sigmacoeffTerm3  :  -9.8112665177825065e-04
# sigmacoeffTerm2  :  -4.7991511558035226e-03
# sigmacoeffTerm1  :  -3.7322159434509390e-03
# sigmacoeff  :  -9.5124937510327121e-03
# sigmastarcoeffTerm2  :  2.9289117703306397e-03
# sigmastarcoeffTerm1  :  1.5409152509055359e-02
# sigmastarcoeff  :  1.8338064279385998e-02
# Deltasigmastar3  :  2.0233849984758751e-04
# Deltasigmastar2  :  -1.3512355202889540e-04
# Deltasigmastar1  :  1.1250383128176774e-04
# Sstar3  :  6.5309549858182840e-03
# Sstar2  :  -1.4922529154563907e-02
# Sstar1  :  1.0672650755065054e-02
# S3  :  6.5309549858182840e-03
# S2  :  -1.4922529154563907e-02
# S1  :  1.0672650755065054e-02
# Sstardotn  :  1.0672650755065054e-02
# SdotSkerrhat  :  1.2931942342856155e-02
# Sdotn  :  1.0672650755065054e-02
# Sdotv  :  8.1307380617147793e-03
# Sdotxi  :  1.2063550947587473e-02
# HdsumTerm2  :  3.4171642241877205e-04
# HdsumTerm1  :  3.7924072353518514e-04
# Hdsum  :  3.7524301116413097e-05
# Hdcoeff  :  5.1763118234513081e-05
# Q4  :  3.1351728068882217e-15
# gammappsum  :  5.4542121697831812e-02
# Hnsradicand  :  1.0545421216978350e+00
# alpha  :  9.5191996703104087e-01
# betapsum  :  -9.3410072202703182e-06
# HssTerm3  :  -3.2660598100648003e+03
# HssTerm3coeff  :  -3.2705589776082927e-18
# HssTerm2  :  2.4906729882517880e+03
# HssTerm2coeff  :  -1.8150688359262292e-11
# HssTerm1  :  5.0775439282310881e-08
# Hss  :  5.5680207495613592e-09
# HsoTerm2c  :  -4.9755873682453537e-02
# HsoTerm2b  :  -1.1972844507646403e+00
# HsoTerm2a  :  2.6845403272598030e+00
# HsoTerm2  :  1.5370117501776164e+00
# HsoTerm2coeff  :  3.0758685521007447e-06
# HsoTerm1  :  2.7265685654791123e-11
# Hso  :  4.7276733722663114e-06
# Hd  :  1.9423748353563621e-09
# Hns  :  9.7752585312403228e-01
# Hs  :  4.7332413930158729e-06
# dSS  :  5.0953646938923089e+00
# Heff  :  9.7753058649090530e-01
# Hreal  :  9.9524307969566350e-01
# rprm  :  0.0000000000000000e+00
# uprm  :  0.0000000000000000e+00
# L3prm  :  -4.7347826086956519e-03
# L2prm  :  -6.4168269882430126e-20
# Lnormprm  :  -4.7347826086956519e-03
# Lhat3prm  :  0.0000000000000000e+00
# Lhat2prm  :  -5.5243401141680363e-23
# Lhat1prm  :  1.2901556451791387e-20
# S2dotLhatprm  :  4.7642433676329553e-23
# S1dotLhatprm  :  6.3207773840894341e-23
# S1perp3prm  :  -6.3207773840894341e-23
# S1perp2prm  :  -8.0533334739495346e-25
# S1perp1prm  :  1.8807773289119537e-22
# S2perp3prm  :  -4.7642433676329553e-23
# S2perp2prm  :  3.0424314472013494e-25
# S2perp1prm  :  -7.1053013130211547e-23
# Sperp3prm  :  -1.1085020751722389e-22
# Sperp2prm  :  -5.0109020267481847e-25
# Sperp1prm  :  1.1702471976098385e-22
# n3prm  :  0.0000000000000000e+00
# n2prm  :  2.2232255208111421e-01
# n1prm  :  0.0000000000000000e+00
# xi3prm  :  1.0001414019282372e-01
# xi2prm  :  0.0000000000000000e+00
# xi1prm  :  1.0634304074980697e-01
# v3prm  :  0.0000000000000000e+00
# v2prm  :  -1.0001414019282372e-01
# v1prm  :  1.6767720957075477e-01
# costhetaprm  :  -1.6767720957075477e-01
# sin2thetaprm  :  1.5086271534911488e-01
# xisqprm  :  1.5086271534911488e-01
# w2prm  :  0.0000000000000000e+00
# Sigmaprm  :  -5.4250258950405319e-05
# Dinvprm  :  0.0000000000000000e+00
# omegatildeprm  :  0.0000000000000000e+00
# chiprm  :  2.8371641720973523e-22
# Kprm  :  -1.7610255367333944e-22
# etaKminus1prm  :  -3.7193376808877938e-23
# Delta0prm  :  2.9465729441695295e-22
# Delta1prm  :  1.5022256728965576e-22
# Delta2prm  :  8.0726796130321159e-24
# Delta3prm  :  -9.3580126620819282e-23
# Delta4prm  :  1.0128820694895884e-21
# Delta5prm  :  4.4003200198125770e-21
# Delta5lprm  :  7.9657582622911805e-22
# logargprm  :  7.0672096737174541e-24
# Deltaucalibprm  :  6.3809435130715463e-23
# Deltaucalibprimeprm  :  -7.8581956822865105e-26
# Deltaubarprm  :  -1.2204680755770346e-22
# Deltaubarprimeprm  :  -2.3432545108164425e-25
# Deltauprm  :  -5.9604929494050925e-30
# Deltauprimeprm  :  1.7039505916322531e-30
# Deltatprimeprm  :  5.1896068739921170e-28
# Deltatprm  :  -2.7034306157940842e-27
# Deltarprm  :  -2.7139621642900712e-27
# Lambtprm  :  -2.2296469857425411e-02
# csiprm  :  -5.9720868484116149e-30
# csi1prm  :  -5.9720868484116149e-30
# csi2prm  :  0.0000000000000000e+00
# prTprm  :  5.1921259316105528e-02
# phat3prm  :  0.0000000000000000e+00
# phat2prm  :  2.2549003355661615e-05
# phat1prm  :  5.2660993659423491e-03
# pdotxirprm  :  2.2647777977750695e-03
# pdotnprm  :  5.7187358682047870e-02
# pdotvrprm  :  -4.9386776162240237e-01
# pphiprm  :  2.2647777977750695e-03
# Qcoeff2prm  :  -5.2281791291283785e-04
# Qcoeff1prm  :  -5.2281791291306466e-04
# DrSipn2prm  :  1.1459735385311855e-04
# Qprm  :  1.0761396156730995e-05
# Qminus1prm  :  1.0761396156730995e-05
# Jtildeprm  :  -6.6805522724218975e-29
# exp2muprm  :  -5.4250258950405319e-05
# expmuprm  :  -1.2736651341880154e-06
# Brtildeprm  :  1.6091982547719566e-29
# Btildeprm  :  -6.6675777091258495e-29
# exp2nuprm  :  -1.0171765352071694e-08
# expnuprm  :  -5.3427628920299816e-09
# omegaprm  :  4.2555872528928029e-13
# Lambtprimeprm  :  -4.4042665951721238e-03
# mucosthetaprm  :  -1.3294153071821990e-07
# nucosthetaprm  :  -1.2476343181783842e-08
# omegacosthetaprm  :  9.4597870522125130e-13
# murprm  :  5.6163233343152363e-09
# nurprm  :  7.9022759999137998e-10
# omegarprm  :  -5.5813691227232749e-14
# dSOprm  :  3.1704393138440951e-20
# sigmacoeffTerm3prm  :  6.9321799381649033e-25
# sigmacoeffTerm2prm  :  -2.7194572182297844e-06
# sigmacoeffTerm1prm  :  -7.2041684003342312e-05
# sigmacoeffprm  :  -7.4761141221572100e-05
# sigmastarcoeffTerm2prm  :  4.2941764444210406e-06
# sigmastarcoeffTerm1prm  :  -5.9750631858151632e-05
# sigmastarcoeffprm  :  -5.5456455413730584e-05
# Deltasigmastar3prm  :  3.2716496880101375e-07
# Deltasigmastar2prm  :  1.8893000328887448e-06
# Deltasigmastar1prm  :  -1.2233978321453686e-06
# Sstar3prm  :  3.2716496880101375e-07
# Sstar2prm  :  1.8893000328887448e-06
# Sstar1prm  :  -1.2233978321453686e-06
# S3prm  :  3.2716496880101375e-07
# S2prm  :  1.8893000328887448e-06
# S1prm  :  -1.2233978321453686e-06
# Sstardotnprm  :  -3.3188381629796248e-03
# SdotSkerrhatprm  :  -2.1317736461063196e-06
# Sdotnprm  :  -3.3188381629796248e-03
# Sdotvprm  :  3.2804428049745872e-03
# Sdotxiprm  :  1.7874930271976109e-03
# HdsumTerm2prm  :  -2.1252480375637926e-04
# HdsumTerm1prm  :  -7.8226665870631992e-08
# Hdsumprm  :  2.1244657709050863e-04
# Hdcoeffprm  :  0.0000000000000000e+00
# Q4prm  :  6.5112848122898303e-13
# gammappsumprm  :  1.0761396156730995e-05
# Hnsradicandprm  :  1.0761396807859475e-05
# alphaprm  :  -5.3427628920299816e-09
# betapsumprm  :  8.8913167006257986e-09
# HssTerm3prm  :  4.0816247396326440e+02
# HssTerm3coeffprm  :  1.2190643342531899e-18
# HssTerm2prm  :  1.4710512501740259e+03
# HssTerm2coeffprm  :  3.4331516002549658e-12
# HssTerm1prm  :  -8.3646038695290710e-12
# Hssprm  :  -1.8158104767409494e-08
# HsoTerm2cprm  :  -2.0027357400419797e-02
# HsoTerm2bprm  :  -4.8192403559546831e-01
# HsoTerm2aprm  :  7.5121555911412063e-01
# HsoTerm2prm  :  2.8931888091907215e-01
# HsoTerm2coeffprm  :  -5.8179240545846522e-07
# HsoTerm1prm  :  -3.0587586542955920e-14
# Hsoprm  :  -4.3149465933933850e-09
# Hdprm  :  1.0996897288453597e-08
# Hnsprm  :  4.9911828461810910e-06
# Hsprm  :  -2.2473051360802881e-08
# dSSprm  :  2.2352286531263766e-21
# Heffprm  :  4.9577128975318347e-06
# Hrealprm  :  1.0520882319499471e-06
# L1prm  :  6.4168269882430126e-20
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\sidmahesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
print("Printing difference between notebook output and trusted NRPy+ module output...")
# Open the files to compare
file = 'partial_derivatives.txt'
outfile = 'partial_derivatives.txt-VALIDATION'
outputdir = 'Derivatives'
print("Checking file " + outfile)
with open(os.path.join(outputdir,file), "r") as file1, open(os.path.join(outputdir,outfile), "r") as file2:
    # Read the lines of each file
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()
    # Compare right-hand sides of the expressions by computing the difference between them
    num_diffs = 0
    for i in range(len(file1_lines)):
        expr_new = custom_parse_expr(file1_lines[i].split("=")[1].replace("sp.",""))
        expr_validated = custom_parse_expr(file2_lines[i].split("=")[1].replace("sp.",""))
        difference = sp.simplify(expr_new - expr_validated)
        if difference != 0:
            num_diffs += 1
            print(difference)
    if num_diffs == 0:
        print("No difference. TEST PASSED!")
    else:
        print("ERROR: Disagreement found with the trusted file. See differences above.")
        sys.exit(1)

# %% [markdown]
# <a id='latex_pdf_output'></a>
#
# # Step 11: Output this notebook to $\LaTeX$-formatted PDF file \[Back to [top](#toc)\]
# $$\label{latex_pdf_output}$$
#
# The following code cell converts this Jupyter notebook into a proper, clickable $\LaTeX$-formatted PDF file. After the cell is successfully run, the generated PDF may be found in the root NRPy+ tutorial directory, with filename
# [Tutorial-SEOBNR_Derivative_Routine.pdf](Tutorial-SEOBNR_Derivative_Routine.pdf) (Note that clicking on this link may not work; you may need to open the PDF file through another means.)

# %%
import cmdline_helper as cmd      # NRPy+: Multi-platform Python command-line interface

cmd.output_Jupyter_notebook_to_LaTeXed_PDF("Tutorial-SEOBNR_Derivative_Routine")
