# %%
# Step 1.a: import all needed modules from Python/NRPy+:
import sympy as sp                # SymPy: The Python computer algebra package upon which NRPy+ depends
import sys, os     # Standard Python modules for multiplatform OS-level functions
sys.path.append('../')

from outputC import superfast_uniq, lhrh      # Remove duplicate entries from a Python array; store left- and right-
                                              #   hand sides of mathematical expressions

# As of April 2021, "sp.sympify("Q+1")" fails because Q is a reserved keyword.
#   This is the workaround, courtesy Ken Sible.
custom_global_dict = {}
exec('from sympy import *', custom_global_dict)
del custom_global_dict['Q']

# Step 1.b: Check for a sufficiently new version of SymPy (for validation)
# Ignore the rc's and b's for release candidates & betas.
sympy_version = sp.__version__.replace('rc', '...').replace('b', '...')
sympy_version_decimal = float(int(sympy_version.split(".")[0]) + int(sympy_version.split(".")[1])/10.0)
if sympy_version_decimal > 1.2:
    custom_parse_expr = lambda expr: sp.parse_expr(expr, global_dict=custom_global_dict)
else:
    custom_parse_expr = lambda expr: sp.sympify(expr)

if sympy_version_decimal < 1.2:
    print('Error: NRPy+ does not support SymPy < 1.2')
    sys.exit(1)

# Step 1.c: Name of the directory containing the input file
inputdir = "Hamiltonian"

# %%
# Step 2.a: Read in expressions as a (single) string
with open(os.path.join(inputdir,'Sympy_Hreal_on_Bottom.txt'), 'r') as file:
    expressions_as_lines = file.readlines()

#print(expressions_as_lines)
# Step 2.b: Create and populate the "lr" array, which separates each line into left- and right-hand sides
#   Each entry is a string of the form lhrh(lhs='',rhs='')
lr = []

for i in range(len(expressions_as_lines)):
    # Ignore lines with 2 or fewer characters and those starting with #
    if len(expressions_as_lines[i]) > 2 and expressions_as_lines[i][0] != "#":
        # Split each line by its equals sign
        split_line = expressions_as_lines[i].split("=")
        #print(split_line)
        # Append the line to "lr", removing spaces, "sp." prefixes, and replacing Lambda->Lamb
        #   (Lambda is a protected keyword):
        lr.append(lhrh(lhs=split_line[0].replace(" ","").replace("Lambda","Lamb"),
                       rhs=split_line[1].replace(" ","").replace("sp.","").replace("Lambda","Lamb")))

# Step 2.c: Separate and sympify right- and left-hand sides into separate arrays
lhss = []
rhss = []
for i in range(len(lr)):
    #print(lr[i].rhs)
    lhss.append(custom_parse_expr(lr[i].lhs))
    rhss.append(custom_parse_expr(lr[i].rhs))

# %%
# Step 3.a: Create `input_constants` array and populate with SymPy symbols
m1,m2,tortoise,eta,EMgamma = sp.symbols('m1 m2 tortoise eta EMgamma',
                                                                real=True)
input_constants = [m1,m2,tortoise,eta,EMgamma]

# Step 3.b: Create `dynamic_variables` array and populate with SymPy symbols
#x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols("x y z p1 p2 p3 S1x S1y S1z S2x S2y S2z", real=True)
x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols("x y z p1 p2 p3 S1x S1y S1z S2x S2y S2z")
dynamic_variables = [x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z]

# %%
# Step 4.a: Prepare array of "free symbols" in the right-hand side expressions
full_symbol_list_with_dups = []
for i in range(len(lr)):
    for variable in rhss[i].free_symbols:
        full_symbol_list_with_dups.append(variable)

# Step 4.b: Remove duplicate free symbols
full_symbol_list = superfast_uniq(full_symbol_list_with_dups)

# Step 4.c: Remove input constants from symbol list
for inputconst in input_constants:
    for symbol in full_symbol_list:
        if str(symbol) == str(inputconst):
            full_symbol_list.remove(symbol)
for dynamic_variable in dynamic_variables:
    for symbol in full_symbol_list:
        if str(symbol) == str(dynamic_variable):
            full_symbol_list.remove(symbol)

# %%
# Step 5.b: Mark each free variable as a function with argument xx
full_function_list = []
for symb in full_symbol_list:
    func = sp.sympify(sp.Function(str(symb),real=True)(x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z))
    full_function_list.append(func)
    for i in range(len(rhss)):
        for var in rhss[i].free_symbols:
            if str(var) == str(symb):
                rhss[i] = rhss[i].subs(var,func)
# Out:
# x/sqrt(x**2 + y**2 + z**2)

# %%
# Step 6: Use SymPy's diff function to differentiate right-hand sides with respect to xx
#   and append "prm" notation to left-hand sides
lhss_deriv = []
rhss_deriv = []
for i in range(len(rhss)):
    for dynamic_variable in dynamic_variables:
        var = str(dynamic_variable)
        lhss_deriv.append(custom_parse_expr(str(lhss[i])+"prm"+var))
        newrhs = custom_parse_expr(str(sp.diff(rhss[i],dynamic_variable)).replace("(x, y, z, p1, p2, p3, S1x, S1y, S1z, S2x, S2y, S2z)","").replace(", "+var+")","prm"+var).replace("Derivative(",""))
        rhss_deriv.append(newrhs)

# %%
# Step 7.a: Define derivative simplification function
def simplify_deriv(lhss_deriv,rhss_deriv):
    # Copy expressions into another array
    lhss_deriv_simp = []
    rhss_deriv_simp = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_simp.append(lhss_deriv[i])
        rhss_deriv_simp.append(rhss_deriv[i])
    # If a right-hand side is 0, substitute value 0 for the corresponding left-hand side in later terms
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == 0:
            for j in range(i+1,len(rhss_deriv_simp)):
                for var in rhss_deriv_simp[j].free_symbols:
                    if str(var) == str(lhss_deriv_simp[i]):
                        rhss_deriv_simp[j] = rhss_deriv_simp[j].subs(var,0)
    zero_elements_to_remove = []
    # Create array of indices for expressions that are zero
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == sp.sympify(0):
            zero_elements_to_remove.append(i)
    # When removing terms that are zero, we need to take into account their new index (after each removal)
    count = 0
    for i in range(len(zero_elements_to_remove)):
        del lhss_deriv_simp[zero_elements_to_remove[i]+count]
        del rhss_deriv_simp[zero_elements_to_remove[i]+count]
        count -= 1
    return lhss_deriv_simp,rhss_deriv_simp

# Step 7.b: Call the simplication function and then copy results
lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv,rhss_deriv)
lhss_deriv = lhss_deriv_simp
rhss_deriv = rhss_deriv_simp

# %%
# Step 9: Output original expression and each partial derivative expression in SymPy snytax
outputdir = "Derivatives"
with open(os.path.join(outputdir,'partial_derivatives.txt-VALIDATION'), 'w') as output:
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(")
        output.write(str(lr[i].lhs)+" = "+right_side_in_sp)
    for i in range(len(lhss_deriv)):
            right_side = str(rhss_deriv[i])
            right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
                                                "_prm")
            output.write(str(lhss_deriv[i]).replace("prm","_prm")+" = "+right_side_in_sp+"\n")

# %%
# Step 10: Create Numpy function to output exact derivatives for all 12 dynamical variables

with open(os.path.join(outputdir,'hamiltonian_first_derivatives.py'),"w") as file:
    file.write("""from __future__ import division
import numpy as np
def ham_first_derivs(m1, m2, tortoise, x, y, z, p1, p2, p3, S1x, S1y, S1z, S2x, S2y, S2z):
""")
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_np = right_side.replace("sqrt(","np.sqrt(").replace("log(","np.log(").replace("pi",
                                                "np.pi").replace("sign(","np.sign(").replace("Abs(",
                                                "np.abs(").replace("Rational(","np.true_divide(")
        file.write("    " + lr[i].lhs + " = " + right_side_in_np)
    for i in range(len(lhss_deriv)):
        right_side = str(rhss_deriv[i])
        right_side_in_np = right_side.replace("sqrt(","np.sqrt(").replace("log(","np.log(").replace("pi",
                                                "np.pi").replace("sign(","np.sign(").replace("Abs(",
                                                "np.abs(").replace("Rational(","np.true_divide(").replace("prm",
                                                "_prm")
        file.write("    " + str(lhss_deriv[i]).replace("prm", "_prm") + " = " + right_side_in_np + "\n")
    file.write("    return np.array([Hreal_prmx, Hreal_prmy, Hreal_prmz, Hreal_prmp1, Hreal_prmp2, Hreal_prmp3, Hreal_prmS1x, Hreal_prmS1y, Hreal_prmS1z, Hreal_prmS2x, Hreal_prmS2y, Hreal_prmS2z])\n")

# %%
## Validate against LALSuite
import numpy as np
from Derivatives.hamiltonian_first_derivatives import ham_first_derivs as dH

for index in range(3):
    validationfile = 'outputv4Pindex'+str(index)+'.txt'
    validationfile_pert = 'outputv4Pindex'+str(index)+'pert.txt'
    with open(os.path.join(outputdir,validationfile)) as datfile, open(os.path.join(outputdir,validationfile_pert)) as pertdatfile:
        data_lines = datfile.readlines()
        pertdata_lines = pertdatfile.readlines()
        for i in range(len(pertdata_lines)//3):
            valuepairs = data_lines[3*i].strip('{}\n').split(',')
            valuepairspert = pertdata_lines[3*i].strip('{}\n').split(',')
            derivpairs = data_lines[3*i+1].strip('{}\n').split(',')
            derivpairspert = pertdata_lines[3*i+1].strip('{}\n').split(',')
            values = dict()
            derivs = dict()
            valuespert = dict()
            derivspert = dict()
            for j in range(len(valuepairs)):
                pair = valuepairs[j].split(': ')
                pairpert = valuepairspert[j].split(': ')
                values[pair[0].strip(" ''")] = float(pair[1])
                valuespert[pairpert[0].strip(" ''")] = float(pairpert[1])
            for j in range(len(derivpairs)):
                pair = derivpairs[j].split(': ')
                pairpert = derivpairspert[j].split(': ')
                derivs[pair[0].strip(" ''")] = float(pair[1])
                derivspert[pairpert[0].strip(" ''")] = float(pairpert[1])
            
            m1 , m2 = values['m1'], values['m2']
            eta = m1*m2/(m1 + m2)/(m1 + m2)
            
            nrpy_derivs = dH(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            for j in range(len(dynamic_variables)):
                var = str(dynamic_variables[j])
                Erel = np.abs((nrpy_derivs[j]/eta - derivs['dHreal_d'+var])/derivs['dHreal_d'+var])
                Erelpert = np.abs((derivs['dHreal_d'+var]-derivspert['dHreal_d'+var])/derivs['dHreal_d'+var])
                print("In line %d: Erel in %s derivative is %.2e, allowed is %.2e"%(i,var,Erel,Erelpert))
# Out:
# In line 0: Erel in x derivative is 1.11e-10, allowed is 5.26e-10
# In line 0: Erel in y derivative is 1.33e-03, allowed is 2.11e-05
# In line 0: Erel in z derivative is 1.53e+03, allowed is 1.01e-07
# In line 0: Erel in p1 derivative is 1.85e-01, allowed is 0.00e+00
# In line 0: Erel in p2 derivative is 4.32e-11, allowed is 7.60e-11
# In line 0: Erel in p3 derivative is 6.26e-09, allowed is 2.79e-09
# In line 0: Erel in S1x derivative is 2.35e-07, allowed is 2.49e-07
# In line 0: Erel in S1y derivative is 1.19e-06, allowed is 4.73e-08
# In line 0: Erel in S1z derivative is 8.51e-10, allowed is 9.84e-10
# In line 0: Erel in S2x derivative is 1.26e-07, allowed is 6.32e-08
# In line 0: Erel in S2y derivative is 1.77e-06, allowed is 1.57e-06
# In line 0: Erel in S2z derivative is 2.44e-09, allowed is 2.52e-09
# In line 1: Erel in x derivative is 3.16e-10, allowed is 1.56e-10
# In line 1: Erel in y derivative is 1.46e-03, allowed is 1.48e-04
# In line 1: Erel in z derivative is 1.53e+03, allowed is 7.09e-07
# In line 1: Erel in p1 derivative is 1.85e-01, allowed is 1.22e-04
# In line 1: Erel in p2 derivative is 2.47e-11, allowed is 2.57e-12
# In line 1: Erel in p3 derivative is 2.17e-09, allowed is 5.97e-09
# In line 1: Erel in S1x derivative is 8.12e-08, allowed is 3.24e-07
# In line 1: Erel in S1y derivative is 1.20e-06, allowed is 1.58e-07
# In line 1: Erel in S1z derivative is 1.26e-11, allowed is 7.50e-10
# In line 1: Erel in S2x derivative is 2.74e-07, allowed is 5.06e-07
# In line 1: Erel in S2y derivative is 1.92e-07, allowed is 1.57e-06
# In line 1: Erel in S2z derivative is 9.99e-10, allowed is 2.52e-09
# In line 2: Erel in x derivative is 2.40e-10, allowed is 4.25e-11
# In line 2: Erel in y derivative is 1.33e-03, allowed is 2.11e-05
# In line 2: Erel in z derivative is 1.53e+03, allowed is 8.10e-07
# In line 2: Erel in p1 derivative is 1.85e-01, allowed is 0.00e+00
# In line 2: Erel in p2 derivative is 5.63e-11, allowed is 1.31e-10
# In line 2: Erel in p3 derivative is 4.94e-09, allowed is 7.55e-09
# In line 2: Erel in S1x derivative is 2.47e-09, allowed is 2.61e-07
# In line 2: Erel in S1y derivative is 1.21e-06, allowed is 7.44e-08
# In line 2: Erel in S1z derivative is 6.56e-10, allowed is 1.31e-10
# In line 2: Erel in S2x derivative is 1.91e-07, allowed is 6.32e-08
# In line 2: Erel in S2y derivative is 1.76e-06, allowed is 1.44e-15
# In line 2: Erel in S2z derivative is 5.89e-10, allowed is 3.15e-10
# In line 3: Erel in x derivative is 6.06e-10, allowed is 3.52e-10
# In line 3: Erel in y derivative is 1.31e-03, allowed is 0.00e+00
# In line 3: Erel in z derivative is 1.53e+03, allowed is 7.09e-07
# In line 3: Erel in p1 derivative is 1.85e-01, allowed is 1.22e-04
# In line 3: Erel in p2 derivative is 9.82e-11, allowed is 9.63e-12
# In line 3: Erel in p3 derivative is 2.66e-09, allowed is 1.27e-09
# In line 3: Erel in S1x derivative is 3.94e-07, allowed is 5.74e-07
# In line 3: Erel in S1y derivative is 1.24e-06, allowed is 6.96e-08
# In line 3: Erel in S1z derivative is 1.63e-09, allowed is 2.55e-09
# In line 3: Erel in S2x derivative is 3.80e-07, allowed is 5.69e-07
# In line 3: Erel in S2y derivative is 1.81e-06, allowed is 1.37e-06
# In line 3: Erel in S2z derivative is 7.72e-11, allowed is 2.84e-09
# In line 4: Erel in x derivative is 1.09e-10, allowed is 1.41e-01
# In line 4: Erel in y derivative is 1.05e-03, allowed is 1.77e-01
# In line 4: Erel in z derivative is 3.44e+03, allowed is 1.47e-01
# In line 4: Erel in p1 derivative is 1.44e-01, allowed is 1.52e-01
# In line 4: Erel in p2 derivative is 6.93e-11, allowed is 7.24e-02
# In line 4: Erel in p3 derivative is 6.57e-09, allowed is 5.72e-01
# In line 4: Erel in S1x derivative is 3.79e-07, allowed is 3.04e-01
# In line 4: Erel in S1y derivative is 1.15e-05, allowed is 1.49e+01
# In line 4: Erel in S1z derivative is 3.99e-10, allowed is 7.72e-02
# In line 4: Erel in S2x derivative is 2.07e-07, allowed is 2.41e-01
# In line 4: Erel in S2y derivative is 3.47e-06, allowed is 6.49e-01
# In line 4: Erel in S2z derivative is 1.16e-09, allowed is 7.87e-02
# In line 5: Erel in x derivative is 1.86e-11, allowed is 7.61e-02
# In line 5: Erel in y derivative is 1.54e-03, allowed is 1.04e-01
# In line 5: Erel in z derivative is 2.35e+03, allowed is 7.01e-02
# In line 5: Erel in p1 derivative is 1.62e-01, allowed is 7.28e-02
# In line 5: Erel in p2 derivative is 3.25e-11, allowed is 4.68e-02
# In line 5: Erel in p3 derivative is 8.40e-10, allowed is 1.55e-01
# In line 5: Erel in S1x derivative is 3.68e-07, allowed is 1.49e-01
# In line 5: Erel in S1y derivative is 2.58e-06, allowed is 3.62e-01
# In line 5: Erel in S1z derivative is 4.87e-10, allowed is 3.18e-02
# In line 5: Erel in S2x derivative is 3.19e-07, allowed is 1.27e-01
# In line 5: Erel in S2y derivative is 1.90e-06, allowed is 1.06e+00
# In line 5: Erel in S2z derivative is 2.24e-09, allowed is 3.26e-02
# In line 9: Erel in S1x derivative is 5.43e-07, allowed is 3.04e-01
# In line 9: Erel in S1y derivative is 3.80e-05, allowed is 1.49e+01
# In line 9: Erel in S1z derivative is 5.45e-10, allowed is 7.72e-02
# In line 9: Erel in S2x derivative is 9.84e-07, allowed is 2.41e-01
# In line 9: Erel in S2y derivative is 2.89e-06, allowed is 6.49e-01
# In line 9: Erel in S2z derivative is 3.86e-09, allowed is 7.87e-02
# In line 10: Erel in x derivative is 1.05e-10, allowed is 7.61e-02
# In line 10: Erel in y derivative is 1.29e-03, allowed is 1.04e-01
# In line 10: Erel in z derivative is 2.35e+03, allowed is 7.01e-02
# In line 10: Erel in p1 derivative is 1.62e-01, allowed is 7.31e-02
# In line 10: Erel in p2 derivative is 1.38e-10, allowed is 4.68e-02
# In line 10: Erel in p3 derivative is 7.44e-09, allowed is 1.55e-01
# In line 10: Erel in S1x derivative is 2.05e-07, allowed is 1.49e-01
# In line 10: Erel in S1y derivative is 7.92e-07, allowed is 3.62e-01
# In line 10: Erel in S1z derivative is 1.16e-09, allowed is 3.18e-02
# In line 10: Erel in S2x derivative is 3.19e-07, allowed is 1.27e-01
# In line 10: Erel in S2y derivative is 9.47e-06, allowed is 1.06e+00
# In line 10: Erel in S2z derivative is 2.21e-09, allowed is 3.26e-02
# In line 11: Erel in x derivative is 5.23e-10, allowed is 4.10e-02
# In line 11: Erel in y derivative is 1.39e-03, allowed is 5.98e-02
# In line 11: Erel in z derivative is 1.91e+03, allowed is 3.61e-02
# In line 11: Erel in p1 derivative is 1.73e-01, allowed is 3.74e-02
# In line 11: Erel in p2 derivative is 6.48e-11, allowed is 2.61e-02
# In line 11: Erel in p3 derivative is 4.52e-09, allowed is 6.32e-02
# In line 11: Erel in S1x derivative is 1.79e-07, allowed is 7.67e-02
# In line 11: Erel in S1y derivative is 1.50e-06, allowed is 1.41e-01
# In line 11: Erel in S1z derivative is 2.40e-10, allowed is 1.55e-02
# In line 11: Erel in S2x derivative is 2.61e-08, allowed is 6.75e-02
# In line 11: Erel in S2y derivative is 5.33e-06, allowed is 2.31e-01
# In line 11: Erel in S2z derivative is 1.83e-09, allowed is 1.58e-02
# In line 12: Erel in x derivative is 2.82e-10, allowed is 1.04e-01
# In line 12: Erel in y derivative is 1.52e-03, allowed is 1.32e-01
# In line 12: Erel in z derivative is 2.86e+03, allowed is 9.71e-02
# In line 12: Erel in p1 derivative is 1.53e-01, allowed is 1.02e-01
# In line 12: Erel in p2 derivative is 7.24e-12, allowed is 6.45e-02
# In line 12: Erel in p3 derivative is 7.46e-09, allowed is 3.00e-01
# In line 12: Erel in S1x derivative is 4.75e-07, allowed is 2.18e-01
# In line 12: Erel in S1y derivative is 1.55e-06, allowed is 9.07e-01
# In line 12: Erel in S1z derivative is 3.62e-10, allowed is 4.47e-02
# In line 12: Erel in S2x derivative is 2.10e-07, allowed is 1.78e-01
# In line 12: Erel in S2y derivative is 5.60e-06, allowed is 2.11e+00
# In line 12: Erel in S2z derivative is 8.86e-10, allowed is 4.59e-02
# In line 13: Erel in x derivative is 1.60e-10, allowed is 7.43e-02
# In line 20: Erel in y derivative is 7.47e-04, allowed is 7.78e-03
# In line 20: Erel in z derivative is 1.65e+03, allowed is 1.19e-03
# In line 20: Erel in p1 derivative is 1.84e-01, allowed is 1.09e-03
# In line 20: Erel in p2 derivative is 7.64e-11, allowed is 5.60e-04
# In line 20: Erel in p3 derivative is 8.19e-10, allowed is 9.01e-01
# In line 20: Erel in S1x derivative is 2.52e-07, allowed is 2.09e-03
# In line 20: Erel in S1y derivative is 2.82e-06, allowed is 2.42e-02
# In line 20: Erel in S1z derivative is 5.62e-10, allowed is 6.00e-04
# In line 20: Erel in S2x derivative is 2.02e-07, allowed is 1.90e-03
# In line 20: Erel in S2y derivative is 7.66e-07, allowed is 1.64e-02
# In line 20: Erel in S2z derivative is 1.83e-09, allowed is 6.06e-04
# In line 21: Erel in x derivative is 5.37e-10, allowed is 3.89e-05
# In line 21: Erel in y derivative is 6.66e-04, allowed is 3.85e-04
# In line 21: Erel in z derivative is 1.65e+03, allowed is 7.92e-05
# In line 21: Erel in p1 derivative is 1.84e-01, allowed is 8.60e-05
# In line 21: Erel in p2 derivative is 9.70e-11, allowed is 2.25e-05
# In line 21: Erel in p3 derivative is 3.81e-07, allowed is 6.26e-01
# In line 21: Erel in S1x derivative is 4.96e-07, allowed is 5.04e-05
# In line 21: Erel in S1y derivative is 9.63e-07, allowed is 1.22e-03
# In line 21: Erel in S1z derivative is 7.92e-10, allowed is 6.11e-05
# In line 21: Erel in S2x derivative is 9.50e-08, allowed is 5.36e-05
# In line 21: Erel in S2y derivative is 7.58e-07, allowed is 8.04e-04
# In line 21: Erel in S2z derivative is 3.02e-09, allowed is 6.06e-05
# In line 22: Erel in x derivative is 1.65e-10, allowed is 6.51e-06
# In line 22: Erel in y derivative is 7.08e-04, allowed is 0.00e+00
# In line 22: Erel in z derivative is 1.65e+03, allowed is 7.98e-06
# In line 22: Erel in p1 derivative is 1.84e-01, allowed is 0.00e+00
# In line 22: Erel in p2 derivative is 1.54e-10, allowed is 1.89e-06
# In line 22: Erel in p3 derivative is 4.75e-05, allowed is 1.24e+00
# In line 22: Erel in S1x derivative is 3.89e-08, allowed is 1.09e-05
# In line 22: Erel in S1y derivative is 1.63e-06, allowed is 4.70e-05
# In line 22: Erel in S1z derivative is 1.39e-09, allowed is 4.54e-06
# In line 22: Erel in S2x derivative is 1.49e-07, allowed is 9.97e-06
# In line 22: Erel in S2y derivative is 4.36e-07, allowed is 3.31e-05
# In line 22: Erel in S2z derivative is 6.24e-10, allowed is 4.55e-06
# In line 23: Erel in x derivative is 1.04e-10, allowed is 4.46e-07
# In line 23: Erel in y derivative is 6.99e-04, allowed is 6.24e-05
# In line 23: Erel in z derivative is 1.65e+03, allowed is 1.33e-06
# In line 23: Erel in p1 derivative is 1.84e-01, allowed is 1.00e-04
# In line 23: Erel in p2 derivative is 7.13e-11, allowed is 6.44e-08
# In line 23: Erel in p3 derivative is 2.78e-04, allowed is 1.00e+00
# In line 23: Erel in S1x derivative is 4.96e-08, allowed is 4.81e-07
# In line 23: Erel in S1y derivative is 1.50e-06, allowed is 2.74e-06
# In line 23: Erel in S1z derivative is 1.76e-10, allowed is 3.77e-07
# In line 23: Erel in S2x derivative is 1.50e-07, allowed is 7.72e-07
# In line 23: Erel in S2y derivative is 1.11e-06, allowed is 2.15e-06
# In line 23: Erel in S2z derivative is 1.48e-09, allowed is 3.75e-07
# In line 24: Erel in x derivative is 1.96e-10, allowed is 2.96e-04
# In line 24: Erel in y derivative is 6.90e-04, allowed is 5.49e-02
# In line 24: Erel in z derivative is 1.65e+03, allowed is 5.63e-04
# In line 24: Erel in p1 derivative is 1.84e-01, allowed is 5.01e-04
# In line 24: Erel in p2 derivative is 3.18e-11, allowed is 1.26e-04
# In line 24: Erel in p3 derivative is 5.45e-02, allowed is 9.64e+06
# In line 24: Erel in S1x derivative is 1.53e-07, allowed is 4.04e-04
# In line 24: Erel in S1y derivative is 1.67e-06, allowed is 2.38e-01
# In line 24: Erel in S1z derivative is 1.14e-09, allowed is 4.20e-04
# In line 24: Erel in S2x derivative is 7.45e-09, allowed is 4.18e-04
# In line 24: Erel in S2y derivative is 1.08e-06, allowed is 1.53e-01
# In line 24: Erel in S2z derivative is 4.05e-10, allowed is 4.18e-04
# In line 25: Erel in x derivative is 3.80e-10, allowed is 5.91e-04
# In line 25: Erel in y derivative is 7.77e-04, allowed is 1.13e-03
# In line 25: Erel in z derivative is 1.65e+03, allowed is 1.12e-03
# In line 25: Erel in p1 derivative is 1.84e-01, allowed is 1.10e-03
# In line 25: Erel in p2 derivative is 5.17e-11, allowed is 2.53e-04
# In line 25: Erel in p3 derivative is 2.02e-08, allowed is 5.53e-04
# In line 25: Erel in S1x derivative is 3.16e-08, allowed is 8.09e-04
# In line 25: Erel in S1y derivative is 1.21e-06, allowed is 7.60e-04
# In line 25: Erel in S1z derivative is 1.04e-09, allowed is 8.38e-04
# In line 25: Erel in S2x derivative is 4.33e-07, allowed is 8.35e-04
# In line 25: Erel in S2y derivative is 1.54e-06, allowed is 8.14e-04
# In line 25: Erel in S2z derivative is 1.60e-09, allowed is 8.32e-04
# In line 26: Erel in x derivative is 2.78e-10, allowed is 4.44e-04
# In line 26: Erel in y derivative is 8.15e-04, allowed is 9.58e-04
# In line 26: Erel in z derivative is 1.65e+03, allowed is 8.38e-04
# In line 26: Erel in p1 derivative is 1.84e-01, allowed is 9.75e-04
# In line 26: Erel in p2 derivative is 8.09e-11, allowed is 1.89e-04
# In line 26: Erel in p3 derivative is 1.56e-08, allowed is 4.15e-04
# In line 26: Erel in S1x derivative is 1.88e-07, allowed is 6.07e-04
# In line 26: Erel in S1y derivative is 1.18e-06, allowed is 5.72e-04
# In line 26: Erel in S1z derivative is 2.27e-10, allowed is 6.29e-04
# In line 26: Erel in S2x derivative is 5.69e-08, allowed is 6.27e-04
# In line 26: Erel in S2y derivative is 9.30e-07, allowed is 6.11e-04
# In line 26: Erel in S2z derivative is 2.94e-09, allowed is 6.24e-04
# In line 27: Erel in x derivative is 2.58e-10, allowed is 2.96e-04
# In line 27: Erel in y derivative is 8.44e-04, allowed is 4.40e-04
# In line 37: Erel in S2x derivative is 5.34e-07, allowed is 2.32e-05
# In line 37: Erel in S2y derivative is 1.01e-07, allowed is 2.14e-05
# In line 37: Erel in S2z derivative is 1.39e-09, allowed is 2.29e-05
# In line 38: Erel in x derivative is 4.54e-10, allowed is 1.05e-05
# In line 38: Erel in y derivative is 7.38e-04, allowed is 1.10e-05
# In line 38: Erel in z derivative is 1.65e+03, allowed is 1.93e-05
# In line 38: Erel in p1 derivative is 1.84e-01, allowed is 1.29e-04
# In line 38: Erel in p2 derivative is 6.51e-11, allowed is 4.47e-06
# In line 38: Erel in p3 derivative is 6.10e-09, allowed is 9.78e-06
# In line 38: Erel in S1x derivative is 4.40e-08, allowed is 1.47e-05
# In line 38: Erel in S1y derivative is 2.19e-06, allowed is 1.43e-05
# In line 38: Erel in S1z derivative is 1.24e-09, allowed is 1.48e-05
# In line 38: Erel in S2x derivative is 3.41e-08, allowed is 1.47e-05
# In line 38: Erel in S2y derivative is 1.85e-06, allowed is 1.30e-05
# In line 38: Erel in S2z derivative is 3.19e-09, allowed is 1.47e-05
# In line 39: Erel in x derivative is 5.32e-10, allowed is 8.15e-06
# In line 39: Erel in y derivative is 7.50e-04, allowed is 8.81e-05
# In line 39: Erel in z derivative is 1.65e+03, allowed is 1.54e-05
# In line 39: Erel in p1 derivative is 1.84e-01, allowed is 1.43e-05
# In line 39: Erel in p2 derivative is 8.42e-11, allowed is 3.48e-06
# In line 39: Erel in p3 derivative is 3.42e-09, allowed is 7.61e-06
# In line 39: Erel in S1x derivative is 1.71e-07, allowed is 1.13e-05
# In line 39: Erel in S1y derivative is 9.05e-07, allowed is 9.42e-06
# In line 39: Erel in S1z derivative is 7.43e-10, allowed is 1.15e-05
# In line 39: Erel in S2x derivative is 1.87e-07, allowed is 1.07e-05
# In line 39: Erel in S2y derivative is 1.07e-06, allowed is 1.16e-05
# In line 39: Erel in S2z derivative is 1.09e-09, allowed is 1.15e-05
# In line 40: Erel in x derivative is 1.37e-10, allowed is 2.31e-06
# In line 40: Erel in y derivative is 7.42e-04, allowed is 1.10e-05
# In line 40: Erel in z derivative is 1.65e+03, allowed is 5.51e-06
# In line 40: Erel in p1 derivative is 1.84e-01, allowed is 1.00e-04
# In line 40: Erel in p2 derivative is 2.00e-11, allowed is 9.88e-07
# In line 40: Erel in p3 derivative is 2.15e-08, allowed is 2.13e-06
# In line 40: Erel in S1x derivative is 3.90e-07, allowed is 2.47e-06
# In line 40: Erel in S1y derivative is 1.82e-06, allowed is 3.79e-06
# In line 40: Erel in S1z derivative is 1.01e-09, allowed is 3.28e-06
# In line 40: Erel in S2x derivative is 3.42e-07, allowed is 3.54e-06
# In line 40: Erel in S2y derivative is 9.88e-07, allowed is 4.12e-06
# In line 40: Erel in S2z derivative is 9.88e-10, allowed is 3.25e-06
# In line 41: Erel in x derivative is 1.96e-10, allowed is 1.37e-06
# In line 41: Erel in y derivative is 7.57e-04, allowed is 1.51e+02
# In line 41: Erel in z derivative is 1.65e+03, allowed is 7.29e-03
# In line 41: Erel in p1 derivative is 1.84e-01, allowed is 1.99e+05
# In line 41: Erel in p2 derivative is 2.84e-11, allowed is 6.32e-07
# In line 41: Erel in p3 derivative is 9.50e-09, allowed is 6.51e-07
# In line 41: Erel in S1x derivative is 1.53e-07, allowed is 3.81e-05
# In line 41: Erel in S1y derivative is 2.36e-06, allowed is 1.84e-04
# In line 41: Erel in S1z derivative is 8.63e-10, allowed is 7.15e-07
# In line 41: Erel in S2x derivative is 7.45e-09, allowed is 9.03e-05
# In line 41: Erel in S2y derivative is 9.74e-07, allowed is 5.26e-05
# In line 41: Erel in S2z derivative is 1.14e-09, allowed is 8.85e-07
# In line 42: Erel in x derivative is 1.18e-06, allowed is 1.22e-06
# In line 42: Erel in y derivative is 1.66e+00, allowed is 1.33e+00
# In line 42: Erel in z derivative is 1.64e+03, allowed is 9.45e-03
# In line 42: Erel in p1 derivative is 3.34e-01, allowed is 1.33e+00
# In line 42: Erel in p2 derivative is 2.12e-07, allowed is 6.90e-07
# In line 42: Erel in p3 derivative is 2.44e-07, allowed is 1.00e+00
# In line 42: Erel in S1x derivative is 5.71e-06, allowed is 5.11e-05
# In line 42: Erel in S1y derivative is 3.06e-05, allowed is 3.13e-01
# In line 42: Erel in S1z derivative is 2.33e-07, allowed is 3.19e-07
# In line 42: Erel in S2x derivative is 1.60e-05, allowed is 1.21e-04
# In line 42: Erel in S2y derivative is 8.60e-06, allowed is 1.81e-01
# In line 42: Erel in S2z derivative is 2.92e-07, allowed is 7.54e-07
# In line 43: Erel in x derivative is 1.32e-07, allowed is 1.35e-06
# In line 43: Erel in y derivative is 1.71e+00, allowed is 6.89e+00
# In line 43: Erel in z derivative is 1.65e+03, allowed is 1.42e-03
# In line 43: Erel in p1 derivative is 3.34e-01, allowed is 6.07e-01
# In line 43: Erel in p2 derivative is 2.36e-08, allowed is 7.80e-07
# In line 43: Erel in p3 derivative is 3.14e-02, allowed is 7.49e+03
# In line 43: Erel in S1x derivative is 2.28e-06, allowed is 1.93e-03
# In line 43: Erel in S1y derivative is 9.72e-06, allowed is 2.00e-03
# In line 43: Erel in S1z derivative is 2.59e-08, allowed is 3.11e-06
# In line 43: Erel in S2x derivative is 5.40e-06, allowed is 2.07e-03
# In line 43: Erel in S2y derivative is 3.32e-06, allowed is 1.76e-03
# In line 43: Erel in S2z derivative is 3.09e-08, allowed is 3.08e-06
# In line 44: Erel in x derivative is 9.66e-08, allowed is 1.72e-06
# In line 44: Erel in y derivative is 2.16e-01, allowed is 4.37e-01
# In line 44: Erel in z derivative is 1.65e+03, allowed is 7.13e-04
# In line 44: Erel in p1 derivative is 2.08e-01, allowed is 1.89e-01
# In line 44: Erel in p2 derivative is 5.30e-07, allowed is 1.41e-06
# In line 44: Erel in p3 derivative is 8.25e-06, allowed is 5.00e-01
# In line 44: Erel in S1x derivative is 2.98e-06, allowed is 9.64e-04
# In line 44: Erel in S1y derivative is 9.02e-06, allowed is 9.98e-04
# In line 44: Erel in S1z derivative is 2.53e-08, allowed is 2.25e-06
# In line 44: Erel in S2x derivative is 5.74e-06, allowed is 1.04e-03
# In line 3: Erel in p2 derivative is 3.26e-11, allowed is 3.62e-11
# In line 3: Erel in p3 derivative is 3.45e-09, allowed is 1.42e-09
# In line 3: Erel in S1x derivative is 4.80e-07, allowed is 6.32e-16
# In line 3: Erel in S1y derivative is 1.86e-07, allowed is 2.36e-08
# In line 3: Erel in S1z derivative is 2.37e-08, allowed is 1.60e-10
# In line 3: Erel in S2x derivative is 5.36e-07, allowed is 7.96e-07
# In line 3: Erel in S2y derivative is 1.12e-07, allowed is 6.09e-07
# In line 3: Erel in S2z derivative is 5.05e-09, allowed is 2.14e-09
# In line 4: Erel in x derivative is 3.55e-10, allowed is 5.00e-03
# In line 4: Erel in y derivative is 2.40e-03, allowed is 9.41e-02
# In line 4: Erel in z derivative is 1.24e+04, allowed is 5.90e-03
# In line 4: Erel in p1 derivative is 1.07e-01, allowed is 1.71e-01
# In line 4: Erel in p2 derivative is 2.99e-11, allowed is 1.48e-03
# In line 4: Erel in p3 derivative is 1.11e-08, allowed is 8.20e-02
# In line 4: Erel in S1x derivative is 6.04e-07, allowed is 3.77e-03
# In line 4: Erel in S1y derivative is 1.14e-06, allowed is 8.74e-02
# In line 4: Erel in S1z derivative is 5.32e-09, allowed is 3.47e-03
# In line 4: Erel in S2x derivative is 3.77e-05, allowed is 1.36e-01
# In line 4: Erel in S2y derivative is 1.21e-05, allowed is 8.74e-02
# In line 4: Erel in S2z derivative is 3.33e-09, allowed is 3.50e-03
# In line 5: Erel in x derivative is 1.44e-10, allowed is 2.39e-03
# In line 5: Erel in y derivative is 1.80e-04, allowed is 9.36e-03
# In line 5: Erel in z derivative is 7.60e+03, allowed is 2.37e-03
# In line 5: Erel in p1 derivative is 1.58e-01, allowed is 1.16e-02
# In line 5: Erel in p2 derivative is 7.81e-11, allowed is 1.15e-03
# In line 5: Erel in p3 derivative is 4.43e-09, allowed is 5.75e-03
# In line 5: Erel in S1x derivative is 1.56e-07, allowed is 1.64e-02
# In line 5: Erel in S1y derivative is 2.77e-07, allowed is 8.14e-03
# In line 5: Erel in S1z derivative is 1.12e-08, allowed is 1.22e-03
# In line 5: Erel in S2x derivative is 2.16e-07, allowed is 8.61e-03
# In line 5: Erel in S2y derivative is 4.91e-07, allowed is 8.15e-03
# In line 5: Erel in S2z derivative is 9.95e-10, allowed is 1.23e-03
# In line 6: Erel in x derivative is 4.26e-10, allowed is 1.67e-16
# In line 6: Erel in y derivative is 4.61e-05, allowed is 0.00e+00
# In line 6: Erel in z derivative is 4.31e+03, allowed is 5.70e-07
# In line 6: Erel in p1 derivative is 1.95e-01, allowed is 0.00e+00
# In line 6: Erel in p2 derivative is 1.47e-10, allowed is 5.59e-11
# In line 6: Erel in p3 derivative is 3.77e-10, allowed is 4.65e-16
# In line 6: Erel in S1x derivative is 4.06e-07, allowed is 6.32e-16
# In line 6: Erel in S1y derivative is 4.48e-08, allowed is 2.12e-07
# In line 6: Erel in S1z derivative is 2.25e-08, allowed is 1.11e-15
# In line 6: Erel in S2x derivative is 2.13e-07, allowed is 1.49e-15
# In line 6: Erel in S2y derivative is 7.01e-08, allowed is 6.09e-07
# In line 6: Erel in S2z derivative is 6.13e-09, allowed is 1.61e-15
# In line 7: Erel in x derivative is 3.77e-11, allowed is 1.32e-10
# In line 7: Erel in y derivative is 8.11e-05, allowed is 0.00e+00
# In line 7: Erel in z derivative is 4.31e+03, allowed is 4.99e-07
# In line 7: Erel in p1 derivative is 1.94e-01, allowed is 5.89e-04
# In line 7: Erel in p2 derivative is 1.81e-11, allowed is 8.90e-11
# In line 7: Erel in p3 derivative is 3.54e-09, allowed is 2.96e-09
# In line 7: Erel in S1x derivative is 1.49e-07, allowed is 1.15e-06
# In line 7: Erel in S1y derivative is 1.79e-08, allowed is 5.51e-16
# In line 7: Erel in S1z derivative is 2.23e-08, allowed is 1.05e-09
# In line 7: Erel in S2x derivative is 5.49e-07, allowed is 1.49e-15
# In line 7: Erel in S2y derivative is 2.90e-08, allowed is 1.52e-15
# In line 7: Erel in S2z derivative is 7.53e-09, allowed is 1.46e-15
# In line 8: Erel in x derivative is 2.43e-10, allowed is 3.41e-10
# In line 8: Erel in y derivative is 8.11e-05, allowed is 1.59e-05
# In line 8: Erel in z derivative is 4.31e+03, allowed is 0.00e+00
# In line 8: Erel in p1 derivative is 1.91e-01, allowed is 0.00e+00
# In line 8: Erel in p2 derivative is 3.26e-11, allowed is 3.62e-11
# In line 8: Erel in p3 derivative is 3.45e-09, allowed is 1.42e-09
# In line 8: Erel in S1x derivative is 4.80e-07, allowed is 6.32e-16
# In line 8: Erel in S1y derivative is 1.86e-07, allowed is 2.36e-08
# In line 8: Erel in S1z derivative is 2.37e-08, allowed is 1.60e-10
# In line 8: Erel in S2x derivative is 5.36e-07, allowed is 7.96e-07
# In line 8: Erel in S2y derivative is 1.12e-07, allowed is 6.09e-07
# In line 8: Erel in S2z derivative is 5.05e-09, allowed is 2.14e-09
# In line 9: Erel in x derivative is 1.38e-10, allowed is 5.00e-03
# In line 9: Erel in y derivative is 2.40e-03, allowed is 9.35e-02
# In line 9: Erel in z derivative is 1.24e+04, allowed is 5.90e-03
# In line 9: Erel in p1 derivative is 1.49e-01, allowed is 6.98e-02
# In line 9: Erel in p2 derivative is 3.72e-11, allowed is 1.48e-03
# In line 9: Erel in p3 derivative is 2.78e-08, allowed is 8.20e-02
# In line 9: Erel in S1x derivative is 3.76e-08, allowed is 3.78e-03
# In line 9: Erel in S1y derivative is 1.14e-06, allowed is 8.74e-02
# In line 9: Erel in S1z derivative is 6.47e-09, allowed is 3.47e-03
# In line 9: Erel in S2x derivative is 3.66e-06, allowed is 1.36e-01
# In line 9: Erel in S2y derivative is 1.21e-05, allowed is 8.74e-02
# In line 9: Erel in S2z derivative is 2.49e-09, allowed is 3.50e-03
# In line 10: Erel in x derivative is 3.53e-10, allowed is 2.39e-03
# In line 10: Erel in y derivative is 1.30e-04, allowed is 9.31e-03
# In line 10: Erel in z derivative is 7.60e+03, allowed is 2.37e-03
# In line 10: Erel in p1 derivative is 1.71e-01, allowed is 3.82e-03
# In line 10: Erel in p2 derivative is 6.50e-13, allowed is 1.15e-03
# In line 10: Erel in p3 derivative is 3.75e-09, allowed is 5.75e-03
# In line 10: Erel in S1x derivative is 1.60e-06, allowed is 1.64e-02
# In line 10: Erel in S1y derivative is 2.25e-07, allowed is 8.14e-03
# In line 10: Erel in S1z derivative is 1.12e-08, allowed is 1.22e-03
# In line 10: Erel in S2x derivative is 2.76e-06, allowed is 8.61e-03
# In line 10: Erel in S2y derivative is 3.10e-07, allowed is 8.16e-03
# In line 10: Erel in S2z derivative is 3.72e-09, allowed is 1.23e-03
# In line 11: Erel in x derivative is 3.10e-11, allowed is 1.17e-03
# In line 11: Erel in y derivative is 1.34e-04, allowed is 3.98e-03
# In line 11: Erel in z derivative is 5.80e+03, allowed is 1.02e-03
# In line 11: Erel in p1 derivative is 1.82e-01, allowed is 1.02e-03
# In line 11: Erel in p2 derivative is 7.30e-11, allowed is 7.06e-04
# In line 11: Erel in p3 derivative is 5.76e-09, allowed is 2.01e-03
# In line 11: Erel in S1x derivative is 9.52e-07, allowed is 2.24e-02
# In line 11: Erel in S1y derivative is 8.05e-08, allowed is 3.18e-03
# In line 11: Erel in S1z derivative is 1.45e-08, allowed is 4.56e-04
# In line 11: Erel in S2x derivative is 3.32e-07, allowed is 3.32e-03
# In line 11: Erel in S2y derivative is 7.94e-07, allowed is 3.19e-03
# In line 11: Erel in S2z derivative is 5.23e-09, allowed is 4.62e-04
# In line 12: Erel in x derivative is 8.39e-11, allowed is 2.95e-03
# In line 12: Erel in y derivative is 1.12e-03, allowed is 2.05e-02
# In line 12: Erel in z derivative is 9.72e+03, allowed is 2.65e-03
# In line 12: Erel in p1 derivative is 1.42e-01, allowed is 3.52e-02
# In line 12: Erel in p2 derivative is 1.15e-10, allowed is 1.68e-03
# In line 12: Erel in p3 derivative is 2.71e-09, allowed is 1.51e-02
# In line 12: Erel in S1x derivative is 3.10e-07, allowed is 8.98e-03
# In line 12: Erel in S1y derivative is 1.27e-07, allowed is 1.80e-02
# In line 12: Erel in S1z derivative is 7.59e-09, allowed is 1.25e-03
# In line 12: Erel in S2x derivative is 9.47e-07, allowed is 2.04e-02
# In line 12: Erel in S2y derivative is 4.15e-06, allowed is 1.81e-02
# In line 12: Erel in S2z derivative is 9.23e-10, allowed is 1.28e-03
# In line 13: Erel in x derivative is 1.62e-10, allowed is 2.11e-03
# In line 13: Erel in y derivative is 3.11e-04, allowed is 8.66e-03
# In line 13: Erel in z derivative is 7.59e+03, allowed is 1.84e-03
# In line 13: Erel in p1 derivative is 1.66e-01, allowed is 1.15e-02
# In line 13: Erel in p2 derivative is 6.38e-11, allowed is 1.26e-03
# In line 13: Erel in p3 derivative is 6.55e-09, allowed is 5.75e-03
# In line 13: Erel in S1x derivative is 7.78e-07, allowed is 1.72e-02
# In line 13: Erel in S1y derivative is 2.60e-07, allowed is 7.86e-03
# In line 13: Erel in S1z derivative is 1.04e-08, allowed is 8.31e-04
# In line 13: Erel in S2x derivative is 5.14e-07, allowed is 8.38e-03
# In line 13: Erel in S2y derivative is 8.62e-07, allowed is 7.88e-03
# In line 13: Erel in S2z derivative is 1.15e-09, allowed is 8.49e-04
# In line 14: Erel in x derivative is 1.61e-10, allowed is 1.17e-03
# In line 14: Erel in y derivative is 1.62e-04, allowed is 4.01e-03
# In line 14: Erel in z derivative is 5.80e+03, allowed is 1.02e-03
# In line 14: Erel in p1 derivative is 1.75e-01, allowed is 7.20e-03
# In line 14: Erel in p2 derivative is 5.34e-11, allowed is 7.06e-04
# In line 14: Erel in p3 derivative is 7.15e-09, allowed is 2.01e-03
# In line 14: Erel in S1x derivative is 1.76e-06, allowed is 2.24e-02
# In line 14: Erel in S1y derivative is 1.59e-08, allowed is 3.18e-03
# In line 14: Erel in S1z derivative is 1.54e-08, allowed is 4.56e-04
# In line 14: Erel in S2x derivative is 5.67e-07, allowed is 3.32e-03
# In line 14: Erel in S2y derivative is 2.76e-08, allowed is 3.19e-03
# In line 14: Erel in S2z derivative is 2.62e-09, allowed is 4.62e-04
# In line 15: Erel in x derivative is 2.58e-10, allowed is 1.17e-03
# In line 15: Erel in y derivative is 1.62e-04, allowed is 3.98e-03
# In line 15: Erel in z derivative is 5.80e+03, allowed is 1.02e-03
# In line 15: Erel in p1 derivative is 1.75e-01, allowed is 6.17e-03
# In line 15: Erel in p2 derivative is 2.92e-11, allowed is 7.06e-04
# In line 15: Erel in p3 derivative is 4.86e-09, allowed is 2.01e-03
# In line 15: Erel in S1x derivative is 1.23e-06, allowed is 2.24e-02
# In line 15: Erel in S1y derivative is 2.15e-07, allowed is 3.18e-03
# In line 15: Erel in S1z derivative is 1.52e-08, allowed is 4.56e-04
# In line 15: Erel in S2x derivative is 1.10e-06, allowed is 3.32e-03
# In line 15: Erel in S2y derivative is 5.45e-08, allowed is 3.19e-03
# In line 15: Erel in S2z derivative is 3.47e-09, allowed is 4.62e-04
# In line 16: Erel in x derivative is 3.05e-10, allowed is 1.17e-03
# In line 16: Erel in y derivative is 5.66e-05, allowed is 3.79e-03
# In line 16: Erel in z derivative is 5.80e+03, allowed is 1.02e-03
# In line 16: Erel in p1 derivative is 1.82e-01, allowed is 2.04e-03
# In line 16: Erel in p2 derivative is 9.45e-11, allowed is 7.06e-04
# In line 16: Erel in p3 derivative is 2.23e-09, allowed is 2.01e-03
# In line 16: Erel in S1x derivative is 9.52e-07, allowed is 2.24e-02
# In line 16: Erel in S1y derivative is 2.00e-07, allowed is 3.18e-03
# In line 16: Erel in S1z derivative is 1.58e-08, allowed is 4.56e-04
# In line 16: Erel in S2x derivative is 1.12e-06, allowed is 3.32e-03
# In line 16: Erel in S2y derivative is 1.76e-07, allowed is 3.19e-03
# In line 16: Erel in S2z derivative is 5.55e-09, allowed is 4.62e-04
# In line 17: Erel in x derivative is 1.02e-10, allowed is 5.32e-03
# In line 17: Erel in y derivative is 1.04e-04, allowed is 1.32e-02
# In line 17: Erel in z derivative is 5.41e+03, allowed is 8.26e-03
# In line 17: Erel in p1 derivative is 1.78e-01, allowed is 2.22e-02
# In line 17: Erel in p2 derivative is 3.10e-11, allowed is 3.31e-04
# In line 17: Erel in p3 derivative is 3.93e-09, allowed is 5.26e-03
# In line 17: Erel in S1x derivative is 7.04e-07, allowed is 2.50e-02
# In line 17: Erel in S1y derivative is 5.36e-08, allowed is 1.06e-02
# In line 17: Erel in S1z derivative is 1.69e-08, allowed is 5.61e-03
# In line 17: Erel in S2x derivative is 6.85e-07, allowed is 9.05e-03
# In line 17: Erel in S2y derivative is 1.06e-07, allowed is 1.05e-02
# In line 17: Erel in S2z derivative is 3.33e-09, allowed is 5.57e-03
# In line 18: Erel in x derivative is 1.17e-10, allowed is 1.32e-02
# In line 18: Erel in y derivative is 2.88e-04, allowed is 1.16e-02
# In line 18: Erel in z derivative is 4.90e+03, allowed is 1.22e-02
# In line 18: Erel in p1 derivative is 1.98e-01, allowed is 2.47e-02
# In line 18: Erel in p2 derivative is 7.06e-11, allowed is 7.29e-03
# In line 18: Erel in p3 derivative is 1.97e-09, allowed is 8.42e-03
# In line 18: Erel in S1x derivative is 3.62e-07, allowed is 1.01e-01
# In line 18: Erel in S1y derivative is 4.87e-08, allowed is 4.75e-03
# In line 18: Erel in S1z derivative is 1.95e-08, allowed is 5.90e-03
# In line 18: Erel in S2x derivative is 1.10e-07, allowed is 3.25e-02
# In line 18: Erel in S2y derivative is 5.54e-08, allowed is 4.82e-03
# In line 18: Erel in S2z derivative is 6.41e-09, allowed is 5.93e-03
# In line 19: Erel in x derivative is 2.06e-10, allowed is 3.59e-03
# In line 19: Erel in y derivative is 2.42e-03, allowed is 2.53e+00
# In line 19: Erel in z derivative is 4.65e+03, allowed is 3.56e-03
# In line 19: Erel in p1 derivative is 1.34e-01, allowed is 2.66e+00
# In line 19: Erel in p2 derivative is 1.04e-10, allowed is 1.72e-03
# In line 19: Erel in p3 derivative is 2.64e-08, allowed is 2.53e+00
# In line 19: Erel in S1x derivative is 2.83e-07, allowed is 2.24e-02
# In line 19: Erel in S1y derivative is 6.42e-06, allowed is 2.53e+00
# In line 19: Erel in S1z derivative is 2.05e-08, allowed is 1.83e-03
# In line 19: Erel in S2x derivative is 9.50e-08, allowed is 8.35e-03
# In line 19: Erel in S2y derivative is 1.28e-05, allowed is 2.53e+00
# In line 19: Erel in S2z derivative is 4.58e-09, allowed is 1.83e-03
# In line 20: Erel in x derivative is 2.10e-10, allowed is 6.00e-04
# In line 20: Erel in y derivative is 8.86e-02, allowed is 2.00e+00
# In line 20: Erel in z derivative is 4.64e+03, allowed is 7.80e-04
# <ipython-input-13-58b6932e7386>:37: RuntimeWarning: divide by zero encountered in double_scalars
#   Erel = np.abs((nrpy_derivs[j]/eta - derivs['dHreal_d'+var])/derivs['dHreal_d'+var])
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-58b6932e7386> in <module>
#      36                 var = str(dynamic_variables[j])
#      37                 Erel = np.abs((nrpy_derivs[j]/eta - derivs['dHreal_d'+var])/derivs['dHreal_d'+var])
# ---> 38                 Erelpert = np.abs((derivs['dHreal_d'+var]-derivspert['dHreal_d'+var])/derivs['dHreal_d'+var])
#      39                 print("In line %d: Erel in %s derivative is %.2e, allowed is %.2e"%(i,var,Erel,Erelpert))
#      40
#
# ZeroDivisionError: float division by zero
