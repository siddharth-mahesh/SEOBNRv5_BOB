# %% [markdown]
# # Symbolic Partial Derivative Routine
#
# ## Authors: Zach Etienne & Tyler Knowles
#
# ## This module contains a routine for computing partial derivatives of a mathematical expression that is written as several subexpressions.
#
# **Notebook Status:** <font color='green'><b> Validated </b></font>
#
# **Validation Notes:** This tutorial notebook has been confirmed to be self-consistent with its corresponding NRPy+ module, as documented [below](#code_validation). Additionally, this notebook has been validated by checking that results are consistent with exact derivative expressions used in the SEOBNRv3_opt approixment of [LALSuite](https://git.ligo.org/lscsoft/lalsuite).
#
# ### NRPy+ Source Code for this module: [SEOBNR_Derivative_Routine.py](../edit/SEOBNR/SEOBNR_Derivative_Routine.py)
#
# ## Introduction
# $$\label{intro}$$
#
# This notebook documents the symbolic partial derivative routine used to generate analytic derivatives of the [SEOBNRv3](https://git.ligo.org/lscsoft/lalsuite) Hamiltonian (documented [here](../Tutorial-SEOBNR_v3_Hamiltonian.ipynb)) and described in [this article](https://arxiv.org/abs/1803.06346).  In general, this notebook takes as input a file of inter-dependent mathematical expressions (in SymPy syntax), a file listing the names of values within those expressions, and a file listing all variables with which to take partial derivatives of each expression.  The output is a text file containing the original expression and those for each partial derivative computation.  The intention is to perform CSE on these expressions to create efficient partial derivative code!

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# This notebook is organized as follows
#
# 1. [Step 1](#initializenrpy): Initialize core Python/NRPy+ modules
# 1. [Step 2:](#read_expressions) Read in Hamiltonian expressions from `Hamstring.txt`
# 1. [Step 3:](#list_constants) Specify constants and variables in Hamiltonian expression
# 1. [Step 4:](#list_free_symbols) Extract free symbols
# 1. [Step 5:](#convert_to_func) Convert variables to function notation; e.g., `var` goes to `var(xx)`
# 1. [Step 6:](#differentiate) Differentiate with respect to `xx`
# 1. [Step 7:](#remove_zeros) Remove derivatives (of constants) that evaluate to zero, simplifying derivative expressions
# 1. [Step 8:](#partial_derivative) Simplify derivatives with respect to a specific variable
# 1. [Step 9:](#store_results) Store partial derivatives to SymPy notebook `partial_derivatives.txt-VALIDATION.txt`
# 1. [Step 10:](#code_validation) Validate against LALSuite and trusted `SEOBNR_Derivative_Routine` NRPy+ module
# 1. [Step 11:](#latex_pdf_output) Output this notebook to $\LaTeX$-formatted PDF file

# %% [markdown]
# <a id='initializenrpy'></a>
#
# # Step 1: Initialize core Python/NRPy+ modules \[Back to [top](#toc)\]
# $$\label{initializenrpy}$$
#
# Let's start by importing all the needed modules from Python/NRPy+ and creating the output directory (if it does not already exist):

# %%
# Step 1.a: import all needed modules from Python/NRPy+:
import sympy as sp                # SymPy: The Python computer algebra package upon which NRPy+ depends
import sys, os     # Standard Python modules for multiplatform OS-level functions
sys.path.append('../')

from outputC import superfast_uniq, lhrh      # Remove duplicate entries from a Python array; store left- and right-
                                              #   hand sides of mathematical expressions

# As of April 2021, "sp.sympify("Q+1")" fails because Q is a reserved keyword.
#   This is the workaround, courtesy Ken Sible.
custom_global_dict = {}
exec('from sympy import *', custom_global_dict)
del custom_global_dict['Q']

# Step 1.b: Check for a sufficiently new version of SymPy (for validation)
# Ignore the rc's and b's for release candidates & betas.
sympy_version = sp.__version__.replace('rc', '...').replace('b', '...')
sympy_version_decimal = float(int(sympy_version.split(".")[0]) + int(sympy_version.split(".")[1])/10.0)
if sympy_version_decimal > 1.2:
    custom_parse_expr = lambda expr: sp.parse_expr(expr, global_dict=custom_global_dict)
else:
    custom_parse_expr = lambda expr: sp.sympify(expr)

if sympy_version_decimal < 1.2:
    print('Error: NRPy+ does not support SymPy < 1.2')
    sys.exit(1)

# Step 1.c: Name of the directory containing the input file
inputdir = "Hamiltonian"

# %% [markdown]
# <a id='read_expressions'></a>
#
# # Step 2: Read in Hamiltonian expressions from `Hamstring.txt` \[Back to [top](#toc)\]
# $$\label{read_expressions}$$
#
# We read in the expressions of which we will compute partial derivatives in a single large string before splitting the string by line (carriage return) and by "=".  Doing so allows us to manipulate the right- and left-hand sides of the expressions appropriately.  We store the left- and right-hand sides in the array `lr`, which consists of `lhrh` arrays with left-hand sides `lhs` and right-hand sides `rhs`.  Note that `Lambda` is a protected keyword in Python, so the variable $\Lambda$ in the Hamiltonian is renamed `Lamb`.

# %%
# Step 2.a: Read in expressions as a (single) string
with open(os.path.join(inputdir,'Sympy_Hreal_on_Bottom.txt'), 'r') as file:
    expressions_as_lines = file.readlines()

#print(expressions_as_lines)
# Step 2.b: Create and populate the "lr" array, which separates each line into left- and right-hand sides
#   Each entry is a string of the form lhrh(lhs='',rhs='')
lr = []

for i in range(len(expressions_as_lines)):
    # Ignore lines with 2 or fewer characters and those starting with #
    if len(expressions_as_lines[i]) > 2 and expressions_as_lines[i][0] != "#":
        # Split each line by its equals sign
        split_line = expressions_as_lines[i].split("=")
        #print(split_line)
        # Append the line to "lr", removing spaces, "sp." prefixes, and replacing Lambda->Lamb
        #   (Lambda is a protected keyword):
        lr.append(lhrh(lhs=split_line[0].replace(" ","").replace("Lambda","Lamb"),
                       rhs=split_line[1].replace(" ","").replace("sp.","").replace("Lambda","Lamb")))

# Step 2.c: Separate and sympify right- and left-hand sides into separate arrays
lhss = []
rhss = []
for i in range(len(lr)):
    #print(lr[i].rhs)
    lhss.append(custom_parse_expr(lr[i].lhs))
    rhss.append(custom_parse_expr(lr[i].rhs))

print(lhss)
print(rhss)
# Out:
# [EMgamma, M, mu, eta, r, u, sigmastar3, sigmastar2, sigmastar1, sigma3, sigma2, sigma1, Skerr3, Skerr2, Skerr1, Skerrmag, Skerrhat3, Skerrhat2, Skerrhat1, a, L3, L2, L1, Lnorm, Lhat3, Lhat2, Lhat1, S2dotLhat, S1dotLhat, S1perp3, S1perp2, S1perp1, S2perp3, S2perp2, S2perp1, Sperp3, Sperp2, Sperp1, n3, n2, n1, e33, e32, e31, xi3, xi2, xi1, v3, v2, v1, costheta, sin2theta, xisq, w2, Sigma, Dinv, omegatilde, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, Delta4, Delta5, Delta5l, logarg, Deltaucalib, Deltaucalibprime, Deltaubar, Deltaubarprime, Deltau, Deltauprime, Deltatprime, Deltat, Deltar, Lambt, csi, csi1, csi2, prT, phat3, phat2, phat1, pdotxir, pdotn, pdotvr, pphi, Qcoeff2, Qcoeff1, DrSipn2, Q, Qminus1, Jtilde, exp2mu, expmu, Brtilde, Btilde, exp2nu, expnu, omega, omegatildeprime, Lambtprime, mucostheta, nucostheta, omegacostheta, mur, nur, omegar, dSO, sigmacoeffTerm3, sigmacoeffTerm2, sigmacoeffTerm1, sigmacoeff, sigmastarcoeffTerm2, sigmastarcoeffTerm1, sigmastarcoeff, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S3, S2, S1, Sstardotn, SdotSkerrhat, Sdotn, Sdotv, Sdotxi, HdsumTerm2, HdsumTerm1, Hdsum, Hdcoeff, Q4, gammappsum, Hnsradicand, alpha, betapsum, HssTerm3, HssTerm3coeff, HssTerm2, HssTerm2coeff, HssTerm1, Hss, HsoTerm2c, HsoTerm2b, HsoTerm2a, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hso, Hd, Hns, Hs, dSS, Heff, Hreal]
# [0.577215664901532860606512090082402431, m1 + m2, m1*m2/M, mu/M, sqrt(x**2 + y**2 + z**2), 1/r, S1z*m2/m1 + S2z*m1/m2, S1y*m2/m1 + S2y*m1/m2, S1x*m2/m1 + S2x*m1/m2, S1z + S2z, S1y + S2y, S1x + S2x, sigma3, sigma2, sigma1, sqrt(Skerr1**2 + Skerr2**2 + Skerr3**2), Skerr3/Skerrmag, Skerr2/Skerrmag, Skerr1/Skerrmag, Skerrmag, -p1*y + p2*x, p1*z - p3*x, -p2*z + p3*y, sqrt(L1**2 + L2**2 + L3**2), L3/Lnorm, L2/Lnorm, L1/Lnorm, Lhat1*S2x + Lhat2*S2y + Lhat3*S2z, Lhat1*S1x + Lhat2*S1y + Lhat3*S1z, -Lhat3*S1dotLhat + S1z, -Lhat2*S1dotLhat + S1y, -Lhat1*S1dotLhat + S1x, -Lhat3*S2dotLhat + S2z, -Lhat2*S2dotLhat + S2y, -Lhat1*S2dotLhat + S2x, S1perp3 + S2perp3, S1perp2 + S2perp2, S1perp1 + S2perp1, z/r, y/r, x/r, Skerrhat3, Skerrhat2, Skerrhat1, e31*n2 - e32*n1, e31*n3 + e33*n1, e32*n3 - e33*n2, n1*xi2 - n2*xi1, -n1*xi3 + n3*xi1, n2*xi3 - n3*xi2, e31*n1 + e32*n2 + e33*n3, 1 - costheta**2, sin2theta, a**2 + r**2, a**2*costheta**2 + r**2, log(eta*u**3*(52 - 6*eta) + 6*eta*u**2 + 1) + 1, 2*a*r, (Lhat1*Skerr1 + Lhat2*Skerr2 + Lhat3*Skerr3)/(1 - 2*eta) + (Skerr1*Sperp1/2 + Skerr2*Sperp2/2 + Skerr3*Sperp3/2)/(Skerrmag*(1.0 - 2.0*eta)), 267.788*eta**3 - 126.687*eta**2 + 10.2573*eta + 1.7336, Kchi0 - 59.1658*chi**3*eta**3 - 0.426958*chi**3*eta + 1.43659*chi**3 + 31.1746*chi**2*eta**3 + 6.16466*chi**2*eta**2 - 1.38086*chi**2 - 27.5201*chi*eta**3 + 17.3736*chi*eta**2 + 2.26831*chi*eta - 1.62045*chi, K*eta - 1, K*(K*eta - 2), -2*etaKminus1*(Delta0 + K), -Delta0*a**2*etaKminus1**2 + Delta1*(Delta1 - 4*etaKminus1)/2, -Delta1**3/3 + Delta1**2*etaKminus1 + Delta1*Delta2 - Delta1*a**2*etaKminus1**2 - 2*etaKminus1*(Delta2 - etaKminus1), Delta1**4/4 - 2*Delta1**3*etaKminus1/3 - Delta1**2*Delta2 + Delta1*(24*Delta2*etaKminus1 + 12*Delta3)/12 + Delta2**2/2 - 2*Delta3*etaKminus1 + a**2*etaKminus1**2*(Delta1**2 - 2*Delta2)/2 + etaKminus1**2*(376 - 123*pi**2/8)/12, etaKminus1**2*(128*EMgamma/5 - a**2*(Delta1**3 - 3*Delta1*Delta2 + 3*Delta3)/3 + eta*(-221/6 + 41*pi**2/32) - 4237/60 + 256*log(2)/5 + 2275*pi**2/512 + (Delta1**4 - 4*Delta1**2*Delta2 + 4*Delta1*Delta3 + 2*Delta2**2 - 4*Delta4)/(2*etaKminus1) - (Delta1**5 - 5*Delta1**3*Delta2 + 5*Delta1**2*Delta3 + 5*Delta1*Delta2**2 - 5*Delta1*Delta4 - 5*Delta2*Delta3)/(5*etaKminus1**2)), 64*etaKminus1**2/5, u*(Delta1 + u*(Delta2 + u*(Delta3 + u*(Delta4 + u*(Delta5 + Delta5l*log(u)))))), eta*(Delta0 + log(logarg + 1)) + 1, -eta*u**2*(Delta1 + u*(2*Delta2 + u*(3*Delta3 + u*(4*Delta4 + u*(5*Delta5 + 5*Delta5l*log(u))))))/(logarg + 1), a**2*u**2 + (2*u + 1/etaKminus1)/etaKminus1, -2*a**2*u**3 - 2*u**2/etaKminus1, Deltaubar*Deltaucalib, Deltaubar*Deltaucalibprime + Deltaubarprime*Deltaucalib, 2*Deltau*r + Deltauprime*r**2, Deltau*r**2, Deltat*Dinv, -Deltat*a**2*sin2theta + w2**2, sqrt(Deltar*Deltat)/w2, (1 - Abs(tortoise - 1))*(csi - 1) + 1, (1/2 - sign(3/2 - tortoise)/2)*(csi - 1) + 1, csi2*(n1*p1 + n2*p2 + n3*p3), n3*prT*(1 - 1/csi1) + p3, n2*prT*(1 - 1/csi1) + p2, n1*prT*(1 - 1/csi1) + p1, r*(phat1*xi1 + phat2*xi2 + phat3*xi3), n1*phat1 + n2*phat2 + n3*phat3, r*(phat1*v1 + phat2*v2 + phat3*v3), pdotxir, 1/(Sigma*sin2theta), Sigma/(Lambt*sin2theta), Deltar*pdotn**2/Sigma, DrSipn2 + Qcoeff1*pdotxir**2 + Qcoeff2*pdotvr**2 + 1, Q - 1, sqrt(Deltar), Sigma, sqrt(exp2mu), (sqrt(Deltar)*Deltatprime - 2*Deltat)/(2*sqrt(Deltar*Deltat)), sqrt(Deltat), Deltat*Sigma/Lambt, sqrt(exp2nu), omegatilde/Lambt, 2*a, -2*Deltatprime*a**2*sin2theta + r*(4*a**2 + 4*r**2), a**2*costheta/Sigma, a**2*costheta*w2*(-Deltat + w2)/(Lambt*Sigma), -2*Deltat*a**2*costheta*omegatilde/Lambt**2, r/Sigma - 1/sqrt(Deltar), r/Sigma + w2*(-4*Deltat*r + Deltatprime*w2)/(2*Deltat*Lambt), (Lambt*omegatildeprime - Lambtprime*omegatilde)/Lambt**2, 147.481*chi**3*eta**2 - 568.651*chi**3*eta + 66.1987*chi**3 - 343.313*chi**2*eta + 2495.29*chi*eta**2 - 44.5324, dSO*eta*u**3, eta*(eta*(r*(-882*DrSipn2 + 204*Qminus1 + r*(810*DrSipn2**2 - 234*DrSipn2*Qminus1)) - 336) + r*(-96*DrSipn2 - 436*Qminus1 + r*(36*DrSipn2*Qminus1 - 45*Qminus1**2)) - 896)/(144*r**2), eta*(-36*Dr ...
# x/sqrt(x**2 + y**2 + z**2)

# %% [markdown]
# <a id='list_constants'></a>
#
# # Step 3: Specify constants and variables in Hamiltonian expression \[Back to [top](#toc)\]
# $$\label{list_constants}$$
#
# We read in and declare as SymPy symbols the constant values; derivatives with respect to these variables will be set to zero.  We then read in the variables with respect to which we want to take derivatives and declare those as SymPy variables as well.

# %%
# Step 3.a: Create `input_constants` array and populate with SymPy symbols
m1,m2,tortoise,eta,KK,k0,k1,EMgamma,d1v2,dheffSSv2 = sp.symbols('m1 m2 tortoise eta KK k0 k1 EMgamma d1v2 dheffSSv2',
                                                                real=True)
input_constants = [m1,m2,tortoise,eta,KK,k0,k1,EMgamma,d1v2,dheffSSv2]

# Step 3.b: Create `dynamic_variables` array and populate with SymPy symbols
x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols('x y z p1 p2 p3 S1x S1y S1z S2x S2y S2z', real=True)
dynamic_variables = [x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z]

# %% [markdown]
# <a id='list_free_symbols'></a>
#
# # Step 4: Extract free symbols \[Back to [top](#toc)\]
# $$\label{list_free_symbols}$$
#
# By ''free symbols'' we mean the variables in the right-hand sides.  We first create a list of all such terms (using SymPy's built-in free_symbol attribute), including duplicates, and then strip the duplicates.  We then remove input constants from the symbol list.

# %%
# Step 4.a: Prepare array of "free symbols" in the right-hand side expressions
full_symbol_list_with_dups = []
for i in range(len(lr)):
    for variable in rhss[i].free_symbols:
        full_symbol_list_with_dups.append(variable)

print(full_symbol_list_with_dups)
# Step 4.b: Remove duplicate free symbols
full_symbol_list = superfast_uniq(full_symbol_list_with_dups)
print(full_symbol_list)
# Step 4.c: Remove input constants from symbol list
for inputconst in input_constants:
    for symbol in full_symbol_list:
        if str(symbol) == str(inputconst):
            full_symbol_list.remove(symbol)
print(full_symbol_list)
# Out:
# [m2, m1, M, m2, m1, mu, M, y, z, x, r, m2, S2z, S1z, m1, m2, S2y, S1y, m1, S2x, m2, S1x, m1, S1z, S2z, S1y, S2y, S1x, S2x, sigma3, sigma2, sigma1, Skerr1, Skerr2, Skerr3, Skerrmag, Skerr3, Skerr2, Skerrmag, Skerr1, Skerrmag, Skerrmag, y, p1, x, p2, p3, z, x, p1, y, z, p3, p2, L2, L3, L1, Lnorm, L3, L2, Lnorm, Lnorm, L1, S2x, Lhat2, S2y, S2z, Lhat3, Lhat1, Lhat2, S1z, S1y, Lhat3, S1x, Lhat1, S1z, Lhat3, S1dotLhat, S1y, Lhat2, S1dotLhat, S1x, Lhat1, S1dotLhat, Lhat3, S2dotLhat, S2z, S2dotLhat, Lhat2, S2y, S2x, S2dotLhat, Lhat1, S2perp3, S1perp3, S2perp2, S1perp2, S2perp1, S1perp1, r, z, r, y, r, x, Skerrhat3, Skerrhat2, Skerrhat1, n2, n1, e31, e32, n3, e33, n1, e31, e32, e33, n2, n3, n2, n1, xi1, xi2, n3, xi3, xi1, n1, n2, xi3, n3, xi2, n3, n2, e31, e32, e33, n1, costheta, sin2theta, r, a, r, a, costheta, eta, u, r, a, eta, Sperp1, Sperp3, Lhat1, Skerr3, Skerrmag, Skerr1, Skerr2, Lhat2, Lhat3, Sperp2, eta, chi, eta, Kchi0, K, eta, K, eta, etaKminus1, K, Delta0, etaKminus1, Delta1, Delta0, a, Delta1, etaKminus1, Delta2, a, Delta1, etaKminus1, Delta2, a, Delta3, Delta1, eta, Delta4, Delta2, a, Delta3, etaKminus1, EMgamma, etaKminus1, Delta1, Delta5l, Delta4, Delta2, Delta3, u, Delta5, logarg, eta, Delta0, Delta1, eta, Delta5l, Delta4, Delta2, Delta3, logarg, u, Delta5, etaKminus1, a, u, etaKminus1, a, u, Deltaucalib, Deltaubar, Deltaucalibprime, Deltaucalib, Deltaubarprime, Deltaubar, r, Deltauprime, Deltau, r, Deltau, Dinv, Deltat, a, sin2theta, Deltat, w2, Deltat, w2, Deltar, tortoise, csi, tortoise, csi, n3, p2, p3, n2, n1, csi2, p1, n3, csi1, prT, p3, n2, csi1, prT, p2, prT, n1, csi1, p1, phat2, xi3, xi1, r, phat3, phat1, xi2, phat2, n3, phat3, n2, n1, phat1, phat2, v1, r, v2, v3, phat3, phat1, pdotxir, Sigma, sin2theta, Lambt, Sigma, sin2theta, Sigma, pdotn, Deltar, DrSipn2, pdotvr, Qcoeff2, pdotxir, Qcoeff1, Q, Deltar, Sigma, exp2mu, Deltar, Deltatprime, Deltat, Deltat, Lambt, Sigma, Deltat, exp2nu, Lambt, omegatilde, a, sin2theta, r, a, Deltatprime, a, Sigma, costheta, Sigma, w2, costheta, a, Lambt, Deltat, Deltat, costheta, a, Lambt, omegatilde, r, Sigma, Deltar, Sigma, Deltat, w2, r, Deltatprime, Lambt, Lambtprime, omegatildeprime, Lambt, omegatilde, chi, eta, eta, dSO, u, DrSipn2, Qminus1, eta, r, DrSipn2, eta, Qminus1, r, sigmacoeffTerm1, sigmacoeffTerm3, sigmacoeffTerm2, DrSipn2, Qminus1, eta, r, DrSipn2, eta, Qminus1, r, sigmastarcoeffTerm1, sigmastarcoeffTerm2, sigmastarcoeff, sigmacoeff, sigmastar3, sigma3, sigmastar2, sigmastarcoeff, sigma2, sigmacoeff, sigmastarcoeff, sigmacoeff, sigmastar1, sigma1, sigmastar3, Deltasigmastar3, Deltasigmastar2, sigmastar2, sigmastar1, Deltasigmastar1, Sstar3, Sstar2, Sstar1, n3, n2, Sstar2, Sstar1, n1, Sstar3, Skerrhat1, S1, Skerrhat3, S3, S2, Skerrhat2, n3, S1, S3, n2, S2, n1, S1, S3, v1, S2, v2, v3, xi3, xi1, S1, S3, S2, xi2, Sstardotn, Sstar1, Sstar3, Sstar2, HdsumTerm1, HdsumTerm2, r, prT, eta, u, pdotvr, Sigma, Deltar, pdotxir, pdotn, sin2theta, Lambt, Q4, gammappsum, Lambt, Sigma, Deltat, Lambt, omegatilde, pphi, pdotvr, Sdotv, Btilde, expnu, pdotxir, pdotn, Sdotn, Sdotxi, expmu, exp2mu, Q, Jtilde, xisq, Btilde, expnu, expmu, exp2mu, Q, omegacostheta, pdotvr, Sdotv, Btilde, expnu, pdotxir, pdotn, exp2nu, Sdotn, Sdotxi, expmu, exp2mu, Q, Jtilde, xisq, Btilde, omegar, expnu, expmu, exp2mu, Q, Jtilde, xisq, SdotSkerrhat, omega, HssTerm1, HssTerm3coeff, HssTerm2coeff, HssTerm3, HssTerm2, Brtilde, Sdotv, expnu, expmu, pdotxir, Q, Jtilde, Sdotv, nur, Btilde, expnu, pdotxir, Sdotn, expmu, xisq, Q, Jtilde, nucostheta, pdotvr, nur, Btilde, nucostheta, pdotn, Sdotxi, mucostheta, mur, Q, Jtilde, xisq, HsoTerm2a, HsoTerm2b, HsoTerm2c, Btilde, expnu, exp2mu, Q, xisq, Btilde, expnu, pdotxir, exp2nu, SdotSkerrhat, expmu, Q, xisq, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hdsum, Hdcoeff, alpha, betapsum, Hnsradicand, Hss, Hso, chi, eta, Hs, Hns, eta, S2x, S2y, dSS, S1x, Hd, S2z, u, S1z, S1y, Heff, eta]
# [m2, m1, M, mu, y, z, x, r, S2z, S1z, S2y, S1y, S2x, S1x, sigma3, sigma2, sigma1, Skerr1, Skerr2, Skerr3, Skerrmag, p1, p2, p3, L2, L3, L1, Lnorm, Lhat2, Lhat3, Lhat1, S1dotLhat, S2dotLhat, S2perp3, S1perp3, S2perp2, S1perp2, S2perp1, S1perp1, Skerrhat3, Skerrhat2, Skerrhat1, n2, n1, e31, e32, n3, e33, xi1, xi2, xi3, costheta, sin2theta, a, eta, u, Sperp1, Sperp3, Sperp2, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, Delta4, EMgamma, Delta5l, Delta5, logarg, Deltaucalib, Deltaubar, Deltaucalibprime, Deltaubarprime, Deltauprime, Deltau, Dinv, Deltat, w2, Deltar, tortoise, csi, csi2, csi1, prT, phat2, phat3, phat1, v1, v2, v3, pdotxir, Sigma, Lambt, pdotn, DrSipn2, pdotvr, Qcoeff2, Qcoeff1, Q, exp2mu, Deltatprime, exp2nu, omegatilde, Lambtprime, omegatildeprime, dSO, Qminus1, sigmacoeffTerm1, sigmacoeffTerm3, sigmacoeffTerm2, sigmastarcoeffTerm1, sigmastarcoeffTerm2, sigmastarcoeff, sigmacoeff, sigmastar3, sigmastar2, sigmastar1, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S1, S3, S2, Sstardotn, HdsumTerm1, HdsumTerm2, Q4, gammappsum, pphi, Sdotv, Btilde, expnu, Sdotn, Sdotxi, expmu, Jtilde, xisq, omegacostheta, omegar, SdotSkerrhat, omega, HssTerm1, HssTerm3coeff, HssTerm2coeff, HssTerm3, HssTerm2, Brtilde, nur, nucostheta, mucostheta, mur, HsoTerm2a, HsoTerm2b, HsoTerm2c, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hdsum, Hdcoeff, alpha, betapsum, Hnsradicand, Hss, Hso, Hs, Hns, dSS, Hd, Heff]
# [M, mu, y, z, x, r, S2z, S1z, S2y, S1y, S2x, S1x, sigma3, sigma2, sigma1, Skerr1, Skerr2, Skerr3, Skerrmag, p1, p2, p3, L2, L3, L1, Lnorm, Lhat2, Lhat3, Lhat1, S1dotLhat, S2dotLhat, S2perp3, S1perp3, S2perp2, S1perp2, S2perp1, S1perp1, Skerrhat3, Skerrhat2, Skerrhat1, n2, n1, e31, e32, n3, e33, xi1, xi2, xi3, costheta, sin2theta, a, u, Sperp1, Sperp3, Sperp2, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, Delta4, Delta5l, Delta5, logarg, Deltaucalib, Deltaubar, Deltaucalibprime, Deltaubarprime, Deltauprime, Deltau, Dinv, Deltat, w2, Deltar, csi, csi2, csi1, prT, phat2, phat3, phat1, v1, v2, v3, pdotxir, Sigma, Lambt, pdotn, DrSipn2, pdotvr, Qcoeff2, Qcoeff1, Q, exp2mu, Deltatprime, exp2nu, omegatilde, Lambtprime, omegatildeprime, dSO, Qminus1, sigmacoeffTerm1, sigmacoeffTerm3, sigmacoeffTerm2, sigmastarcoeffTerm1, sigmastarcoeffTerm2, sigmastarcoeff, sigmacoeff, sigmastar3, sigmastar2, sigmastar1, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S1, S3, S2, Sstardotn, HdsumTerm1, HdsumTerm2, Q4, gammappsum, pphi, Sdotv, Btilde, expnu, Sdotn, Sdotxi, expmu, Jtilde, xisq, omegacostheta, omegar, SdotSkerrhat, omega, HssTerm1, HssTerm3coeff, HssTerm2coeff, HssTerm3, HssTerm2, Brtilde, nur, nucostheta, mucostheta, mur, HsoTerm2a, HsoTerm2b, HsoTerm2c, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hdsum, Hdcoeff, alpha, betapsum, Hnsradicand, Hss, Hso, Hs, Hns, dSS, Hd, Heff]

# %% [markdown]
# <a id='convert_to_func'></a>
#
# # Step 5: Convert variables to function notation; e.g., `var` goes to `var(xx)` \[Back to [top](#toc)\]
# $$\label{convert_to_func}$$
#
# In order to compute the partial derivative of each right-hand side, we mark each variable (left-hand side) and each free symbol (in right-hand sides) as a function with argument $\texttt{xx}$.

# %%
# Step 5.a: Convert each left-hand side to function notation
#   while separating and simplifying left- and right-hand sides
xx = sp.Symbol('xx',real=True)
func = []
for i in range(len(lr)):
    func.append(sp.sympify(sp.Function(lr[i].lhs,real=True)(xx)))
print(func)
# Step 5.b: Mark each free variable as a function with argument xx
full_function_list = []
for symb in full_symbol_list:
    func = sp.sympify(sp.Function(str(symb),real=True)(xx))
    full_function_list.append(func)
    for i in range(len(rhss)):
        for var in rhss[i].free_symbols:
            if str(var) == str(symb):
                rhss[i] = rhss[i].subs(var,func)
print(func)
print(rhss)
# Out:
# [EMgamma(xx), M(xx), mu(xx), eta(xx), r(xx), u(xx), sigmastar3(xx), sigmastar2(xx), sigmastar1(xx), sigma3(xx), sigma2(xx), sigma1(xx), Skerr3(xx), Skerr2(xx), Skerr1(xx), Skerrmag(xx), Skerrhat3(xx), Skerrhat2(xx), Skerrhat1(xx), a(xx), L3(xx), L2(xx), L1(xx), Lnorm(xx), Lhat3(xx), Lhat2(xx), Lhat1(xx), S2dotLhat(xx), S1dotLhat(xx), S1perp3(xx), S1perp2(xx), S1perp1(xx), S2perp3(xx), S2perp2(xx), S2perp1(xx), Sperp3(xx), Sperp2(xx), Sperp1(xx), n3(xx), n2(xx), n1(xx), e33(xx), e32(xx), e31(xx), xi3(xx), xi2(xx), xi1(xx), v3(xx), v2(xx), v1(xx), costheta(xx), sin2theta(xx), xisq(xx), w2(xx), Sigma(xx), Dinv(xx), omegatilde(xx), chi(xx), Kchi0(xx), K(xx), etaKminus1(xx), Delta0(xx), Delta1(xx), Delta2(xx), Delta3(xx), Delta4(xx), Delta5(xx), Delta5l(xx), logarg(xx), Deltaucalib(xx), Deltaucalibprime(xx), Deltaubar(xx), Deltaubarprime(xx), Deltau(xx), Deltauprime(xx), Deltatprime(xx), Deltat(xx), Deltar(xx), Lambt(xx), csi(xx), csi1(xx), csi2(xx), prT(xx), phat3(xx), phat2(xx), phat1(xx), pdotxir(xx), pdotn(xx), pdotvr(xx), pphi(xx), Qcoeff2(xx), Qcoeff1(xx), DrSipn2(xx), Q(xx), Qminus1(xx), Jtilde(xx), exp2mu(xx), expmu(xx), Brtilde(xx), Btilde(xx), exp2nu(xx), expnu(xx), omega(xx), omegatildeprime(xx), Lambtprime(xx), mucostheta(xx), nucostheta(xx), omegacostheta(xx), mur(xx), nur(xx), omegar(xx), dSO(xx), sigmacoeffTerm3(xx), sigmacoeffTerm2(xx), sigmacoeffTerm1(xx), sigmacoeff(xx), sigmastarcoeffTerm2(xx), sigmastarcoeffTerm1(xx), sigmastarcoeff(xx), Deltasigmastar3(xx), Deltasigmastar2(xx), Deltasigmastar1(xx), Sstar3(xx), Sstar2(xx), Sstar1(xx), S3(xx), S2(xx), S1(xx), Sstardotn(xx), SdotSkerrhat(xx), Sdotn(xx), Sdotv(xx), Sdotxi(xx), HdsumTerm2(xx), HdsumTerm1(xx), Hdsum(xx), Hdcoeff(xx), Q4(xx), gammappsum(xx), Hnsradicand(xx), alpha(xx), betapsum(xx), HssTerm3(xx), HssTerm3coeff(xx), HssTerm2(xx), HssTerm2coeff(xx), HssTerm1(xx), Hss(xx), HsoTerm2c(xx), HsoTerm2b(xx), HsoTerm2a(xx), HsoTerm2(xx), HsoTerm2coeff(xx), HsoTerm1(xx), Hso(xx), Hd(xx), Hns(xx), Hs(xx), dSS(xx), Heff(xx), Hreal(xx)]
# Heff(xx)
# [0.577215664901532860606512090082402431, m1 + m2, m1*m2/M(xx), mu(xx)/M(xx), sqrt(x(xx)**2 + y(xx)**2 + z(xx)**2), 1/r(xx), m1*S2z(xx)/m2 + m2*S1z(xx)/m1, m1*S2y(xx)/m2 + m2*S1y(xx)/m1, m1*S2x(xx)/m2 + m2*S1x(xx)/m1, S1z(xx) + S2z(xx), S1y(xx) + S2y(xx), S1x(xx) + S2x(xx), sigma3(xx), sigma2(xx), sigma1(xx), sqrt(Skerr1(xx)**2 + Skerr2(xx)**2 + Skerr3(xx)**2), Skerr3(xx)/Skerrmag(xx), Skerr2(xx)/Skerrmag(xx), Skerr1(xx)/Skerrmag(xx), Skerrmag(xx), -p1(xx)*y(xx) + p2(xx)*x(xx), p1(xx)*z(xx) - p3(xx)*x(xx), -p2(xx)*z(xx) + p3(xx)*y(xx), sqrt(L1(xx)**2 + L2(xx)**2 + L3(xx)**2), L3(xx)/Lnorm(xx), L2(xx)/Lnorm(xx), L1(xx)/Lnorm(xx), Lhat1(xx)*S2x(xx) + Lhat2(xx)*S2y(xx) + Lhat3(xx)*S2z(xx), Lhat1(xx)*S1x(xx) + Lhat2(xx)*S1y(xx) + Lhat3(xx)*S1z(xx), -Lhat3(xx)*S1dotLhat(xx) + S1z(xx), -Lhat2(xx)*S1dotLhat(xx) + S1y(xx), -Lhat1(xx)*S1dotLhat(xx) + S1x(xx), -Lhat3(xx)*S2dotLhat(xx) + S2z(xx), -Lhat2(xx)*S2dotLhat(xx) + S2y(xx), -Lhat1(xx)*S2dotLhat(xx) + S2x(xx), S1perp3(xx) + S2perp3(xx), S1perp2(xx) + S2perp2(xx), S1perp1(xx) + S2perp1(xx), z(xx)/r(xx), y(xx)/r(xx), x(xx)/r(xx), Skerrhat3(xx), Skerrhat2(xx), Skerrhat1(xx), e31(xx)*n2(xx) - e32(xx)*n1(xx), e31(xx)*n3(xx) + e33(xx)*n1(xx), e32(xx)*n3(xx) - e33(xx)*n2(xx), n1(xx)*xi2(xx) - n2(xx)*xi1(xx), -n1(xx)*xi3(xx) + n3(xx)*xi1(xx), n2(xx)*xi3(xx) - n3(xx)*xi2(xx), e31(xx)*n1(xx) + e32(xx)*n2(xx) + e33(xx)*n3(xx), 1 - costheta(xx)**2, sin2theta(xx), a(xx)**2 + r(xx)**2, a(xx)**2*costheta(xx)**2 + r(xx)**2, log(eta*(52 - 6*eta)*u(xx)**3 + 6*eta*u(xx)**2 + 1) + 1, 2*a(xx)*r(xx), (Lhat1(xx)*Skerr1(xx) + Lhat2(xx)*Skerr2(xx) + Lhat3(xx)*Skerr3(xx))/(1 - 2*eta) + (Skerr1(xx)*Sperp1(xx)/2 + Skerr2(xx)*Sperp2(xx)/2 + Skerr3(xx)*Sperp3(xx)/2)/((1.0 - 2.0*eta)*Skerrmag(xx)), 267.788*eta**3 - 126.687*eta**2 + 10.2573*eta + 1.7336, -59.1658*eta**3*chi(xx)**3 + 31.1746*eta**3*chi(xx)**2 - 27.5201*eta**3*chi(xx) + 6.16466*eta**2*chi(xx)**2 + 17.3736*eta**2*chi(xx) - 0.426958*eta*chi(xx)**3 + 2.26831*eta*chi(xx) + Kchi0(xx) + 1.43659*chi(xx)**3 - 1.38086*chi(xx)**2 - 1.62045*chi(xx), eta*K(xx) - 1, (eta*K(xx) - 2)*K(xx), -2*(Delta0(xx) + K(xx))*etaKminus1(xx), (Delta1(xx) - 4*etaKminus1(xx))*Delta1(xx)/2 - Delta0(xx)*a(xx)**2*etaKminus1(xx)**2, -2*(Delta2(xx) - etaKminus1(xx))*etaKminus1(xx) - Delta1(xx)**3/3 + Delta1(xx)**2*etaKminus1(xx) + Delta1(xx)*Delta2(xx) - Delta1(xx)*a(xx)**2*etaKminus1(xx)**2, (24*Delta2(xx)*etaKminus1(xx) + 12*Delta3(xx))*Delta1(xx)/12 + (Delta1(xx)**2 - 2*Delta2(xx))*a(xx)**2*etaKminus1(xx)**2/2 + Delta1(xx)**4/4 - 2*Delta1(xx)**3*etaKminus1(xx)/3 - Delta1(xx)**2*Delta2(xx) + Delta2(xx)**2/2 - 2*Delta3(xx)*etaKminus1(xx) + (376 - 123*pi**2/8)*etaKminus1(xx)**2/12, (128*EMgamma/5 + eta*(-221/6 + 41*pi**2/32) - (Delta1(xx)**3 - 3*Delta1(xx)*Delta2(xx) + 3*Delta3(xx))*a(xx)**2/3 + (Delta1(xx)**4 - 4*Delta1(xx)**2*Delta2(xx) + 4*Delta1(xx)*Delta3(xx) + 2*Delta2(xx)**2 - 4*Delta4(xx))/(2*etaKminus1(xx)) - (Delta1(xx)**5 - 5*Delta1(xx)**3*Delta2(xx) + 5*Delta1(xx)**2*Delta3(xx) + 5*Delta1(xx)*Delta2(xx)**2 - 5*Delta1(xx)*Delta4(xx) - 5*Delta2(xx)*Delta3(xx))/(5*etaKminus1(xx)**2) - 4237/60 + 256*log(2)/5 + 2275*pi**2/512)*etaKminus1(xx)**2, 64*etaKminus1(xx)**2/5, (((((Delta5(xx) + Delta5l(xx)*log(u(xx)))*u(xx) + Delta4(xx))*u(xx) + Delta3(xx))*u(xx) + Delta2(xx))*u(xx) + Delta1(xx))*u(xx), eta*(Delta0(xx) + log(logarg(xx) + 1)) + 1, -eta*(((((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*u(xx) + 3*Delta3(xx))*u(xx) + 2*Delta2(xx))*u(xx) + Delta1(xx))*u(xx)**2/(logarg(xx) + 1), (2*u(xx) + 1/etaKminus1(xx))/etaKminus1(xx) + a(xx)**2*u(xx)**2, -2*a(xx)**2*u(xx)**3 - 2*u(xx)**2/etaKminus1(xx), Deltaubar(xx)*Deltaucalib(xx), Deltaubar(xx)*Deltaucalibprime(xx) + Deltaubarprime(xx)*Deltaucalib(xx), 2*Deltau(xx)*r(xx) + Deltauprime(xx)*r(xx)**2, Deltau(xx)*r(xx)**2, Deltat(xx)*Dinv(xx), -Deltat(xx)*a(xx)**2*sin2theta(xx) + w2(xx)**2, sqrt(Deltar(xx)*Deltat(xx))/w2(xx), (1 - Abs(tortoise - 1))*(csi(xx) - 1) + 1, (1/2 - sign(3/2 - tortoise)/2)*(csi(xx) - 1) + 1,  ...

# %% [markdown]
# <a id='differentiate'></a>
#
# # Step 6: Differentiate with respect to `xx` \[Back to [top](#toc)\]
# $$\label{differentiate}$$
#
# Now we differentiate the right-hand expressions with respect to `xx`.  We use the SymPy $\texttt{diff}$ command, differentiating with respect to $\texttt{xx}$.  After so doing, we remove $\texttt{(xx)}$ and "Derivative" (which is output by $\texttt{diff}$), and use "prm" suffix to denote the derivative with respect to $\texttt{xx}$.

# %%
# Step 6: Use SymPy's diff function to differentiate right-hand sides with respect to xx
#   and append "prm" notation to left-hand sides
lhss_deriv = []
rhss_deriv = []
for i in range(len(rhss)):
    lhss_deriv.append(custom_parse_expr(str(lhss[i])+"prm"))
    print(sp.diff(rhss[i],xx))
    newrhs = custom_parse_expr(str(sp.diff(rhss[i],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
    rhss_deriv.append(newrhs)
# Out:
# 0
# 0
# -m1*m2*Derivative(M(xx), xx)/M(xx)**2
# Derivative(mu(xx), xx)/M(xx) - mu(xx)*Derivative(M(xx), xx)/M(xx)**2
# (x(xx)*Derivative(x(xx), xx) + y(xx)*Derivative(y(xx), xx) + z(xx)*Derivative(z(xx), xx))/sqrt(x(xx)**2 + y(xx)**2 + z(xx)**2)
# -Derivative(r(xx), xx)/r(xx)**2
# m1*Derivative(S2z(xx), xx)/m2 + m2*Derivative(S1z(xx), xx)/m1
# m1*Derivative(S2y(xx), xx)/m2 + m2*Derivative(S1y(xx), xx)/m1
# m1*Derivative(S2x(xx), xx)/m2 + m2*Derivative(S1x(xx), xx)/m1
# Derivative(S1z(xx), xx) + Derivative(S2z(xx), xx)
# Derivative(S1y(xx), xx) + Derivative(S2y(xx), xx)
# Derivative(S1x(xx), xx) + Derivative(S2x(xx), xx)
# Derivative(sigma3(xx), xx)
# Derivative(sigma2(xx), xx)
# Derivative(sigma1(xx), xx)
# (Skerr1(xx)*Derivative(Skerr1(xx), xx) + Skerr2(xx)*Derivative(Skerr2(xx), xx) + Skerr3(xx)*Derivative(Skerr3(xx), xx))/sqrt(Skerr1(xx)**2 + Skerr2(xx)**2 + Skerr3(xx)**2)
# -Skerr3(xx)*Derivative(Skerrmag(xx), xx)/Skerrmag(xx)**2 + Derivative(Skerr3(xx), xx)/Skerrmag(xx)
# -Skerr2(xx)*Derivative(Skerrmag(xx), xx)/Skerrmag(xx)**2 + Derivative(Skerr2(xx), xx)/Skerrmag(xx)
# -Skerr1(xx)*Derivative(Skerrmag(xx), xx)/Skerrmag(xx)**2 + Derivative(Skerr1(xx), xx)/Skerrmag(xx)
# Derivative(Skerrmag(xx), xx)
# -p1(xx)*Derivative(y(xx), xx) + p2(xx)*Derivative(x(xx), xx) + x(xx)*Derivative(p2(xx), xx) - y(xx)*Derivative(p1(xx), xx)
# p1(xx)*Derivative(z(xx), xx) - p3(xx)*Derivative(x(xx), xx) - x(xx)*Derivative(p3(xx), xx) + z(xx)*Derivative(p1(xx), xx)
# -p2(xx)*Derivative(z(xx), xx) + p3(xx)*Derivative(y(xx), xx) + y(xx)*Derivative(p3(xx), xx) - z(xx)*Derivative(p2(xx), xx)
# (L1(xx)*Derivative(L1(xx), xx) + L2(xx)*Derivative(L2(xx), xx) + L3(xx)*Derivative(L3(xx), xx))/sqrt(L1(xx)**2 + L2(xx)**2 + L3(xx)**2)
# -L3(xx)*Derivative(Lnorm(xx), xx)/Lnorm(xx)**2 + Derivative(L3(xx), xx)/Lnorm(xx)
# -L2(xx)*Derivative(Lnorm(xx), xx)/Lnorm(xx)**2 + Derivative(L2(xx), xx)/Lnorm(xx)
# -L1(xx)*Derivative(Lnorm(xx), xx)/Lnorm(xx)**2 + Derivative(L1(xx), xx)/Lnorm(xx)
# Lhat1(xx)*Derivative(S2x(xx), xx) + Lhat2(xx)*Derivative(S2y(xx), xx) + Lhat3(xx)*Derivative(S2z(xx), xx) + S2x(xx)*Derivative(Lhat1(xx), xx) + S2y(xx)*Derivative(Lhat2(xx), xx) + S2z(xx)*Derivative(Lhat3(xx), xx)
# Lhat1(xx)*Derivative(S1x(xx), xx) + Lhat2(xx)*Derivative(S1y(xx), xx) + Lhat3(xx)*Derivative(S1z(xx), xx) + S1x(xx)*Derivative(Lhat1(xx), xx) + S1y(xx)*Derivative(Lhat2(xx), xx) + S1z(xx)*Derivative(Lhat3(xx), xx)
# -Lhat3(xx)*Derivative(S1dotLhat(xx), xx) - S1dotLhat(xx)*Derivative(Lhat3(xx), xx) + Derivative(S1z(xx), xx)
# -Lhat2(xx)*Derivative(S1dotLhat(xx), xx) - S1dotLhat(xx)*Derivative(Lhat2(xx), xx) + Derivative(S1y(xx), xx)
# -Lhat1(xx)*Derivative(S1dotLhat(xx), xx) - S1dotLhat(xx)*Derivative(Lhat1(xx), xx) + Derivative(S1x(xx), xx)
# -Lhat3(xx)*Derivative(S2dotLhat(xx), xx) - S2dotLhat(xx)*Derivative(Lhat3(xx), xx) + Derivative(S2z(xx), xx)
# -Lhat2(xx)*Derivative(S2dotLhat(xx), xx) - S2dotLhat(xx)*Derivative(Lhat2(xx), xx) + Derivative(S2y(xx), xx)
# -Lhat1(xx)*Derivative(S2dotLhat(xx), xx) - S2dotLhat(xx)*Derivative(Lhat1(xx), xx) + Derivative(S2x(xx), xx)
# Derivative(S1perp3(xx), xx) + Derivative(S2perp3(xx), xx)
# Derivative(S1perp2(xx), xx) + Derivative(S2perp2(xx), xx)
# Derivative(S1perp1(xx), xx) + Derivative(S2perp1(xx), xx)
# Derivative(z(xx), xx)/r(xx) - z(xx)*Derivative(r(xx), xx)/r(xx)**2
# Derivative(y(xx), xx)/r(xx) - y(xx)*Derivative(r(xx), xx)/r(xx)**2
# Derivative(x(xx), xx)/r(xx) - x(xx)*Derivative(r(xx), xx)/r(xx)**2
# Derivative(Skerrhat3(xx), xx)
# Derivative(Skerrhat2(xx), xx)
# Derivative(Skerrhat1(xx), xx)
# e31(xx)*Derivative(n2(xx), xx) - e32(xx)*Derivative(n1(xx), xx) - n1(xx)*Derivative(e32(xx), xx) + n2(xx)*Derivative(e31(xx), xx)
# e31(xx)*Derivative(n3(xx), xx) + e33(xx)*Derivative(n1(xx), xx) + n1(xx)*Derivative(e33(xx), xx) + n3(xx)*Derivative(e31(xx), xx)
# e32(xx)*Derivative(n3(xx), xx) - e33(xx)*Derivative(n2(xx), xx) - n2(xx)*Derivative(e33(xx), xx) + n3(xx)*Derivative(e32(xx), xx)
# n1(xx)*Derivative(xi2(xx), xx) - n2(xx)*Derivative(xi1(xx), xx) - xi1(xx)*Derivative(n2(xx), xx) + xi2(xx)*Derivative(n1(xx), xx)
# -n1(xx)*Derivative(xi3(xx), xx) + n3(xx)*Derivative(xi1(xx), xx) + xi1(xx)*Derivative(n3(xx), xx) - xi3(xx)*Derivative(n1(xx), xx)
# n2(xx)*Derivative(xi3(xx), xx) - n3(xx)*Derivative(xi2(xx), xx) - xi2(xx)*Derivative(n3(xx), xx) + xi3(xx)*Derivative(n2(xx), xx)
# e31(xx)*Derivative(n1(xx), xx) + e32(xx)*Derivative(n2(xx), xx) + e33(xx)*Derivative(n3(xx), xx) + n1(xx)*Derivative(e31(xx), xx) + n2(xx)*Derivative(e32(xx), xx) + n3(xx)*Derivative(e33(xx), xx)
# -2*costheta(xx)*Derivative(costheta(xx), xx)
# Derivative(sin2theta(xx), xx)
# 2*a(xx)*Derivative(a(xx), xx) + 2*r(xx)*Derivative(r(xx), xx)
# 2*a(xx)**2*costheta(xx)*Derivative(costheta(xx), xx) + 2*a(xx)*costheta(xx)**2*Derivative(a(xx), xx) + 2*r(xx)*Derivative(r(xx), xx)
# (3*eta*(52 - 6*eta)*u(xx)**2*Derivative(u(xx), xx) + 12*eta*u(xx)*Derivative(u(xx), xx))/(eta*(52 - 6*eta)*u(xx)**3 + 6*eta*u(xx)**2 + 1)
# 2*a(xx)*Derivative(r(xx), xx) + 2*r(xx)*Derivative(a(xx), xx)
# (Lhat1(xx)*Derivative(Skerr1(xx), xx) + Lhat2(xx)*Derivative(Skerr2(xx), xx) + Lhat3(xx)*Derivative(Skerr3(xx), xx) + Skerr1(xx)*Derivative(Lhat1(xx), xx) + Skerr2(xx)*Derivative(Lhat2(xx), xx) + Skerr3(xx)*Derivative(Lhat3(xx), xx))/(1 - 2*eta) - (Skerr1(xx)*Sperp1(xx)/2 + Skerr2(xx)*Sperp2(xx)/2 + Skerr3(xx)*Sperp3(xx)/2)*Derivative(Skerrmag(xx), xx)/((1.0 - 2.0*eta)*Skerrmag(xx)**2) + (Skerr1(xx)*Derivative(Sperp1(xx), xx)/2 + Skerr2(xx)*Derivative(Sperp2(xx), xx)/2 + Skerr3(xx)*Derivative(Sperp3(xx), xx)/2 + Sperp1(xx)*Derivative(Skerr1(xx), xx)/2 + Sperp2(xx)*Derivative(Skerr2(xx), xx)/2 + Sperp3(xx)*Derivative(Skerr3(xx), xx)/2)/((1.0 - 2.0*eta)*Skerrmag(xx))
# 0
# -177.4974*eta**3*chi(xx)**2*Derivative(chi(xx), xx) + 62.3492*eta**3*chi(xx)*Derivative(chi(xx), xx) - 27.5201*eta**3*Derivative(chi(xx), xx) + 12.32932*eta**2*chi(xx)*Derivative(chi(xx), xx) + 17.3736*eta**2*Derivative(chi(xx), xx) - 1.280874*eta*chi(xx)**2*Derivative(chi(xx), xx) + 2.26831*eta*Derivative(chi(xx), xx) + 4.30977*chi(xx)**2*Derivative(chi(xx), xx) - 2.76172*chi(xx)*Derivative(chi(xx), xx) + Derivative(Kchi0(xx), xx) - 1.62045*Derivative(chi(xx), xx)
# eta*Derivative(K(xx), xx)
# eta*K(xx)*Derivative(K(xx), xx) + (eta*K(xx) - 2)*Derivative(K(xx), xx)
# (-2*Delta0(xx) - 2*K(xx))*Derivative(etaKminus1(xx), xx) + (-2*Derivative(Delta0(xx), xx) - 2*Derivative(K(xx), xx))*etaKminus1(xx)
# (Delta1(xx)/2 - 2*etaKminus1(xx))*Derivative(Delta1(xx), xx) + (Derivative(Delta1(xx), xx)/2 - 2*Derivative(etaKminus1(xx), xx))*Delta1(xx) - 2*Delta0(xx)*a(xx)**2*etaKminus1(xx)*Derivative(etaKminus1(xx), xx) - 2*Delta0(xx)*a(xx)*etaKminus1(xx)**2*Derivative(a(xx), xx) - a(xx)**2*etaKminus1(xx)**2*Derivative(Delta0(xx), xx)
# (-2*Delta2(xx) + 2*etaKminus1(xx))*Derivative(etaKminus1(xx), xx) + (-2*Derivative(Delta2(xx), xx) + 2*Derivative(etaKminus1(xx), xx))*etaKminus1(xx) - Delta1(xx)**2*Derivative(Delta1(xx), xx) + Delta1(xx)**2*Derivative(etaKminus1(xx), xx) - 2*Delta1(xx)*a(xx)**2*etaKminus1(xx)*Derivative(etaKminus1(xx), xx) - 2*Delta1(xx)*a(xx)*etaKminus1(xx)**2*Derivative(a(xx), xx) + 2*Delta1(xx)*etaKminus1(xx)*Derivative(Delta1(xx), xx) + Delta1(xx)*Derivative(Delta2(xx), xx) + Delta2(xx)*Derivative(Delta1(xx), xx) - a(xx)**2*etaKminus1(xx)**2*Derivative(Delta1(xx), xx)
# (2*Delta1(xx)*Derivative(Delta1(xx), xx) - 2*Derivative(Delta2(xx), xx))*a(xx)**2*etaKminus1(xx)**2/2 + (2*Delta2(xx)*etaKminus1(xx) + Delta3(xx))*Derivative(Delta1(xx), xx) + (Delta1(xx)**2 - 2*Delta2(xx))*a(xx)**2*etaKminus1(xx)*Derivative(etaKminus1(xx), xx) + (Delta1(xx)**2 - 2*Delta2(xx))*a(xx)*etaKminus1(xx)**2*Derivative(a(xx), xx) + (2*Delta2(xx)*Derivative(etaKminus1(xx), xx) + 2*etaKminus1(xx)*Derivative(Delta2(xx), xx) + Derivative(Delta3(xx), xx))*Delta1(xx) + Delta1(xx)**3*Derivative(Delta1(xx), xx) - 2*Delta1(xx)**3*Derivative(etaKminus1(xx), xx)/3 - 2*Delta1(xx)**2*etaKminus1(xx)*Derivative(Delta1(xx), xx) - Delta1(xx)**2*Derivative(Delta2(xx), xx) - 2*Delta1(xx)*Delta2(xx)*Derivative(Delta1(xx), xx) + Delta2(xx)*Derivative(Delta2(xx), xx) - 2*Delta3(xx)*Derivative(etaKminus1(xx), xx) - 2*etaKminus1(xx)*Derivative(Delta3(xx), xx) + (376 - 123*pi**2/8)*etaKminus1(xx)*Derivative(etaKminus1(xx), xx)/6
# (-2*(Delta1(xx)**3 - 3*Delta1(xx)*Delta2(xx) + 3*Delta3(xx))*a(xx)*Derivative(a(xx), xx)/3 - (3*Delta1(xx)**2*Derivative(Delta1(xx), xx) - 3*Delta1(xx)*Derivative(Delta2(xx), xx) - 3*Delta2(xx)*Derivative(Delta1(xx), xx) + 3*Derivative(Delta3(xx), xx))*a(xx)**2/3 - (Delta1(xx)**4 - 4*Delta1(xx)**2*Delta2(xx) + 4*Delta1(xx)*Delta3(xx) + 2*Delta2(xx)**2 - 4*Delta4(xx))*Derivative(etaKminus1(xx), xx)/(2*etaKminus1(xx)**2) + 2*(Delta1(xx)**5 - 5*Delta1(xx)**3*Delta2(xx) + 5*Delta1(xx)**2*Delta3(xx) + 5*Delta1(xx)*Delta2(xx)**2 - 5*Delta1(xx)*Delta4(xx) - 5*Delta2(xx)*Delta3(xx))*Derivative(etaKminus1(xx), xx)/(5*etaKminus1(xx)**3) + (4*Delta1(xx)**3*Derivative(Delta1(xx), xx) - 4*Delta1(xx)**2*Derivative(Delta2(xx), xx) - 8*Delta1(xx)*Delta2(xx)*Derivative(Delta1(xx), xx) + 4*Delta1(xx)*Derivative(Delta3(xx), xx) + 4*Delta2(xx)*Derivative(Delta2(xx), xx) + 4*Delta3(xx)*Derivative(Delta1(xx), xx) - 4*Derivative(Delta4(xx), xx))/(2*etaKminus1(xx)) - (5*Delta1(xx)**4*Derivative(Delta1(xx), xx) - 5*Delta1(xx)**3*Derivative(Delta2(xx), xx) - 15*Delta1(xx)**2*Delta2(xx)*Derivative(Delta1(xx), xx) + 5*Delta1(xx)**2*Derivative(Delta3(xx), xx) + 10*Delta1(xx)*Delta2(xx)*Derivative(Delta2(xx), xx) + 10*Delta1(xx)*Delta3(xx)*Derivative(Delta1(xx), xx) - 5*Delta1(xx)*Derivative(Delta4(xx), xx) + 5*Delta2(xx)**2*Derivative(Delta1(xx), xx) - 5*Delta2(xx)*Derivative(Delta3(xx), xx) - 5*Delta3(xx)*Derivative(Delta2(xx), xx) - 5*Delta4(xx)*Derivative(Delta1(xx), xx))/(5*etaKminus1(xx)**2))*etaKminus1(xx)**2 + 2*(128*EMgamma/5 + eta*(-221/6 + 41*pi**2/32) - (Delta1(xx)**3 - 3*Delta1(xx)*Delta2(xx) + 3*Delta3(xx))*a(xx)**2/3 + (Delta1(xx)**4 - 4*Delta1(xx)**2*Delta2(xx) + 4*Delta1(xx)*Delta3(xx) + 2*Delta2(xx)**2 - 4*Delta4(xx))/(2*etaKminus1(xx)) - (Delta1(xx)**5 - 5*Delta1(xx)**3*Delta2(xx) + 5*Delta1(xx)**2*Delta3(xx) + 5*Delta1(xx)*Delta2(xx)**2 - 5*Delta1(xx)*Delta4(xx) - 5*Delta2(xx)*Delta3(xx))/(5*etaKminus1(xx)**2) - 4237/60 + 256*log(2)/5 + 2275*pi**2/512)*etaKminus1(xx)*Derivative(etaKminus1(xx), xx)
# 128*etaKminus1(xx)*Derivative(etaKminus1(xx), xx)/5
# (((((Delta5(xx) + Delta5l(xx)*log(u(xx)))*u(xx) + Delta4(xx))*u(xx) + Delta3(xx))*u(xx) + Delta2(xx))*u(xx) + Delta1(xx))*Derivative(u(xx), xx) + (((((Delta5(xx) + Delta5l(xx)*log(u(xx)))*u(xx) + Delta4(xx))*u(xx) + Delta3(xx))*u(xx) + Delta2(xx))*Derivative(u(xx), xx) + ((((Delta5(xx) + Delta5l(xx)*log(u(xx)))*u(xx) + Delta4(xx))*u(xx) + Delta3(xx))*Derivative(u(xx), xx) + (((Delta5(xx) + Delta5l(xx)*log(u(xx)))*u(xx) + Delta4(xx))*Derivative(u(xx), xx) + ((Delta5(xx) + Delta5l(xx)*log(u(xx)))*Derivative(u(xx), xx) + (Delta5l(xx)*Derivative(u(xx), xx)/u(xx) + log(u(xx))*Derivative(Delta5l(xx), xx) + Derivative(Delta5(xx), xx))*u(xx) + Derivative(Delta4(xx), xx))*u(xx) + Derivative(Delta3(xx), xx))*u(xx) + Derivative(Delta2(xx), xx))*u(xx) + Derivative(Delta1(xx), xx))*u(xx)
# eta*(Derivative(Delta0(xx), xx) + Derivative(logarg(xx), xx)/(logarg(xx) + 1))
# -2*eta*(((((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*u(xx) + 3*Delta3(xx))*u(xx) + 2*Delta2(xx))*u(xx) + Delta1(xx))*u(xx)*Derivative(u(xx), xx)/(logarg(xx) + 1) + eta*(((((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*u(xx) + 3*Delta3(xx))*u(xx) + 2*Delta2(xx))*u(xx) + Delta1(xx))*u(xx)**2*Derivative(logarg(xx), xx)/(logarg(xx) + 1)**2 - eta*(((((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*u(xx) + 3*Delta3(xx))*u(xx) + 2*Delta2(xx))*Derivative(u(xx), xx) + ((((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*u(xx) + 3*Delta3(xx))*Derivative(u(xx), xx) + (((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*u(xx) + 4*Delta4(xx))*Derivative(u(xx), xx) + ((5*Delta5(xx) + 5*Delta5l(xx)*log(u(xx)))*Derivative(u(xx), xx) + (5*Delta5l(xx)*Derivative(u(xx), xx)/u(xx) + 5*log(u(xx))*Derivative(Delta5l(xx), xx) + 5*Derivative(Delta5(xx), xx))*u(xx) + 4*Derivative(Delta4(xx), xx))*u(xx) + 3*Derivative(Delta3(xx), xx))*u(xx) + 2*Derivative(Delta2(xx), xx))*u(xx) + Derivative(Delta1(xx), xx))*u(xx)**2/(logarg(xx) + 1)
# -(2*u(xx) + 1/etaKminus1(xx))*Derivative(etaKminus1(xx), xx)/etaKminus1(xx)**2 + (2*Derivative(u(xx), xx) - Derivative(etaKminus1(xx), xx)/etaKminus1(xx)**2)/etaKminus1(xx) + 2*a(xx)**2*u(xx)*Derivative(u(xx), xx) + 2*a(xx)*u(xx)**2*Derivative(a(xx), xx)
# -6*a(xx)**2*u(xx)**2*Derivative(u(xx), xx) - 4*a(xx)*u(xx)**3*Derivative(a(xx), xx) - 4*u(xx)*Derivative(u(xx), xx)/etaKminus1(xx) + 2*u(xx)**2*Derivative(etaKminus1(xx), xx)/etaKminus1(xx)**2
# Deltaubar(xx)*Derivative(Deltaucalib(xx), xx) + Deltaucalib(xx)*Derivative(Deltaubar(xx), xx)
# Deltaubar(xx)*Derivative(Deltaucalibprime(xx), xx) + Deltaubarprime(xx)*Derivative(Deltaucalib(xx), xx) + Deltaucalib(xx)*Derivative(Deltaubarprime(xx), xx) + Deltaucalibprime(xx)*Derivative(Deltaubar(xx), xx)
# 2*Deltau(xx)*Derivative(r(xx), xx) + 2*Deltauprime(xx)*r(xx)*Derivative(r(xx), xx) + r(xx)**2*Derivative(Deltauprime(xx), xx) + 2*r(xx)*Derivative(Deltau(xx), xx)
# 2*Deltau(xx)*r(xx)*Derivative(r(xx), xx) + r(xx)**2*Derivative(Deltau(xx), xx)
# Deltat(xx)*Derivative(Dinv(xx), xx) + Dinv(xx)*Derivative(Deltat(xx), xx)
# -Deltat(xx)*a(xx)**2*Derivative(sin2theta(xx), xx) - 2*Deltat(xx)*a(xx)*sin2theta(xx)*Derivative(a(xx), xx) - a(xx)**2*sin2theta(xx)*Derivative(Deltat(xx), xx) + 2*w2(xx)*Derivative(w2(xx), xx)
# sqrt(Deltar(xx)*Deltat(xx))*(Deltar(xx)*Derivative(Deltat(xx), xx)/2 + Deltat(xx)*Derivative(Deltar(xx), xx)/2)/(Deltar(xx)*Deltat(xx)*w2(xx)) - sqrt(Deltar(xx)*Deltat(xx))*Derivative(w2(xx), xx)/w2(xx)**2
# (1 - Abs(tortoise - 1))*Derivative(csi(xx), xx)
# (1/2 - sign(3/2 - tortoise)/2)*Derivative(csi(xx), xx)
# (n1(xx)*p1(xx) + n2(xx)*p2(xx) + n3(xx)*p3(xx))*Derivative(csi2(xx), xx) + (n1(xx)*Derivative(p1(xx), xx) + n2(xx)*Derivative(p2(xx), xx) + n3(xx)*Derivative(p3(xx), xx) + p1(xx)*Derivative(n1(xx), xx) + p2(xx)*Derivative(n2(xx), xx) + p3(xx)*Derivative(n3(xx), xx))*csi2(xx)
# (1 - 1/csi1(xx))*n3(xx)*Derivative(prT(xx), xx) + (1 - 1/csi1(xx))*prT(xx)*Derivative(n3(xx), xx) + Derivative(p3(xx), xx) + n3(xx)*prT(xx)*Derivative(csi1(xx), xx)/csi1(xx)**2
# (1 - 1/csi1(xx))*n2(xx)*Derivative(prT(xx), xx) + (1 - 1/csi1(xx))*prT(xx)*Derivative(n2(xx), xx) + Derivative(p2(xx), xx) + n2(xx)*prT(xx)*Derivative(csi1(xx), xx)/csi1(xx)**2
# (1 - 1/csi1(xx))*n1(xx)*Derivative(prT(xx), xx) + (1 - 1/csi1(xx))*prT(xx)*Derivative(n1(xx), xx) + Derivative(p1(xx), xx) + n1(xx)*prT(xx)*Derivative(csi1(xx), xx)/csi1(xx)**2
# (phat1(xx)*xi1(xx) + phat2(xx)*xi2(xx) + phat3(xx)*xi3(xx))*Derivative(r(xx), xx) + (phat1(xx)*Derivative(xi1(xx), xx) + phat2(xx)*Derivative(xi2(xx), xx) + phat3(xx)*Derivative(xi3(xx), xx) + xi1(xx)*Derivative(phat1(xx), xx) + xi2(xx)*Derivative(phat2(xx), xx) + xi3(xx)*Derivative(phat3(xx), xx))*r(xx)
# n1(xx)*Derivative(phat1(xx), xx) + n2(xx)*Derivative(phat2(xx), xx) + n3(xx)*Derivative(phat3(xx), xx) + phat1(xx)*Derivative(n1(xx), xx) + phat2(xx)*Derivative(n2(xx), xx) + phat3(xx)*Derivative(n3(xx), xx)
# (phat1(xx)*v1(xx) + phat2(xx)*v2(xx) + phat3(xx)*v3(xx))*Derivative(r(xx), xx) + (phat1(xx)*Derivative(v1(xx), xx) + phat2(xx)*Derivative(v2(xx), xx) + phat3(xx)*Derivative(v3(xx), xx) + v1(xx)*Derivative(phat1(xx), xx) + v2(xx)*Derivative(phat2(xx), xx) + v3(xx)*Derivative(phat3(xx), xx))*r(xx)
# Derivative(pdotxir(xx), xx)
# -Derivative(sin2theta(xx), xx)/(Sigma(xx)*sin2theta(xx)**2) - Derivative(Sigma(xx), xx)/(Sigma(xx)**2*sin2theta(xx))
# -Sigma(xx)*Derivative(sin2theta(xx), xx)/(Lambt(xx)*sin2theta(xx)**2) + Derivative(Sigma(xx), xx)/(Lambt(xx)*sin2theta(xx)) - Sigma(xx)*Derivative(Lambt(xx), xx)/(Lambt(xx)**2*sin2theta(xx))
# 2*Deltar(xx)*pdotn(xx)*Derivative(pdotn(xx), xx)/Sigma(xx) - Deltar(xx)*pdotn(xx)**2*Derivative(Sigma(xx), xx)/Sigma(xx)**2 + pdotn(xx)**2*Derivative(Deltar(xx), xx)/Sigma(xx)
# 2*Qcoeff1(xx)*pdotxir(xx)*Derivative(pdotxir(xx), xx) + 2*Qcoeff2(xx)*pdotvr(xx)*Derivative(pdotvr(xx), xx) + pdotvr(xx)**2*Derivative(Qcoeff2(xx), xx) + pdotxir(xx)**2*Derivative(Qcoeff1(xx), xx) + Derivative(DrSipn2(xx), xx)
# Derivative(Q(xx), xx)
# Derivative(Deltar(xx), xx)/(2*sqrt(Deltar(xx)))
# Derivative(Sigma(xx), xx)
# Derivative(exp2mu(xx), xx)/(2*sqrt(exp2mu(xx)))
# (sqrt(Deltar(xx))*Deltatprime(xx) - 2*Deltat(xx))*(-Deltar(xx)*Derivative(Deltat(xx), xx)/2 - Deltat(xx)*Derivative(Deltar(xx), xx)/2)/(2*sqrt(Deltar(xx)*Deltat(xx))*Deltar(xx)*Deltat(xx)) + (sqrt(Deltar(xx))*Derivative(Deltatprime(xx), xx) - 2*Derivative(Deltat(xx), xx) + Deltatprime(xx)*Derivative(Deltar(xx), xx)/(2*sqrt(Deltar(xx))))/(2*sqrt(Deltar(xx)*Deltat(xx)))
# Derivative(Deltat(xx), xx)/(2*sqrt(Deltat(xx)))
# Deltat(xx)*Derivative(Sigma(xx), xx)/Lambt(xx) - Deltat(xx)*Sigma(xx)*Derivative(Lambt(xx), xx)/Lambt(xx)**2 + Sigma(xx)*Derivative(Deltat(xx), xx)/Lambt(xx)
# Derivative(exp2nu(xx), xx)/(2*sqrt(exp2nu(xx)))
# Derivative(omegatilde(xx), xx)/Lambt(xx) - omegatilde(xx)*Derivative(Lambt(xx), xx)/Lambt(xx)**2
# 2*Derivative(a(xx), xx)
# (8*a(xx)*Derivative(a(xx), xx) + 8*r(xx)*Derivative(r(xx), xx))*r(xx) + (4*a(xx)**2 + 4*r(xx)**2)*Derivative(r(xx), xx) - 2*Deltatprime(xx)*a(xx)**2*Derivative(sin2theta(xx), xx) - 4*Deltatprime(xx)*a(xx)*sin2theta(xx)*Derivative(a(xx), xx) - 2*a(xx)**2*sin2theta(xx)*Derivative(Deltatprime(xx), xx)
# a(xx)**2*Derivative(costheta(xx), xx)/Sigma(xx) + 2*a(xx)*costheta(xx)*Derivative(a(xx), xx)/Sigma(xx) - a(xx)**2*costheta(xx)*Derivative(Sigma(xx), xx)/Sigma(xx)**2
# (-Deltat(xx) + w2(xx))*a(xx)**2*costheta(xx)*Derivative(w2(xx), xx)/(Lambt(xx)*Sigma(xx)) + (-Deltat(xx) + w2(xx))*a(xx)**2*w2(xx)*Derivative(costheta(xx), xx)/(Lambt(xx)*Sigma(xx)) + 2*(-Deltat(xx) + w2(xx))*a(xx)*costheta(xx)*w2(xx)*Derivative(a(xx), xx)/(Lambt(xx)*Sigma(xx)) - (-Deltat(xx) + w2(xx))*a(xx)**2*costheta(xx)*w2(xx)*Derivative(Sigma(xx), xx)/(Lambt(xx)*Sigma(xx)**2) - (-Deltat(xx) + w2(xx))*a(xx)**2*costheta(xx)*w2(xx)*Derivative(Lambt(xx), xx)/(Lambt(xx)**2*Sigma(xx)) + (-Derivative(Deltat(xx), xx) + Derivative(w2(xx), xx))*a(xx)**2*costheta(xx)*w2(xx)/(Lambt(xx)*Sigma(xx))
# -2*Deltat(xx)*a(xx)**2*costheta(xx)*Derivative(omegatilde(xx), xx)/Lambt(xx)**2 - 2*Deltat(xx)*a(xx)**2*omegatilde(xx)*Derivative(costheta(xx), xx)/Lambt(xx)**2 - 4*Deltat(xx)*a(xx)*costheta(xx)*omegatilde(xx)*Derivative(a(xx), xx)/Lambt(xx)**2 + 4*Deltat(xx)*a(xx)**2*costheta(xx)*omegatilde(xx)*Derivative(Lambt(xx), xx)/Lambt(xx)**3 - 2*a(xx)**2*costheta(xx)*omegatilde(xx)*Derivative(Deltat(xx), xx)/Lambt(xx)**2
# Derivative(r(xx), xx)/Sigma(xx) - r(xx)*Derivative(Sigma(xx), xx)/Sigma(xx)**2 + Derivative(Deltar(xx), xx)/(2*Deltar(xx)**(3/2))
# (-4*Deltat(xx)*r(xx) + Deltatprime(xx)*w2(xx))*Derivative(w2(xx), xx)/(2*Deltat(xx)*Lambt(xx)) - (-4*Deltat(xx)*r(xx) + Deltatprime(xx)*w2(xx))*w2(xx)*Derivative(Lambt(xx), xx)/(2*Deltat(xx)*Lambt(xx)**2) - (-4*Deltat(xx)*r(xx) + Deltatprime(xx)*w2(xx))*w2(xx)*Derivative(Deltat(xx), xx)/(2*Deltat(xx)**2*Lambt(xx)) + (-4*Deltat(xx)*Derivative(r(xx), xx) + Deltatprime(xx)*Derivative(w2(xx), xx) - 4*r(xx)*Derivative(Deltat(xx), xx) + w2(xx)*Derivative(Deltatprime(xx), xx))*w2(xx)/(2*Deltat(xx)*Lambt(xx)) + Derivative(r(xx), xx)/Sigma(xx) - r(xx)*Derivative(Sigma(xx), xx)/Sigma(xx)**2
# -2*(Lambt(xx)*omegatildeprime(xx) - Lambtprime(xx)*omegatilde(xx))*Derivative(Lambt(xx), xx)/Lambt(xx)**3 + (Lambt(xx)*Derivative(omegatildeprime(xx), xx) - Lambtprime(xx)*Derivative(omegatilde(xx), xx) - omegatilde(xx)*Derivative(Lambtprime(xx), xx) + omegatildeprime(xx)*Derivative(Lambt(xx), xx))/Lambt(xx)**2
# 442.443*eta**2*chi(xx)**2*Derivative(chi(xx), xx) + 2495.29*eta**2*Derivative(chi(xx), xx) - 1705.953*eta*chi(xx)**2*Derivative(chi(xx), xx) - 686.626*eta*chi(xx)*Derivative(chi(xx), xx) + 198.5961*chi(xx)**2*Derivative(chi(xx), xx)
# 3*eta*dSO(xx)*u(xx)**2*Derivative(u(xx), xx) + eta*u(xx)**3*Derivative(dSO(xx), xx)
# -eta*(eta*(((810*DrSipn2(xx)**2 - 234*DrSipn2(xx)*Qminus1(xx))*r(xx) - 882*DrSipn2(xx) + 204*Qminus1(xx))*r(xx) - 336) + ((36*DrSipn2(xx)*Qminus1(xx) - 45*Qminus1(xx)**2)*r(xx) - 96*DrSipn2(xx) - 436*Qminus1(xx))*r(xx) - 896)*Derivative(r(xx), xx)/(72*r(xx)**3) + eta*(eta*(((810*DrSipn2(xx)**2 - 234*DrSipn2(xx)*Qminus1(xx))*r(xx) - 882*DrSipn2(xx) + 204*Qminus1(xx))*Derivative(r(xx), xx) + ((810*DrSipn2(xx)**2 - 234*DrSipn2(xx)*Qminus1(xx))*Derivative(r(xx), xx) + (1620*DrSipn2(xx)*Derivative(DrSipn2(xx), xx) - 234*DrSipn2(xx)*Derivative(Qminus1(xx), xx) - 234*Qminus1(xx)*Derivative(DrSipn2(xx), xx))*r(xx) - 882*Derivative(DrSipn2(xx), xx) + 204*Derivative(Qminus1(xx), xx))*r(xx)) + ((36*DrSipn2(xx)*Qminus1(xx) - 45*Qminus1(xx)**2)*r(xx) - 96*DrSipn2(xx) - 436*Qminus1(xx))*Derivative(r(xx), xx) + ((36*DrSipn2(xx)*Qminus1(xx) - 45*Qminus1(xx)**2)*Derivative(r(xx), xx) + (36*DrSipn2(xx)*Derivative(Qminus1(xx), xx) + 36*Qminus1(xx)*Derivative(DrSipn2(xx), xx) - 90*Qminus1(xx)*Derivative(Qminus1(xx), xx))*r(xx) - 96*Derivative(DrSipn2(xx), xx) - 436*Derivative(Qminus1(xx), xx))*r(xx))/(144*r(xx)**2)
# eta*(-36*Derivative(DrSipn2(xx), xx) + 3*Derivative(Qminus1(xx), xx) + 8*Derivative(r(xx), xx)/r(xx)**2)/12
# Derivative(sigmacoeffTerm1(xx), xx) + Derivative(sigmacoeffTerm2(xx), xx) + Derivative(sigmacoeffTerm3(xx), xx)
# -eta*(eta*((((-126*DrSipn2(xx) - 3*Qminus1(xx))*Qminus1(xx) + 360*DrSipn2(xx)**2)*r(xx) - 324*DrSipn2(xx) + 120*Qminus1(xx))*r(xx) - 54) + ((96*DrSipn2(xx) - 23*Qminus1(xx))*Qminus1(xx)*r(xx) + 282*DrSipn2(xx) - 206*Qminus1(xx))*r(xx) + 706)*Derivative(r(xx), xx)/(36*r(xx)**3) + eta*(eta*((((-126*DrSipn2(xx) - 3*Qminus1(xx))*Qminus1(xx) + 360*DrSipn2(xx)**2)*r(xx) - 324*DrSipn2(xx) + 120*Qminus1(xx))*Derivative(r(xx), xx) + (((-126*DrSipn2(xx) - 3*Qminus1(xx))*Qminus1(xx) + 360*DrSipn2(xx)**2)*Derivative(r(xx), xx) + ((-126*DrSipn2(xx) - 3*Qminus1(xx))*Derivative(Qminus1(xx), xx) + (-126*Derivative(DrSipn2(xx), xx) - 3*Derivative(Qminus1(xx), xx))*Qminus1(xx) + 720*DrSipn2(xx)*Derivative(DrSipn2(xx), xx))*r(xx) - 324*Derivative(DrSipn2(xx), xx) + 120*Derivative(Qminus1(xx), xx))*r(xx)) + ((96*DrSipn2(xx) - 23*Qminus1(xx))*Qminus1(xx)*r(xx) + 282*DrSipn2(xx) - 206*Qminus1(xx))*Derivative(r(xx), xx) + ((96*DrSipn2(xx) - 23*Qminus1(xx))*Qminus1(xx)*Derivative(r(xx), xx) + (96*DrSipn2(xx) - 23*Qminus1(xx))*r(xx)*Derivative(Qminus1(xx), xx) + (96*Derivative(DrSipn2(xx), xx) - 23*Derivative(Qminus1(xx), xx))*Qminus1(xx)*r(xx) + 282*Derivative(DrSipn2(xx), xx) - 206*Derivative(Qminus1(xx), xx))*r(xx))/(72*r(xx)**2)
# eta*(-30*Derivative(DrSipn2(xx), xx) + 4*Derivative(Qminus1(xx), xx) - 14*Derivative(r(xx), xx)/r(xx)**2)/12
# Derivative(sigmastarcoeffTerm1(xx), xx) + Derivative(sigmastarcoeffTerm2(xx), xx)
# sigma3(xx)*Derivative(sigmacoeff(xx), xx) + sigmacoeff(xx)*Derivative(sigma3(xx), xx) + sigmastar3(xx)*Derivative(sigmastarcoeff(xx), xx) + sigmastarcoeff(xx)*Derivative(sigmastar3(xx), xx)
# sigma2(xx)*Derivative(sigmacoeff(xx), xx) + sigmacoeff(xx)*Derivative(sigma2(xx), xx) + sigmastar2(xx)*Derivative(sigmastarcoeff(xx), xx) + sigmastarcoeff(xx)*Derivative(sigmastar2(xx), xx)
# sigma1(xx)*Derivative(sigmacoeff(xx), xx) + sigmacoeff(xx)*Derivative(sigma1(xx), xx) + sigmastar1(xx)*Derivative(sigmastarcoeff(xx), xx) + sigmastarcoeff(xx)*Derivative(sigmastar1(xx), xx)
# Derivative(Deltasigmastar3(xx), xx) + Derivative(sigmastar3(xx), xx)
# Derivative(Deltasigmastar2(xx), xx) + Derivative(sigmastar2(xx), xx)
# Derivative(Deltasigmastar1(xx), xx) + Derivative(sigmastar1(xx), xx)
# Derivative(Sstar3(xx), xx)
# Derivative(Sstar2(xx), xx)
# Derivative(Sstar1(xx), xx)
# Sstar1(xx)*Derivative(n1(xx), xx) + Sstar2(xx)*Derivative(n2(xx), xx) + Sstar3(xx)*Derivative(n3(xx), xx) + n1(xx)*Derivative(Sstar1(xx), xx) + n2(xx)*Derivative(Sstar2(xx), xx) + n3(xx)*Derivative(Sstar3(xx), xx)
# S1(xx)*Derivative(Skerrhat1(xx), xx) + S2(xx)*Derivative(Skerrhat2(xx), xx) + S3(xx)*Derivative(Skerrhat3(xx), xx) + Skerrhat1(xx)*Derivative(S1(xx), xx) + Skerrhat2(xx)*Derivative(S2(xx), xx) + Skerrhat3(xx)*Derivative(S3(xx), xx)
# S1(xx)*Derivative(n1(xx), xx) + S2(xx)*Derivative(n2(xx), xx) + S3(xx)*Derivative(n3(xx), xx) + n1(xx)*Derivative(S1(xx), xx) + n2(xx)*Derivative(S2(xx), xx) + n3(xx)*Derivative(S3(xx), xx)
# S1(xx)*Derivative(v1(xx), xx) + S2(xx)*Derivative(v2(xx), xx) + S3(xx)*Derivative(v3(xx), xx) + v1(xx)*Derivative(S1(xx), xx) + v2(xx)*Derivative(S2(xx), xx) + v3(xx)*Derivative(S3(xx), xx)
# S1(xx)*Derivative(xi1(xx), xx) + S2(xx)*Derivative(xi2(xx), xx) + S3(xx)*Derivative(xi3(xx), xx) + xi1(xx)*Derivative(S1(xx), xx) + xi2(xx)*Derivative(S2(xx), xx) + xi3(xx)*Derivative(S3(xx), xx)
# 6*Sstardotn(xx)*Derivative(Sstardotn(xx), xx)
# 2*Sstar1(xx)*Derivative(Sstar1(xx), xx) + 2*Sstar2(xx)*Derivative(Sstar2(xx), xx) + 2*Sstar3(xx)*Derivative(Sstar3(xx), xx)
# Derivative(HdsumTerm1(xx), xx) - Derivative(HdsumTerm2(xx), xx)
# -3*Derivative(r(xx), xx)/(2*r(xx)**4)
# 4*eta*(4 - 3*eta)*prT(xx)**4*u(xx)*Derivative(u(xx), xx) + 8*eta*(4 - 3*eta)*prT(xx)**3*u(xx)**2*Derivative(prT(xx), xx)
# 2*Deltar(xx)*pdotn(xx)*Derivative(pdotn(xx), xx)/Sigma(xx) - Deltar(xx)*pdotn(xx)**2*Derivative(Sigma(xx), xx)/Sigma(xx)**2 + pdotn(xx)**2*Derivative(Deltar(xx), xx)/Sigma(xx) - pdotvr(xx)**2*Derivative(sin2theta(xx), xx)/(Sigma(xx)*sin2theta(xx)**2) + 2*pdotvr(xx)*Derivative(pdotvr(xx), xx)/(Sigma(xx)*sin2theta(xx)) - pdotvr(xx)**2*Derivative(Sigma(xx), xx)/(Sigma(xx)**2*sin2theta(xx)) - Sigma(xx)*pdotxir(xx)**2*Derivative(sin2theta(xx), xx)/(Lambt(xx)*sin2theta(xx)**2) + 2*Sigma(xx)*pdotxir(xx)*Derivative(pdotxir(xx), xx)/(Lambt(xx)*sin2theta(xx)) + pdotxir(xx)**2*Derivative(Sigma(xx), xx)/(Lambt(xx)*sin2theta(xx)) - Sigma(xx)*pdotxir(xx)**2*Derivative(Lambt(xx), xx)/(Lambt(xx)**2*sin2theta(xx))
# Derivative(Q4(xx), xx) + Derivative(gammappsum(xx), xx)
# sqrt(Deltat(xx)*Sigma(xx)/Lambt(xx))*(Deltat(xx)*Derivative(Sigma(xx), xx)/(2*Lambt(xx)) - Deltat(xx)*Sigma(xx)*Derivative(Lambt(xx), xx)/(2*Lambt(xx)**2) + Sigma(xx)*Derivative(Deltat(xx), xx)/(2*Lambt(xx)))*Lambt(xx)/(Deltat(xx)*Sigma(xx))
# omegatilde(xx)*Derivative(pphi(xx), xx)/Lambt(xx) + pphi(xx)*Derivative(omegatilde(xx), xx)/Lambt(xx) - omegatilde(xx)*pphi(xx)*Derivative(Lambt(xx), xx)/Lambt(xx)**2
# 2*((-Jtilde(xx)*Sdotv(xx)*pdotn(xx) + Sdotn(xx)*pdotvr(xx))*pdotvr(xx) - (sqrt(Q(xx)) + Q(xx))*Sdotn(xx)*exp2mu(xx)*xisq(xx))*Btilde(xx)*Derivative(Btilde(xx), xx) + (Btilde(xx)*Jtilde(xx)*Sdotxi(xx)*pdotn(xx) - Sdotn(xx)*expmu(xx)*expnu(xx)*pdotxir(xx))*expmu(xx)*expnu(xx)*Derivative(pdotxir(xx), xx) + (Btilde(xx)*Jtilde(xx)*Sdotxi(xx)*pdotn(xx) - Sdotn(xx)*expmu(xx)*expnu(xx)*pdotxir(xx))*expmu(xx)*pdotxir(xx)*Derivative(expnu(xx), xx) + (Btilde(xx)*Jtilde(xx)*Sdotxi(xx)*pdotn(xx) - Sdotn(xx)*expmu(xx)*expnu(xx)*pdotxir(xx))*expnu(xx)*pdotxir(xx)*Derivative(expmu(xx), xx) + ((-Jtilde(xx)*Sdotv(xx)*pdotn(xx) + Sdotn(xx)*pdotvr(xx))*Derivative(pdotvr(xx), xx) + (-sqrt(Q(xx)) - Q(xx))*Sdotn(xx)*exp2mu(xx)*Derivative(xisq(xx), xx) + (-sqrt(Q(xx)) - Q(xx))*Sdotn(xx)*xisq(xx)*Derivative(exp2mu(xx), xx) + (-sqrt(Q(xx)) - Q(xx))*exp2mu(xx)*xisq(xx)*Derivative(Sdotn(xx), xx) + (-Derivative(Q(xx), xx) - Derivative(Q(xx), xx)/(2*sqrt(Q(xx))))*Sdotn(xx)*exp2mu(xx)*xisq(xx) + (-Jtilde(xx)*Sdotv(xx)*Derivative(pdotn(xx), xx) - Jtilde(xx)*pdotn(xx)*Derivative(Sdotv(xx), xx) + Sdotn(xx)*Derivative(pdotvr(xx), xx) - Sdotv(xx)*pdotn(xx)*Derivative(Jtilde(xx), xx) + pdotvr(xx)*Derivative(Sdotn(xx), xx))*pdotvr(xx))*Btilde(xx)**2 + (Btilde(xx)*Jtilde(xx)*Sdotxi(xx)*Derivative(pdotn(xx), xx) + Btilde(xx)*Jtilde(xx)*pdotn(xx)*Derivative(Sdotxi(xx), xx) + Btilde(xx)*Sdotxi(xx)*pdotn(xx)*Derivative(Jtilde(xx), xx) + Jtilde(xx)*Sdotxi(xx)*pdotn(xx)*Derivative(Btilde(xx), xx) - Sdotn(xx)*expmu(xx)*expnu(xx)*Derivative(pdotxir(xx), xx) - Sdotn(xx)*expmu(xx)*pdotxir(xx)*Derivative(expnu(xx), xx) - Sdotn(xx)*expnu(xx)*pdotxir(xx)*Derivative(expmu(xx), xx) - expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Sdotn(xx), xx))*expmu(xx)*expnu(xx)*pdotxir(xx)
# Derivative(omegacostheta(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)) - omegacostheta(xx)*Derivative(expnu(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)**2) - omegacostheta(xx)*Derivative(expmu(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)**2*expnu(xx)) - omegacostheta(xx)*Derivative(exp2mu(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)**2*expmu(xx)*expnu(xx)) - omegacostheta(xx)*Derivative(Btilde(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)**2*exp2mu(xx)*expmu(xx)*expnu(xx)) + (-Derivative(Q(xx), xx) - Derivative(Q(xx), xx)/(2*sqrt(Q(xx))))*omegacostheta(xx)/(2*(sqrt(Q(xx)) + Q(xx))**2*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx))
# ((-Jtilde(xx)*Sdotv(xx)*pdotn(xx) + Sdotn(xx)*pdotvr(xx))*Jtilde(xx)*pdotn(xx) + (sqrt(Q(xx)) + Q(xx))*Sdotv(xx)*exp2mu(xx))*Btilde(xx)**2*Derivative(xisq(xx), xx) + 2*((-Jtilde(xx)*Sdotv(xx)*pdotn(xx) + Sdotn(xx)*pdotvr(xx))*Jtilde(xx)*pdotn(xx) + (sqrt(Q(xx)) + Q(xx))*Sdotv(xx)*exp2mu(xx))*Btilde(xx)*xisq(xx)*Derivative(Btilde(xx), xx) + (-Btilde(xx)*Sdotxi(xx)*expnu(xx)*pdotvr(xx) + Sdotv(xx)*exp2nu(xx)*expmu(xx)*pdotxir(xx))*expmu(xx)*Derivative(pdotxir(xx), xx) + (-Btilde(xx)*Sdotxi(xx)*expnu(xx)*pdotvr(xx) + Sdotv(xx)*exp2nu(xx)*expmu(xx)*pdotxir(xx))*pdotxir(xx)*Derivative(expmu(xx), xx) + ((-Jtilde(xx)*Sdotv(xx)*pdotn(xx) + Sdotn(xx)*pdotvr(xx))*Jtilde(xx)*Derivative(pdotn(xx), xx) + (-Jtilde(xx)*Sdotv(xx)*pdotn(xx) + Sdotn(xx)*pdotvr(xx))*pdotn(xx)*Derivative(Jtilde(xx), xx) + (sqrt(Q(xx)) + Q(xx))*Sdotv(xx)*Derivative(exp2mu(xx), xx) + (sqrt(Q(xx)) + Q(xx))*exp2mu(xx)*Derivative(Sdotv(xx), xx) + (Derivative(Q(xx), xx) + Derivative(Q(xx), xx)/(2*sqrt(Q(xx))))*Sdotv(xx)*exp2mu(xx) + (-Jtilde(xx)*Sdotv(xx)*Derivative(pdotn(xx), xx) - Jtilde(xx)*pdotn(xx)*Derivative(Sdotv(xx), xx) + Sdotn(xx)*Derivative(pdotvr(xx), xx) - Sdotv(xx)*pdotn(xx)*Derivative(Jtilde(xx), xx) + pdotvr(xx)*Derivative(Sdotn(xx), xx))*Jtilde(xx)*pdotn(xx))*Btilde(xx)**2*xisq(xx) + (-Btilde(xx)*Sdotxi(xx)*expnu(xx)*Derivative(pdotvr(xx), xx) - Btilde(xx)*Sdotxi(xx)*pdotvr(xx)*Derivative(expnu(xx), xx) - Btilde(xx)*expnu(xx)*pdotvr(xx)*Derivative(Sdotxi(xx), xx) + Sdotv(xx)*exp2nu(xx)*expmu(xx)*Derivative(pdotxir(xx), xx) + Sdotv(xx)*exp2nu(xx)*pdotxir(xx)*Derivative(expmu(xx), xx) + Sdotv(xx)*expmu(xx)*pdotxir(xx)*Derivative(exp2nu(xx), xx) - Sdotxi(xx)*expnu(xx)*pdotvr(xx)*Derivative(Btilde(xx), xx) + exp2nu(xx)*expmu(xx)*pdotxir(xx)*Derivative(Sdotv(xx), xx))*expmu(xx)*pdotxir(xx)
# -Jtilde(xx)*omegar(xx)*Derivative(xisq(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)*xisq(xx)**2) + Jtilde(xx)*Derivative(omegar(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)*xisq(xx)) - Jtilde(xx)*omegar(xx)*Derivative(expnu(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)**2*xisq(xx)) - Jtilde(xx)*omegar(xx)*Derivative(expmu(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)**2*expnu(xx)*xisq(xx)) - Jtilde(xx)*omegar(xx)*Derivative(exp2mu(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)**2*expmu(xx)*expnu(xx)*xisq(xx)) + omegar(xx)*Derivative(Jtilde(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)*xisq(xx)) - Jtilde(xx)*omegar(xx)*Derivative(Btilde(xx), xx)/(2*(sqrt(Q(xx)) + Q(xx))*Btilde(xx)**2*exp2mu(xx)*expmu(xx)*expnu(xx)*xisq(xx)) + (-Derivative(Q(xx), xx) - Derivative(Q(xx), xx)/(2*sqrt(Q(xx))))*Jtilde(xx)*omegar(xx)/(2*(sqrt(Q(xx)) + Q(xx))**2*Btilde(xx)*exp2mu(xx)*expmu(xx)*expnu(xx)*xisq(xx))
# SdotSkerrhat(xx)*Derivative(omega(xx), xx) + omega(xx)*Derivative(SdotSkerrhat(xx), xx)
# HssTerm2(xx)*Derivative(HssTerm2coeff(xx), xx) + HssTerm2coeff(xx)*Derivative(HssTerm2(xx), xx) + HssTerm3(xx)*Derivative(HssTerm3coeff(xx), xx) + HssTerm3coeff(xx)*Derivative(HssTerm3(xx), xx) + Derivative(HssTerm1(xx), xx)
# (sqrt(Q(xx)) + 1)*Brtilde(xx)*Jtilde(xx)*Sdotv(xx)*expmu(xx)*expnu(xx)*Derivative(pdotxir(xx), xx) + (sqrt(Q(xx)) + 1)*Brtilde(xx)*Jtilde(xx)*Sdotv(xx)*expmu(xx)*pdotxir(xx)*Derivative(expnu(xx), xx) + (sqrt(Q(xx)) + 1)*Brtilde(xx)*Jtilde(xx)*Sdotv(xx)*expnu(xx)*pdotxir(xx)*Derivative(expmu(xx), xx) + (sqrt(Q(xx)) + 1)*Brtilde(xx)*Jtilde(xx)*expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Sdotv(xx), xx) + (sqrt(Q(xx)) + 1)*Brtilde(xx)*Sdotv(xx)*expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Jtilde(xx), xx) + (sqrt(Q(xx)) + 1)*Jtilde(xx)*Sdotv(xx)*expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Brtilde(xx), xx) + Brtilde(xx)*Jtilde(xx)*Sdotv(xx)*expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Q(xx), xx)/(2*sqrt(Q(xx)))
# (Jtilde(xx)*Sdotv(xx)*nur(xx) - Sdotn(xx)*nucostheta(xx)*xisq(xx))*(2*sqrt(Q(xx)) + 1)*Btilde(xx)*expmu(xx)*expnu(xx)*Derivative(pdotxir(xx), xx) + (Jtilde(xx)*Sdotv(xx)*nur(xx) - Sdotn(xx)*nucostheta(xx)*xisq(xx))*(2*sqrt(Q(xx)) + 1)*Btilde(xx)*expmu(xx)*pdotxir(xx)*Derivative(expnu(xx), xx) + (Jtilde(xx)*Sdotv(xx)*nur(xx) - Sdotn(xx)*nucostheta(xx)*xisq(xx))*(2*sqrt(Q(xx)) + 1)*Btilde(xx)*expnu(xx)*pdotxir(xx)*Derivative(expmu(xx), xx) + (Jtilde(xx)*Sdotv(xx)*nur(xx) - Sdotn(xx)*nucostheta(xx)*xisq(xx))*(2*sqrt(Q(xx)) + 1)*expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Btilde(xx), xx) + (Jtilde(xx)*Sdotv(xx)*nur(xx) - Sdotn(xx)*nucostheta(xx)*xisq(xx))*Btilde(xx)*expmu(xx)*expnu(xx)*pdotxir(xx)*Derivative(Q(xx), xx)/sqrt(Q(xx)) + (2*sqrt(Q(xx)) + 1)*(Jtilde(xx)*Sdotv(xx)*Derivative(nur(xx), xx) + Jtilde(xx)*nur(xx)*Derivative(Sdotv(xx), xx) - Sdotn(xx)*nucostheta(xx)*Derivative(xisq(xx), xx) - Sdotn(xx)*xisq(xx)*Derivative(nucostheta(xx), xx) + Sdotv(xx)*nur(xx)*Derivative(Jtilde(xx), xx) - nucostheta(xx)*xisq(xx)*Derivative(Sdotn(xx), xx))*Btilde(xx)*expmu(xx)*expnu(xx)*pdotxir(xx)
# (-((mucostheta(xx) - nucostheta(xx))*pdotn(xx)*xisq(xx) + nur(xx)*pdotvr(xx))*sqrt(Q(xx)) + (sqrt(Q(xx)) + 1)*mur(xx)*pdotvr(xx) - mucostheta(xx)*pdotn(xx)*xisq(xx))*Btilde(xx)**2*Jtilde(xx)*Derivative(Sdotxi(xx), xx) + (-((mucostheta(xx) - nucostheta(xx))*pdotn(xx)*xisq(xx) + nur(xx)*pdotvr(xx))*sqrt(Q(xx)) + (sqrt(Q(xx)) + 1)*mur(xx)*pdotvr(xx) - mucostheta(xx)*pdotn(xx)*xisq(xx))*Btilde(xx)**2*Sdotxi(xx)*Derivative(Jtilde(xx), xx) + 2*(-((mucostheta(xx) - nucostheta(xx))*pdotn(xx)*xisq(xx) + nur(xx)*pdotvr(xx))*sqrt(Q(xx)) + (sqrt(Q(xx)) + 1)*mur(xx)*pdotvr(xx) - mucostheta(xx)*pdotn(xx)*xisq(xx))*Btilde(xx)*Jtilde(xx)*Sdotxi(xx)*Derivative(Btilde(xx), xx) + (-((mucostheta(xx) - nucostheta(xx))*pdotn(xx)*xisq(xx) + nur(xx)*pdotvr(xx))*Derivative(Q(xx), xx)/(2*sqrt(Q(xx))) + (sqrt(Q(xx)) + 1)*mur(xx)*Derivative(pdotvr(xx), xx) + (sqrt(Q(xx)) + 1)*pdotvr(xx)*Derivative(mur(xx), xx) - ((mucostheta(xx) - nucostheta(xx))*pdotn(xx)*Derivative(xisq(xx), xx) + (mucostheta(xx) - nucostheta(xx))*xisq(xx)*Derivative(pdotn(xx), xx) + (Derivative(mucostheta(xx), xx) - Derivative(nucostheta(xx), xx))*pdotn(xx)*xisq(xx) + nur(xx)*Derivative(pdotvr(xx), xx) + pdotvr(xx)*Derivative(nur(xx), xx))*sqrt(Q(xx)) - mucostheta(xx)*pdotn(xx)*Derivative(xisq(xx), xx) - mucostheta(xx)*xisq(xx)*Derivative(pdotn(xx), xx) - pdotn(xx)*xisq(xx)*Derivative(mucostheta(xx), xx) + mur(xx)*pdotvr(xx)*Derivative(Q(xx), xx)/(2*sqrt(Q(xx))))*Btilde(xx)**2*Jtilde(xx)*Sdotxi(xx)
# Derivative(HsoTerm2a(xx), xx) + Derivative(HsoTerm2b(xx), xx) - Derivative(HsoTerm2c(xx), xx)
# -expnu(xx)*Derivative(xisq(xx), xx)/((sqrt(Q(xx)) + Q(xx))*Btilde(xx)**2*exp2mu(xx)*xisq(xx)**2) + Derivative(expnu(xx), xx)/((sqrt(Q(xx)) + Q(xx))*Btilde(xx)**2*exp2mu(xx)*xisq(xx)) - expnu(xx)*Derivative(exp2mu(xx), xx)/((sqrt(Q(xx)) + Q(xx))*Btilde(xx)**2*exp2mu(xx)**2*xisq(xx)) - 2*expnu(xx)*Derivative(Btilde(xx), xx)/((sqrt(Q(xx)) + Q(xx))*Btilde(xx)**3*exp2mu(xx)*xisq(xx)) + (-Derivative(Q(xx), xx) - Derivative(Q(xx), xx)/(2*sqrt(Q(xx))))*expnu(xx)/((sqrt(Q(xx)) + Q(xx))**2*Btilde(xx)**2*exp2mu(xx)*xisq(xx))
# -(-Btilde(xx) + expmu(xx)*expnu(xx))*SdotSkerrhat(xx)*exp2nu(xx)*pdotxir(xx)*Derivative(xisq(xx), xx)/(Btilde(xx)**2*sqrt(Q(xx))*expmu(xx)*xisq(xx)**2) + (-Btilde(xx) + expmu(xx)*expnu(xx))*SdotSkerrhat(xx)*exp2nu(xx)*Derivative(pdotxir(xx), xx)/(Btilde(xx)**2*sqrt(Q(xx))*expmu(xx)*xisq(xx)) - (-Btilde(xx) + expmu(xx)*expnu(xx))*SdotSkerrhat(xx)*exp2nu(xx)*pdotxir(xx)*Derivative(expmu(xx), xx)/(Btilde(xx)**2*sqrt(Q(xx))*expmu(xx)**2*xisq(xx)) + (-Btilde(xx) + expmu(xx)*expnu(xx))*SdotSkerrhat(xx)*pdotxir(xx)*Derivative(exp2nu(xx), xx)/(Btilde(xx)**2*sqrt(Q(xx))*expmu(xx)*xisq(xx)) + (-Btilde(xx) + expmu(xx)*expnu(xx))*exp2nu(xx)*pdotxir(xx)*Derivative(SdotSkerrhat(xx), xx)/(Btilde(xx)**2*sqrt(Q(xx))*expmu(xx)*xisq(xx)) - (-Btilde(xx) + expmu(xx)*expnu(xx))*SdotSkerrhat(xx)*exp2nu(xx)*pdotxir(xx)*Derivative(Q(xx), xx)/(2*Btilde(xx)**2*Q(xx)**(3/2)*expmu(xx)*xisq(xx)) - 2*(-Btilde(xx) + expmu(xx)*expnu(xx))*SdotSkerrhat(xx)*exp2nu(xx)*pdotxir(xx)*Derivative(Btilde(xx), xx)/(Btilde(xx)**3*sqrt(Q(xx))*expmu(xx)*xisq(xx)) + (expmu(xx)*Derivative(expnu(xx), xx) + expnu(xx)*Derivative(expmu(xx), xx) - Derivative(Btilde(xx), xx))*SdotSkerrhat(xx)*exp2nu(xx)*pdotxir(xx)/(Btilde(xx)**2*sqrt(Q(xx))*expmu(xx)*xisq(xx))
# HsoTerm2(xx)*Derivative(HsoTerm2coeff(xx), xx) + HsoTerm2coeff(xx)*Derivative(HsoTerm2(xx), xx) + Derivative(HsoTerm1(xx), xx)
# Hdcoeff(xx)*Derivative(Hdsum(xx), xx) + Hdsum(xx)*Derivative(Hdcoeff(xx), xx)
# sqrt(Hnsradicand(xx))*Derivative(alpha(xx), xx) + Derivative(betapsum(xx), xx) + alpha(xx)*Derivative(Hnsradicand(xx), xx)/(2*sqrt(Hnsradicand(xx)))
# Derivative(Hso(xx), xx) + Derivative(Hss(xx), xx)
# 2323.56*eta**3*chi(xx)*Derivative(chi(xx), xx) + 1585.533*eta**2*chi(xx)**2*Derivative(chi(xx), xx) - 652.65*eta**2*chi(xx)*Derivative(chi(xx), xx) - 123.0009*eta*chi(xx)**2*Derivative(chi(xx), xx) + 37.1964*eta*Derivative(chi(xx), xx)
# eta*(2*S1x(xx)*Derivative(S1x(xx), xx) + 2*S1y(xx)*Derivative(S1y(xx), xx) + 2*S1z(xx)*Derivative(S1z(xx), xx) + 2*S2x(xx)*Derivative(S2x(xx), xx) + 2*S2y(xx)*Derivative(S2y(xx), xx) + 2*S2z(xx)*Derivative(S2z(xx), xx))*dSS(xx)*u(xx)**4 + 4*eta*(S1x(xx)**2 + S1y(xx)**2 + S1z(xx)**2 + S2x(xx)**2 + S2y(xx)**2 + S2z(xx)**2)*dSS(xx)*u(xx)**3*Derivative(u(xx), xx) + eta*(S1x(xx)**2 + S1y(xx)**2 + S1z(xx)**2 + S2x(xx)**2 + S2y(xx)**2 + S2z(xx)**2)*u(xx)**4*Derivative(dSS(xx), xx) - Derivative(Hd(xx), xx) + Derivative(Hns(xx), xx) + Derivative(Hs(xx), xx)
# eta*Derivative(Heff(xx), xx)/sqrt(2*eta*(Heff(xx) - 1) + 1)

# %% [markdown]
# <a id='remove_zeros'></a>
#
# # Step 7: Remove derivatives (of constants) that evaluate to zero, simplifying derivative expressions \[Back to [top](#toc)\]
# $$\label{remove_zeros}$$
#
# We declare a function to simply the derivative expressions.  In particular, we want to remove terms equal to zero.

# %%
# Step 7.a: Define derivative simplification function
def simplify_deriv(lhss_deriv,rhss_deriv):
    # Copy expressions into another array
    lhss_deriv_simp = []
    rhss_deriv_simp = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_simp.append(lhss_deriv[i])
        rhss_deriv_simp.append(rhss_deriv[i])
    # If a right-hand side is 0, substitute value 0 for the corresponding left-hand side in later terms
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == 0:
            for j in range(i+1,len(rhss_deriv_simp)):
                for var in rhss_deriv_simp[j].free_symbols:
                    if str(var) == str(lhss_deriv_simp[i]):
                        rhss_deriv_simp[j] = rhss_deriv_simp[j].subs(var,0)
    zero_elements_to_remove = []
    # Create array of indices for expressions that are zero
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == sp.sympify(0):
            zero_elements_to_remove.append(i)

    # When removing terms that are zero, we need to take into account their new index (after each removal)
    count = 0
    for i in range(len(zero_elements_to_remove)):
        del lhss_deriv_simp[zero_elements_to_remove[i]+count]
        del rhss_deriv_simp[zero_elements_to_remove[i]+count]
        count -= 1
    return lhss_deriv_simp,rhss_deriv_simp

# Step 7.b: Call the simplication function and then copy results
lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv,rhss_deriv)
lhss_deriv = lhss_deriv_simp
rhss_deriv = rhss_deriv_simp

# %% [markdown]
# <a id='partial_derivative'></a>
#
# # Step 8: Simplify derivatives with respect to a specific variable \[Back to [top](#toc)\]
# $$\label{partial_derivative}$$
#
# In [Step 6](#differentiate) we took a generic derivative of each expression, assuming all variables were functions of `xx`.  We now define a function that will select a specific dynamic variable (element of `dynamic_variables`) and set the derivative of the variable to 1 and all others to 0.

# %%
# Step 8.a: Define onevar derivative function
def deriv_onevar(lhss_deriv,rhss_deriv,variable_list,index):
    # Denote each variable with prm
    variableprm_list = []
    for variable in variable_list:
        variableprm_list.append(str(variable)+"prm")

    # Copy expressions into another array
    lhss_deriv_new = []
    rhss_deriv_new = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_new.append(lhss_deriv[i])
        rhss_deriv_new.append(rhss_deriv[i])
    # For each free symbol's derivative, replace it with:
    #   1, if we are differentiating with respect to the variable, or
    #   0, if we are note differentiating with respect to that variable
    for i in range(len(rhss_deriv_new)):
        for var in variableprm_list:
            if variableprm_list.index(str(var))==index:
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,1)
            else:
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var,0)
    # Simplify derivative expressions again
    lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv_new,rhss_deriv_new)
    return lhss_deriv_simp,rhss_deriv_simp

# Step 8.b: Call the derivative function and populate dictionaries with the result
lhss_derivative = {}
rhss_derivative = {}
for index in range(len(dynamic_variables)):
    lhss_temp,rhss_temp = deriv_onevar(lhss_deriv,rhss_deriv,dynamic_variables,index)
    lhss_derivative[dynamic_variables[index]] = lhss_temp
    rhss_derivative[dynamic_variables[index]] = rhss_temp

# %% [markdown]
# <a id='store_results'></a>
#
# # Step 9: Store partial derivatives to SymPy notebook `partial_derivatives.txt-VALIDATION.txt` \[Back to [top](#toc)\]
# $$\label{store_results}$$
#
# We write the resulting derivatives in SymPy syntax.  Each partial derivative is output in its own file, in a similar format to the input expressions.

# %%
# Step 9: Output original expression and each partial derivative expression in SymPy snytax
with open(os.path.join(inputdir,'partial_derivatives.txt-VALIDATION'), 'w') as output:
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(")
        output.write(str(lr[i].lhs)+" = "+right_side_in_sp)
    for var in dynamic_variables:
        for i in range(len(lhss_derivative[var])):
            right_side = str(rhss_derivative[var][i])
            right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
                                                "prm_"+str(var))
            output.write(str(lhss_derivative[var][i]).replace("prm","prm_"+str(var))+" = "+right_side_in_sp+"\n")

# %% [markdown]
# <a id='code_validation'></a>
#
# # Step 10: Validate against LALSuite and trusted `SEOBNR_Derivative_Routine` NRPy+ module \[Back to [top](#toc)\]
# $$\label{code_validation}$$
#
# We validate the output of this notebook against known LALSuite values of the Hamiltonian partial derivatives and the output of the `SEOBNR_Derivative_Routine` NRPy+ module.  We note that due to cancellations in the deriavtive terms, various versions of SymPy may result in relative errors that differ as much as an order of magnitude.  Furthermore, even changing the set of input pararameters can affect the relative error by as many as two orders of magnitude.  Therefore we look for agreement with LALSuite to at least 10 significant digits.
#
# When comparing the notebook output to that of the NRPy+ module, we compare term-by-term using SymPy to check that each right-hand side side is equivalent.

# %%
# Numerically evaluate right-hand sides using input values
def evaluate_expression(left_sides,right_sides,input_values):
    new_right_sides = []
    for i in range(len(right_sides)):
        term = custom_parse_expr(str(right_sides[i]).replace("(xx)",""))
        # Only look for the free variables in each expression to reduce computation time
        free_vars = term.free_symbols
        for variable in free_vars:
            term = term.subs(variable, input_values[str(variable)])
        # Evaluate each term to reduce computation time
        new_right_sides.append(sp.sympify(term.evalf()))
        # Store each subexpression in values numerically
        input_values[str(left_sides[i])] = new_right_sides[i]
    # Return the input values dictionary with all numerical right-hand added
    return input_values

# %%
##hard validation against lalsuite integration
import numpy as np

Derivativedir = 'Derivatives'
var_index = ['x', 'y', 'z', 'p1', 'p2', 'p3', 'S1x', 'S1y', 'S1z', 'S2x', 'S2y', 'S2z']

for index in range(1):
    validationfile = 'outputv4Pindex'+str(index)+'.txt'
    validationfile_pert = 'outputv4Pindex'+str(index)+'pert.txt'
    with open(os.path.join(Derivativedir,validationfile)) as file1, open(os.path.join(Derivativedir,validationfile_pert)) as file2:
        file1_lines = file1.readlines()
        file2_lines = file2.readlines()
        for i in range(len(file2_lines)//3):
            valuepairs = file1_lines[3*i].strip('{}\n').split(',')
            valuepairspert = file2_lines[3*i].strip('{}\n').split(',')
            derivpairs = file1_lines[3*i+1].strip('{}\n').split(',')
            derivpairspert = file2_lines[3*i+1].strip('{}\n').split(',')
            values = dict()
            derivs = dict()
            valuespert = dict()
            derivspert = dict()
            for j in range(len(valuepairs)):
                pair = valuepairs[j].split(': ')
                pairpert = valuepairspert[j].split(': ')
                values[pair[0].strip(" ''")] = float(pair[1])
                valuespert[pairpert[0].strip(" ''")] = float(pairpert[1])
            for j in range(len(derivpairs)):
                pair = derivpairs[j].split(': ')
                pairpert = derivpairspert[j].split(': ')
                derivs[pair[0].strip(" ''")] = float(pair[1])
                derivspert[pairpert[0].strip(" ''")] = float(pairpert[1]) 
            values = evaluate_expression(lhss,rhss,values)
            eta = values['eta']
            #Hreal = values['Hreal']
            #LAL_Hreal = derivs['Hreal']
            #LAL_Hreal_pert = derivspert['Hreal']
            #Erel = abs((Hreal-LAL_Hreal)/LAL_Hreal)
            #Erelpert = abs((LAL_Hreal-LAL_Hreal_pert)/LAL_Hreal)
            #if Erel > Erelpert:
            #    print("Line %d: Erel in Hamiltonian is %.2e, allowed is %.2e"%(i,Erel,Erelpert))
            for k in range(len(var_index)):
                values = evaluate_expression(lhss_derivative[dynamic_variables[k]],rhss_derivative[dynamic_variables[k]],values)
                Hrealprm = values['Hrealprm']
                if var_index[k][0] != 'S':
                    Hrealprm /= eta
                LAL_Hrealprm = derivs['dHreal_d'+var_index[k]]
                LAL_Hreal_pertprm = derivspert['dHreal_d'+var_index[k]]
                Erel = abs((Hrealprm-LAL_Hrealprm)/LAL_Hrealprm)
                Erelpert = abs((LAL_Hrealprm-LAL_Hreal_pertprm)/LAL_Hrealprm)
                if Erel > 10*Erelpert:
                    print("Line %d: Erel in %s derivative is %.2e, allowed is %.2e"%(i,var_index[k],Erel,Erelpert))
                    if Erel > 1:
                        print(var_index[k])
                        valuekeys = list(values.keys())
                        valueterms = list(values.values())
                        for l in range(len(valuekeys)):
                            print(valuekeys[l]," : ",valueterms[l])
                        sys.exit(1)
# Out:
# Line 0: Erel in y derivative is 1.33e-03, allowed is 2.11e-05
# Line 0: Erel in z derivative is 1.53e+03, allowed is 1.01e-07
# z
# m1  :  23.0
# m2  :  10.0
# x  :  21.24407241358192
# y  :  0.0
# z  :  0.0
# S1x  :  0.004857667584940312
# S1y  :  -0.009715335169880624
# S1z  :  -0.014573002754820936
# S2x  :  0.0036730945821854912
# S2y  :  -0.004591368227731864
# S2z  :  0.005509641873278237
# p1  :  0.0
# p2  :  0.21696072000958128
# p3  :  0.001
# tortoise  :  1.0
# EMgamma  :  0.577215664901533
# M  :  33.0000000000000
# mu  :  6.96969696969697
# eta  :  0.211202938475666
# r  :  21.2440724135819
# u  :  0.0470719540270759
# sigmastar3  :  0.00633608815426997
# sigmastar2  :  -0.0147842056932966
# sigmastar1  :  0.0105601469237833
# sigma3  :  -0.00906336088154270
# sigma2  :  -0.0143067033976125
# sigma1  :  0.00853076216712580
# Skerr3  :  -0.00906336088154270
# Skerr2  :  -0.0143067033976125
# Skerr1  :  0.00853076216712580
# Skerrmag  :  0.0189631267392379
# Skerrhat3  :  -0.477946543635606
# Skerrhat2  :  -0.754448546083358
# Skerrhat1  :  0.449860525873838
# a  :  0.0189631267392379
# L3  :  4.60912924678642
# L2  :  -0.0212440724135819
# L1  :  0
# Lnorm  :  4.60917820486414
# Lhat3  :  0.999989378133032
# Lhat2  :  -0.00460908028922872
# Lhat1  :  0
# S2dotLhat  :  0.00553074533539425
# S1dotLhat  :  -0.0145280692024896
# S1perp3  :  -4.50878675497153e-5
# S1perp2  :  -0.00978229620728237
# S1perp1  :  0.00485766758494031
# S2perp3  :  -2.10447152748207e-5
# S2perp2  :  -0.00456587657842175
# S2perp1  :  0.00367309458218549
# Sperp3  :  -6.61325828245360e-5
# Sperp2  :  -0.0143481727857041
# Sperp1  :  0.00853076216712580
# n3  :  0
# n2  :  0
# n1  :  1.00000000000000
# e33  :  -0.477946543635606
# e32  :  -0.754448546083358
# e31  :  0.449860525873838
# xi3  :  0.754448546083357
# xi2  :  -0.477946543635606
# xi1  :  0
# v3  :  -0.477946543635606
# v2  :  -0.754448546083357
# v1  :  0
# costheta  :  0.449860525873838
# sin2theta  :  0.797625507260514
# xisq  :  0.797625507260514
# w2  :  451.310972313688
# Sigma  :  451.310685487416
# Dinv  :  1.00391774845226
# omegatilde  :  0.805708075272604
# chi  :  -0.00285704832456787
# Kchi0  :  0.771732667895071
# K  :  0.773513578479020
# etaKminus1  :  -0.836631659274404
# Delta0  :  -1.42065952711320
# Delta1  :  -1.08284557759705
# Delta2  :  -1.22525092784356
# Delta3  :  0.119003317202021
# Delta4  :  12.7541839296632
# Delta5  :  19.5805008739413
# Delta5l  :  8.95939242624309
# logarg  :  -0.0536133022848030
# Deltaucalib  :  0.688314401913981
# Deltaucalibprime  :  0.000589565636452168
# Deltaubar  :  1.31614179516757
# Deltaubarprime  :  0.00529680523617960
# Deltau  :  0.905919352574756
# Deltauprime  :  0.00442181930332507
# Deltatprime  :  40.4864466330188
# Deltat  :  408.851018079542
# Deltar  :  410.452793522829
# Lambt  :  203681.476461513
# csi  :  0.907691476710035
# csi1  :  0.907691476710035
# csi2  :  1.00000000000000
# prT  :  0
# phat3  :  0.00100000000000000
# phat2  :  0.216960720009581
# phat1  :  0
# pdotxir  :  -2.18688983312603
# pdotn  :  0
# pdotvr  :  -3.48750438993111
# pphi  :  -2.18688983312603
# Qcoeff2  :  0.00277795591849152
# Qcoeff1  :  0.00277795398688792
# DrSipn2  :  0
# Q  :  1.04707293719869
# Qminus1  :  0.0470729371986869
# Jtilde  :  20.2596345851259
# exp2mu  :  451.310685487416
# expmu  :  21.2440741263868
# Brtilde  :  0.00309846370982059
# Btilde  :  20.2200647397466
# exp2nu  :  0.905918576579897
# expnu  :  0.951797550206921
# omega  :  3.95572581891043e-6
# omegatildeprime  :  0.0379262534784758
# Lambtprime  :  38350.7086823511
# mucostheta  :  3.58444701974630e-7
# nucostheta  :  3.37229877791677e-8
# omegacostheta  :  -2.56902013760768e-12
# mur  :  -0.00228728537954503
# nur  :  0.00244055659692128
# omegar  :  -5.58610615979661e-7
# dSO  :  -44.8509991160567
# sigmacoeffTerm3  :  -0.000988004127530963
# sigmacoeffTerm2  :  -0.00456566340914119
# sigmacoeffTerm1  :  -0.00414233767544580
# sigmacoeff  :  -0.00969600521211796
# sigmastarcoeffTerm2  :  0.00318679930965077
# sigmastarcoeffTerm1  :  0.0149126717317092
# sigmastarcoeff  :  0.0180994710413600
# Deltasigmastar3  :  0.000202558238410458
# Deltasigmastar2  :  -0.000128868432103855
# Deltasigmastar1  :  0.000108418759003732
# Sstar3  :  0.00653864639268043
# Sstar2  :  -0.0149130741254005
# Sstar1  :  0.0106685656827870
# S3  :  0.00653864639268043
# S2  :  -0.0149130741254005
# S1  :  0.0106685656827870
# Sstardotn  :  0.0106685656827870
# SdotSkerrhat  :  0.0129253902164828
# Sdotn  :  0.0106685656827870
# Sdotv  :  0.00812602364810468
# Sdotxi  :  0.0120607244975277
# HdsumTerm2  :  0.000341454881183823
# HdsumTerm1  :  0.000378971970246142
# Hdsum  :  3.75170890623197e-5
# Hdcoeff  :  5.21502848604147e-5
# Q4  :  0
# gammappsum  :  0.0470729371986869
# Hnsradicand  :  1.04707293719869
# alpha  :  0.951797550206921
# betapsum  :  -8.65073657600937e-6
# HssTerm3  :  -3218.58565297430
# HssTerm3coeff  :  -3.36244780806825e-18
# HssTerm2  :  2454.32998308712
# HssTerm2coeff  :  -1.85707653424622e-11
# HssTerm1  :  5.11292997988334e-8
# Hss  :  5.55052443227949e-9
# HsoTerm2c  :  -0.0456371320773124
# HsoTerm2b  :  -1.09444966801384
# HsoTerm2a  :  2.48243169250343
# HsoTerm2  :  1.43361915656691
# HsoTerm2coeff  :  3.12365770284989e-6
# HsoTerm1  :  2.53930355188574e-11
# Hso  :  4.47816091439890e-6
# Hd  :  1.95652688173352e-9
# Hns  :  0.973933249400371
# Hs  :  4.48371143883118e-6
# dSS  :  5.09683998580384
# Heff  :  0.973937733244390
# Hreal  :  0.994480339351039
# rprm  :  0
# uprm  :  0
# L3prm  :  0
# L2prm  :  0
# Lnormprm  :  0
# Lhat3prm  :  0
# Lhat2prm  :  0
# Lhat1prm  :  -0.0470714540350423
# S2dotLhatprm  :  -0.000172897902791707
# S1dotLhatprm  :  -0.000228657476442033
# S1perp3prm  :  0.000228655047672737
# S1perp2prm  :  -1.05390066765375e-6
# S1perp1prm  :  -0.000683857341682903
# S2perp3prm  :  0.000172896066293185
# S2perp2prm  :  -7.96900315806241e-7
# S2perp1prm  :  0.000260340224834535
# Sperp3prm  :  0.000401551113965921
# Sperp2prm  :  -1.85080098345999e-6
# Sperp1prm  :  -0.000423517116848368
# n3prm  :  0.0470719540270759
# n2prm  :  0
# n1prm  :  0
# xi3prm  :  0
# xi2prm  :  0.0211758139925295
# xi1prm  :  -0.0355133672770301
# v3prm  :  0.0211758139925295
# v2prm  :  0
# v1prm  :  0.0224978777294151
# costhetaprm  :  -0.0224978777294151
# sin2thetaprm  :  0.0202418142127999
# xisqprm  :  0.0202418142127999
# w2prm  :  0
# Sigmaprm  :  -7.27895994798448e-6
# Dinvprm  :  0
# omegatildeprm  :  0
# chiprm  :  -0.00102507797172623
# Kprm  :  0.000636579589534958
# etaKminus1prm  :  0.000134447479883416
# Delta0prm  :  -0.00106516527650570
# Delta1prm  :  -0.000543122425041928
# Delta2prm  :  -2.93442201462828e-5
# Delta3prm  :  0.000338128609258832
# Delta4prm  :  -0.00366168386261949
# Delta5prm  :  -0.0159091610288984
# Delta5lprm  :  -0.00287956526541119
# logargprm  :  -2.56152072728628e-5
# Deltaucalibprm  :  -0.000230682523139652
# Deltaucalibprimeprm  :  2.85621245779602e-7
# Deltaubarprm  :  0.000441093388753904
# Deltaubarprimeprm  :  8.51213545235590e-7
# Deltauprm  :  2.19495487324001e-11
# Deltauprimeprm  :  -6.29053741524702e-12
# Deltatprimeprm  :  -1.90639068973930e-9
# Deltatprm  :  9.90606428720457e-9
# Deltarprm  :  9.94487375523378e-9
# Lambtprm  :  -0.00297601018813498
# csiprm  :  2.19924855842916e-11
# csi1prm  :  2.19924855842916e-11
# csi2prm  :  0
# prTprm  :  4.70719540270759e-5
# phat3prm  :  0
# phat2prm  :  0
# phat1prm  :  -4.78702585195757e-6
# pdotxirprm  :  0.0976020635974767
# pdotnprm  :  4.22849281751184e-5
# pdotvrprm  :  0.000449860525873838
# pphiprm  :  0.0976020635974767
# Qcoeff2prm  :  -7.04977854201036e-5
# Qcoeff1prm  :  -7.04977854201344e-5
# DrSipn2prm  :  0
# Qprm  :  -0.00238919441744482
# Qminus1prm  :  -0.00238919441744482
# Jtildeprm  :  2.45435664534025e-10
# exp2muprm  :  -7.27895994798448e-6
# expmuprm  :  -1.71317420205747e-7
# Brtildeprm  :  -5.92694538941785e-11
# Btildeprm  :  2.44956295014532e-10
# exp2nuprm  :  -1.35268343441760e-9
# expnuprm  :  -7.10594093315078e-10
# omegaprm  :  5.77975009954844e-14
# Lambtprimeprm  :  -0.000589398445862304
# mucosthetaprm  :  -1.79260948966268e-8
# nucosthetaprm  :  -1.68651203937628e-9
# omegacosthetaprm  :  1.28478636857315e-13
# murprm  :  7.59797387904581e-10
# nurprm  :  1.03554734174383e-10
# omegarprm  :  -7.59768332674455e-15
# dSOprm  :  -0.114521473717344
# sigmacoeffTerm3prm  :  -2.52274622536017e-6
# sigmacoeffTerm2prm  :  7.96568647935664e-5
# sigmacoeffTerm1prm  :  -0.000126151220388501
# sigmacoeffprm  :  -4.90171018202943e-5
# sigmastarcoeffTerm2prm  :  7.51918819177182e-5
# sigmastarcoeffTerm1prm  :  -0.000168201627184667
# sigmastarcoeffprm  :  -9.30097452669493e-5
# Deltasigmastar3prm  :  -1.45058262052934e-7
# Deltasigmastar2prm  :  2.07634834266122e-6
# Deltasigmastar1prm  :  -1.40034981311336e-6
# Sstar3prm  :  -1.45058262052934e-7
# Sstar2prm  :  2.07634834266122e-6
# Sstar1prm  :  -1.40034981311336e-6
# S3prm  :  -1.45058262052934e-7
# S2prm  :  2.07634834266122e-6
# S1prm  :  -1.40034981311336e-6
# Sstardotnprm  :  0.000306386512582446
# SdotSkerrhatprm  :  -2.12712999664387e-6
# Sdotnprm  :  0.000306386512582446
# Sdotvprm  :  0.000376984078160591
# Sdotxiprm  :  -0.000695774997656881
# HdsumTerm2prm  :  1.96122278028352e-5
# HdsumTerm1prm  :  -9.37058907724770e-8
# Hdsumprm  :  -1.97059336936077e-5
# Hdcoeffprm  :  0
# Q4prm  :  0
# gammappsumprm  :  -0.00238919441744482
# Hnsradicandprm  :  -0.00238919441744482
# alphaprm  :  -7.10594093315078e-10
# betapsumprm  :  3.86086876554709e-7
# HssTerm3prm  :  -167.496651159930
# HssTerm3coeffprm  :  1.62382128433885e-19
# HssTerm2prm  :  176.613223423320
# HssTerm2coeffprm  :  4.39377903265241e-13
# HssTerm1prm  :  -8.41359599264909e-12
# Hssprm  :  -2.20987792211519e-9
# HsoTerm2cprm  :  -5.40629692358912e-5
# HsoTerm2bprm  :  -0.00108932875140495
# HsoTerm2aprm  :  -0.145453518690012
# HsoTerm2prm  :  -0.146488784472181
# HsoTerm2coeffprm  :  -7.39047363683707e-8
# HsoTerm1prm  :  -1.10851270616867e-12
# Hsoprm  :  -5.63533174329075e-7
# Hdprm  :  -1.02767005556209e-9
# Hnsprm  :  -0.00111077722886031
# Hsprm  :  -5.65743052251190e-7
# dSSprm  :  -0.00807452715282067
# Heffprm  :  -0.00111134194755212
# Hrealprm  :  -0.000236021443246877
# L1prm  :  -0.216960720009581
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
print("Printing difference between notebook output and trusted NRPy+ module output...")
# Open the files to compare
file = 'partial_derivatives.txt'
outfile = 'partial_derivatives.txt-VALIDATION'
outputdir = 'Derivatives'
print("Checking file " + outfile)
with open(os.path.join(outputdir,file), "r") as file1, open(os.path.join(outputdir,outfile), "r") as file2:
    # Read the lines of each file
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()
    # Compare right-hand sides of the expressions by computing the difference between them
    num_diffs = 0
    for i in range(len(file1_lines)):
        expr_new = custom_parse_expr(file1_lines[i].split("=")[1].replace("sp.",""))
        expr_validated = custom_parse_expr(file2_lines[i].split("=")[1].replace("sp.",""))
        difference = sp.simplify(expr_new - expr_validated)
        if difference != 0:
            num_diffs += 1
            print(difference)
    if num_diffs == 0:
        print("No difference. TEST PASSED!")
    else:
        print("ERROR: Disagreement found with the trusted file. See differences above.")
        sys.exit(1)
# Out:
# Printing difference between notebook output and trusted NRPy+ module output...
# Checking file partial_derivatives.txt-VALIDATION
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-ec6e61985944> in <module>
#       5 outputdir = 'Derivatives'
#       6 print("Checking file " + outfile)
# ----> 7 with open(os.path.join(outputdir,file), "r") as file1, open(os.path.join(outputdir,outfile), "r") as file2:
#       8     # Read the lines of each file
#       9     file1_lines = file1.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Derivatives\\partial_derivatives.txt'

# %% [markdown]
# <a id='latex_pdf_output'></a>
#
# # Step 11: Output this notebook to $\LaTeX$-formatted PDF file \[Back to [top](#toc)\]
# $$\label{latex_pdf_output}$$
#
# The following code cell converts this Jupyter notebook into a proper, clickable $\LaTeX$-formatted PDF file. After the cell is successfully run, the generated PDF may be found in the root NRPy+ tutorial directory, with filename
# [Tutorial-SEOBNR_Derivative_Routine.pdf](Tutorial-SEOBNR_Derivative_Routine.pdf) (Note that clicking on this link may not work; you may need to open the PDF file through another means.)

# %%
import cmdline_helper as cmd      # NRPy+: Multi-platform Python command-line interface

cmd.output_Jupyter_notebook_to_LaTeXed_PDF("Tutorial-SEOBNR_Derivative_Routine")
