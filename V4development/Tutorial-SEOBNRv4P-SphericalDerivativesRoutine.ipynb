# %% [markdown]
# # Symbolic Partial Derivative Routine
#
# ## Authors: Zach Etienne, Tyler Knowles & Siddharth Mahesh
#
# ## This module contains a routine for computing partial derivatives of a mathematical expression that is written as several subexpressions.
#
# **Notebook Status:** <font color='green'><b> Validated </b></font>
#
# **Validation Notes:** This tutorial notebook has been confirmed to be self-consistent with its corresponding NRPy+ module, as documented [below](#code_validation). Additionally, this notebook has been validated by checking that results are consistent with exact derivative expressions used in the SEOBNRv3_opt approixment of [LALSuite](https://git.ligo.org/lscsoft/lalsuite).
#
# ### NRPy+ Source Code for this module: [SEOBNR_Derivative_Routine.py](../edit/SEOBNR/SEOBNR_Derivative_Routine.py)
#
# ## Introduction
# $$\label{intro}$$
#
# This notebook documents the symbolic partial derivative routine used to generate analytic derivatives of the [SEOBNRv3](https://git.ligo.org/lscsoft/lalsuite) Hamiltonian (documented [here](../Tutorial-SEOBNR_v3_Hamiltonian.ipynb)) and described in [this article](https://arxiv.org/abs/1803.06346).  In general, this notebook takes as input a file of inter-dependent mathematical expressions (in SymPy syntax), a file listing the names of values within those expressions, and a file listing all variables with which to take partial derivatives of each expression.  The output is a text file containing the original expression and those for each partial derivative computation.  The intention is to perform CSE on these expressions to create efficient partial derivative code!

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# This notebook is organized as follows
#
# 1. [Step 1](#initializenrpy): Initialize core Python/NRPy+ modules
# 1. [Step 2:](#read_expressions) Read in Hamiltonian expressions from `Sympy_Hreal_on_Bottom.txt`
# 1. [Step 3:](#list_constants) Specify constants and variables in Hamiltonian expression
# 1. [Step 4:](#list_free_symbols) Extract free symbols
# 1. [Step 5:](#convert_to_func) Convert variables to function notation; e.g., `var` goes to `var(xx)`
# 1. [Step 6:](#differentiate) Differentiate with respect to `xx`
# 1. [Step 7:](#remove_zeros) Remove derivatives (of constants) that evaluate to zero, simplifying derivative expressions
# 1. [Step 8:](#store_results) Store partial derivatives to SymPy notebook `partial_derivatives.txt-VALIDATION.txt`
# 1. [Step 9:](#numpy_function) Create numpy function to output exact derivatives for all 12 dynamic variables
# 1. [Step 10:](#code_validation) Validate against LALSuite and trusted `SEOBNR_Derivative_Routine` NRPy+ module
# 1. [Step 11:](#spherical_orbit) Spherical Orbit Test
# 1. [Step 11:](#latex_pdf_output) Output this notebook to $\LaTeX$-formatted PDF file

# %% [markdown]
# <a id='initializenrpy'></a>
#
# # Step 1: Initialize core Python/NRPy+ modules \[Back to [top](#toc)\]
# $$\label{initializenrpy}$$
#
# Let's start by importing all the needed modules from Python/NRPy+ and creating the output directory (if it does not already exist). Note that since the expression 'Q' appears in the Hamiltonian and is a protected symbol in sympy we must create a new global dictionary to ensure that sympy does not spit out errors.

# %%
# Step 1.a: import all needed modules from Python/NRPy+:
import sympy as sp                # SymPy: The Python computer algebra package upon which NRPy+ depends
import sys, os     # Standard Python modules for multiplatform OS-level functions
sys.path.append('../')

from outputC import superfast_uniq, lhrh, outputC      # Remove duplicate entries from a Python array; store left- and right-
                                              #   hand sides of mathematical expressions
                                              #   create optimized C expressions

# As of April 2021, "sp.sympify("Q+1")" fails because Q is a reserved keyword.
#   This is the workaround, courtesy Ken Sible.
custom_global_dict = {}
exec('from sympy import *', custom_global_dict)
del custom_global_dict['Q']

# Step 1.b: Check for a sufficiently new version of SymPy (for validation)
# Ignore the rc's and b's for release candidates & betas.
sympy_version = sp.__version__.replace('rc', '...').replace('b', '...')
sympy_version_decimal = float(int(sympy_version.split(".")[0]) + int(sympy_version.split(".")[1])/10.0)
print(sympy_version_decimal)
if sympy_version_decimal > 1.2:
    custom_parse_expr = lambda expr: sp.parse_expr(expr, global_dict=custom_global_dict)
else:
    custom_parse_expr = lambda expr: sp.sympify(expr)

if sympy_version_decimal < 1.2:
    print('Error: NRPy+ does not support SymPy < 1.2')
    sys.exit(1)

# Step 1.c: Name of the directory containing the input file
inputdir = "Hamiltonian"
# Out:
# 1.8

# %% [markdown]
# <a id='read_expressions'></a>
#
# # Step 2: Read in Hamiltonian expressions from `Sympy_Hreal_on_Bottom.txt` \[Back to [top](#toc)\]
# $$\label{read_expressions}$$
#
# We read in the expressions of which we will compute partial derivatives in a single large string before splitting the string by line (carriage return) and by "=".  Doing so allows us to manipulate the right- and left-hand sides of the expressions appropriately.  We store the left- and right-hand sides in the array `lr`, which consists of `lhrh` arrays with left-hand sides `lhs` and right-hand sides `rhs`.  Note that `Lambda` is a protected keyword in Python, so the variable $\Lambda$ in the Hamiltonian is renamed `Lamb`.

# %%
# Step 2.a: Read in expressions as a (single) string
with open(os.path.join(inputdir,'Sympy_Hreal_on_Bottom.txt'), 'r') as file:
#with open(os.path.join(inputdir,'lalcomparev4P.txt'),'r') as file:
    expressions_as_lines = file.readlines()

#print(expressions_as_lines)
# Step 2.b: Create and populate the "lr" array, which separates each line into left- and right-hand sides
#   Each entry is a string of the form lhrh(lhs='',rhs='')
lr = []

for i in range(len(expressions_as_lines)):
    # Ignore lines with 2 or fewer characters and those starting with #
    if len(expressions_as_lines[i]) > 2 and expressions_as_lines[i][0] != "#":
        # Split each line by its equals sign
        split_line = expressions_as_lines[i].split("=")
        #print(split_line)
        # Append the line to "lr", removing spaces, "sp." prefixes, and replacing Lambda->Lamb
        #   (Lambda is a protected keyword):
        lr.append(lhrh(lhs=split_line[0].replace(" ","").replace("Lambda","Lamb"),
                       rhs=split_line[1].replace(" ","").replace("sp.","").replace("Lambda","Lamb")))

# Step 2.c: Separate and sympify right- and left-hand sides into separate arrays
lhss = []
rhss = []
for i in range(len(lr)):
    #print(lr[i].rhs)
    #print(lr[i].rhs)
    lhss.append(custom_parse_expr(lr[i].lhs))
    rhss.append(custom_parse_expr(lr[i].rhs))

print(lhss)
# Out:
# [EMgamma, M, mu, eta, r, u, sigmastar3, sigmastar2, sigmastar1, sigma3, sigma2, sigma1, Skerr3, Skerr2, Skerr1, Skerrmag, Skerrhat3, Skerrhat2, Skerrhat1, a, L3, L2, L1, Lnorm, Lhat3, Lhat2, Lhat1, S2dotLhat, S1dotLhat, S1perp3, S1perp2, S1perp1, S2perp3, S2perp2, S2perp1, Sperp3, Sperp2, Sperp1, n3, n2, n1, TINYDOUBLE, condition_e3prov_lhs, condition_e3prov_rhs, e3prov_gt_bound, e3prov_leq_bound, e3prov1, e3prov2, e3prov3, lambdavec3, lambdavec2, lambdavec1, lambdavecnorm, lambdahat3, lambdahat2, lambdahat1, lambdahat_dot_e3prov, lambdahat_cross_e3prov3, lambdahat_cross_e3prov2, lambdahat_cross_e3prov1, e3prov_dot_n, cos_0_1_deg, sin_0_1_deg, condition_e3_lhs, condition_e3_rhs, e3_gt_bound, e3_leq_bound, e31, e32, e33, xi3, xi2, xi1, v3, v2, v1, costheta, sin2theta, xisq, w2, Sigma, Dinv, Dinvprime, omegatilde, chi, Kchi0, K, etaKminus1, Delta0, Delta1, Delta2, Delta3, Delta4, Delta5, Delta5l, logarg, Deltaucalib, Deltaucalibprime, Deltaubar, Deltaubarprime, Deltau, Deltauprime, Deltatprime, Deltat, Deltar, Deltarprime, Lambt, csi, csiprime, csi1, csi2, prT, phat3, phat2, phat1, pdotxir, pdotn, pdotvr, pphi, Qcoeff2, Qcoeff1, DrSipn2, Q, Qminus1, Jtilde, exp2mu, expmu, Brtilde, Btilde, exp2nu, expnu, omega, omegatildeprime, Lambtprime, mucostheta, nucostheta, omegacostheta, mur, nur, omegar, dSO, sigmacoeffTerm3, sigmacoeffTerm2, sigmacoeffTerm1, sigmacoeff, sigmastarcoeffTerm2, sigmastarcoeffTerm1, sigmastarcoeff, Deltasigmastar3, Deltasigmastar2, Deltasigmastar1, Sstar3, Sstar2, Sstar1, S3, S2, S1, Sstardotn, Sdote3, Sdotn, Sdotv, Sdotxi, HdsumTerm2, HdsumTerm1, Hdsum, Hdcoeff, Q4, gammappsum, Hnsradicand, alpha, betapsum, HssTerm3, HssTerm3coeff, HssTerm2, HssTerm2coeff, HssTerm1, Hss, HsoTerm2c, HsoTerm2b, HsoTerm2a, HsoTerm2, HsoTerm2coeff, HsoTerm1, Hso, Hd, Hns, Hs, dSS, Heff, Hreal]

# %% [markdown]
# <a id='list_constants'></a>
#
# # Step 3: Specify constants and variables in Hamiltonian expression \[Back to [top](#toc)\]
# $$\label{list_constants}$$
#
# We read in and declare as SymPy symbols the constant values; derivatives with respect to these variables will be set to zero.  We then read in the variables with respect to which we want to take derivatives and declare those as SymPy variables as well.

# %%
# Step 3.a: Create `input_constants` array and populate with SymPy symbols
m1,m2,tortoise = sp.symbols('m1 m2 tortoise',
                                                                real=True)

condition_rhs ,condition_lhs, greaterthan_bound, lesserthan_equal_bound = sp.symbols('condition_rhs condition_lhs greaterthan_bound lesserthan_equal_bound',real = True)

input_constants = [m1,m2,tortoise,condition_rhs, condition_lhs, greaterthan_bound, lesserthan_equal_bound]

# Step 3.b: Create `dynamic_variables` array and populate with SymPy symbols
x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols("x y z p1 p2 p3 S1x S1y S1z S2x S2y S2z", real=True)
#x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols("x y z p1 p2 p3 S1x S1y S1z S2x S2y S2z")
#x1,x2,x3,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z = sp.symbols("x1 x2 x3 p1 p2 p3 S1x S1y S1z S2x S2y S2z")
dynamic_variables = [x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z]
#dynamic_variables = [x1,x2,x3,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z]

# %% [markdown]
# <a id='list_free_symbols'></a>
#
# # Step 4: Extract free symbols \[Back to [top](#toc)\]
# $$\label{list_free_symbols}$$
#
# By ''free symbols'' we mean the variables in the right-hand sides.  We first create a list of all such terms (using SymPy's built-in free_symbol attribute), including duplicates, and then strip the duplicates.  We then remove input constants from the symbol list.

# %%
# Step 4.a: Prepare array of "free symbols" in the right-hand side expressions
full_symbol_list_with_dups = []
for i in range(len(lr)):
    for variable in rhss[i].free_symbols:
        full_symbol_list_with_dups.append(variable)

# Step 4.b: Remove duplicate free symbols
full_symbol_list = superfast_uniq(full_symbol_list_with_dups)

# Step 4.c: Remove input constants from symbol list
for inputconst in input_constants:
    for symbol in full_symbol_list:
        if str(symbol) == str(inputconst):
            full_symbol_list.remove(symbol)

# %% [markdown]
# <a id='convert_to_func'></a>
#
# # Step 5: Convert variables to function notation; e.g., `var` goes to `var(x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z)` \[Back to [top](#toc)\]
# $$\label{convert_to_func}$$
#
# In order to compute the partial derivative of each right-hand side, we mark each variable (left-hand side) and each free symbol (in right-hand sides) as a function with the dynamic variables as arguments.

# %%
# Step 5.a: Convert each left-hand side to function notation
#   while separating and simplifying left- and right-hand sides
xx = sp.Symbol('xx',real=True)
func = []
for i in range(len(lr)):
    func.append(sp.sympify(sp.Function(lr[i].lhs,real=True)(xx)))

# Step 5.b: Mark each free variable as a function with arguments as the dynamic variables
full_function_list = []
for symb in full_symbol_list:
    func = sp.sympify(sp.Function(str(symb),real=True)(xx))
    #func = sp.sympify(sp.Function(str(symb),real=True)(x1,x2,x3,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z))
    full_function_list.append(func)
    for i in range(len(rhss)):
        for var in rhss[i].free_symbols:
            if str(var) == str(symb):
                rhss[i] = rhss[i].subs(var,func)

# %% [markdown]
# <a id='differentiate'></a>
#
# # Step 6: Differentiate with respect to dynamic variables \[Back to [top](#toc)\]
# $$\label{differentiate}$$
#
# Now we differentiate the right-hand expressions with respect to the dynamic variabls.  We use the SymPy $\texttt{diff}$ command, differentiating with respect to each dynamic variable.  After so doing, we remove $\texttt{(xx)}$, where 'xx' represents a dynamic variable and "Derivative" (which is output by $\texttt{diff}$), and use "prm_xx" suffix to denote the derivative with respect to $\texttt{xx}$.

# %%
# Step 6: Use SymPy's diff function to differentiate right-hand sides with respect to dynamic variables
#   and append "prm" notation to left-hand sides
lhss_deriv = []
rhss_deriv = []
#print(len(rhss))
#print(len(lhss))
for i in range(len(rhss)):
    lhss_deriv.append(custom_parse_expr(str(lhss[i])+"prm"))
    newrhs = custom_parse_expr(str(sp.diff(rhss[i],xx)).replace("(xx)","").replace(", xx","prm").replace("Derivative",""))
    rhss_deriv.append(newrhs)

# %% [markdown]
# <a id='remove_zeros'></a>
#
# # Step 7: Remove derivatives (of constants) that evaluate to zero, simplifying derivative expressions \[Back to [top](#toc)\]
# $$\label{remove_zeros}$$
#
# We declare a function to simply the derivative expressions.  In particular, we want to remove terms equal to zero.

# %%
# Step 7.a: Define derivative simplification function
def simplify_deriv(lhss_deriv,rhss_deriv):
    # Copy expressions into another array
    lhss_deriv_simp = []
    rhss_deriv_simp = []
    for i in range(len(rhss_deriv)):
        lhss_deriv_simp.append(lhss_deriv[i])
        rhss_deriv_simp.append(rhss_deriv[i])
    # If a right-hand side is 0, substitute value 0 for the corresponding left-hand side in later terms
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == 0:
            for j in range(i+1,len(rhss_deriv_simp)):
                for var in rhss_deriv_simp[j].free_symbols:
                    if str(var) == str(lhss_deriv_simp[i]):
                        rhss_deriv_simp[j] = rhss_deriv_simp[j].subs(var,0)
    zero_elements_to_remove = []
    # Create array of indices for expressions that are zero
    for i in range(len(rhss_deriv_simp)):
        if rhss_deriv_simp[i] == sp.sympify(0):
            zero_elements_to_remove.append(i)
    # When removing terms that are zero, we need to take into account their new index (after each removal)
    count = 0
    for i in range(len(zero_elements_to_remove)):
        del lhss_deriv_simp[zero_elements_to_remove[i]+count]
        del rhss_deriv_simp[zero_elements_to_remove[i]+count]
        count -= 1
    return lhss_deriv_simp,rhss_deriv_simp

# Step 7.b: Call the simplication function and then copy results
lhss_deriv_simp,rhss_deriv_simp = simplify_deriv(lhss_deriv,rhss_deriv)
lhss_deriv = lhss_deriv_simp
rhss_deriv = rhss_deriv_simp

# %% [markdown]
# <a id='partial_derivative'></a>
#
# # Step 8: Simplify derivatives with respect to a specific variable \[Back to [top](#toc)\]
# $$\label{partial_derivative}$$
#
# In [Step 6](#differentiate) we took a generic derivative of each expression, assuming all variables were functions of `xx`.  We now define a function that will select a specific dynamic variable (element of `dynamic_variables`) and set the derivative of the variable to 1 and all others to 0.

# %%
# Step 8.a: Define onevar derivative function
# deriv_onevar() replaces variable derivatives with 1 or 0 depending on which partial derivaitve is computed.  For
# example, pass 'xprm=1' to replace each instance of 'xprm' with 1 and 'qprm' with 0 for each q in (y,z,p1,p2,p3,S1x,
# S1y,S1z,S2x,S2y,S2z).  This produces expressions which compute the partial derivative of the Hamiltonian with respect
# to x.
def deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0, p3prm=0, S1xprm=0, S1yprm=0,
                 S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0):
    if xprm + yprm + zprm + p1prm + p2prm + p3prm + S1xprm + S1yprm + S1zprm + S2xprm + S2yprm + S2zprm != 1:
        print("deriv_onevar() cannot take more than one derivative at a time!")
        sys.exit()

    # Create 'new' arrays to store and manipulate derivative terms.
    lhss_deriv_new = []
    rhss_deriv_new = []
    # Append derivative terms to 'new' arrays
    for i in range(len(rhss_deriv)):
        lhss_deriv_new.append(lhss_deriv[i])
        rhss_deriv_new.append(rhss_deriv[i])
    # Replace each instance of 'qprm', q in (x,y,z,p1,p2,p3,S1x,S1y,S1z,S2x,S2y,S2z), with either 0 or 1.
    for i in range(len(rhss_deriv_new)):
        for var in rhss_deriv_new[i].free_symbols:
            if str(var) == "xprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, xprm)
            elif str(var) == "yprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, yprm)
            elif str(var) == "zprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, zprm)
            elif str(var) == "p1prm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, p1prm)
            elif str(var) == "p2prm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, p2prm)
            elif str(var) == "p3prm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, p3prm)
            elif str(var) == "S1xprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, S1xprm)
            elif str(var) == "S1yprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, S1yprm)
            elif str(var) == "S1zprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, S1zprm)
            elif str(var) == "S2xprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, S2xprm)
            elif str(var) == "S2yprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, S2yprm)
            elif str(var) == "S2zprm":
                rhss_deriv_new[i] = rhss_deriv_new[i].subs(var, S2zprm)
    # Simplify the derivative expressions with simplify_deriv().
    lhss_deriv_simp, rhss_deriv_simp = simplify_deriv(lhss_deriv_new, rhss_deriv_new)
    # Return simplified derivative expression.
    return lhss_deriv_simp, rhss_deriv_simp

## validate scheme
#xlhs,xrhs = deriv_onevar(lhss_deriv,rhss_deriv,xprm=1, yprm=0, zprm=0, p1prm=0, p2prm=0, p3prm=0, S1xprm=0, S1yprm=0,
#                 S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)

#with open(os.path.join(outputdir,'partial_x_derivative.txt-VALIDATION-FULLNOTEBOOK'), 'w') as output:
#    for i in range(len(xlhs)):
#        right_side = str(xrhs[i])
#        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
#                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
#                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
#                                                "_prm")
#        output.write(str(xlhs[i]).replace("prm","_prm")+" = "+right_side_in_sp+"\n")

# %% [markdown]
# <a id='store_results'></a>
#
# # Step 9: Store partial derivatives to SymPy notebook `partial_derivatives.txt-VALIDATION.txt` \[Back to [top](#toc)\]
# $$\label{store_results}$$
#
# We write the resulting derivatives in SymPy syntax.  Each partial derivative is output in its own file, in a similar format to the input expressions.

# %%
# Step 9: Output original expression and each partial derivative expression in SymPy snytax
outputdir = "Derivatives"
with open(os.path.join(outputdir,'partial_derivatives.txt-VALIDATION'), 'w') as output:
#with open(os.path.join(outputdir,'lal_derivatives.txt-VALIDATION'), 'w') as output:
    for i in range(len(lr)):
        #print(lr[i].lhs)
        #print(lr[i].rhs)
        right_side = lr[i].rhs
        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(")
        #print(str(lr[i].lhs)+" = "+right_side_in_sp) 
        output.write(str(lr[i].lhs)+" = "+right_side_in_sp)
    output.write("\n")
    for i in range(len(lhss_deriv)):
            right_side = str(rhss_deriv[i])
            right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
                                                "_prm")
            output.write(str(lhss_deriv[i]).replace("prm","_prm")+" = "+right_side_in_sp+"\n")

# %% [markdown]
# <a id='numpy_function'></a>
#
# # Step 10: Create numpy function to output exact derivatives for all 12 dynamic variables \[Back to [top](#toc)\]
# $$\label{numpy_function}$$
#
# We create a python module where we store the exact derivatives as a numpy function.

# %%
# Step 10: Create Numpy function to output exact derivatives for all 12 dynamical variables
file = open(os.path.join(outputdir,'hamiltonian_first_derivatives.py'),"w") 
cfile = open(os.path.join(outputdir,'v4P_hamiltonian_first_derivatives.c'),"w")
optcfile = open(os.path.join(outputdir,'gen_v4popt_hamiltonian_first_derivatives.py'),"w")
file.write("""from __future__ import division
import numpy as np\n""")
cfile.write('#include "mainv4pheader.h"\n')
#lrcount = 0

lhss_deriv_x, rhss_deriv_x = deriv_onevar(lhss_deriv, rhss_deriv, xprm=1, yprm=0, zprm=0, p1prm=0, p2prm=0, p3prm=0,
                                              S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_y, rhss_deriv_y = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=1, zprm=0, p1prm=0, p2prm=0, p3prm=0,
                                               S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_z, rhss_deriv_z = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=1, p1prm=0, p2prm=0, p3prm=0,
                                               S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_p1, rhss_deriv_p1 = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=1, p2prm=0,
                                                p3prm=0, S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_p2, rhss_deriv_p2 = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=1,
                                                p3prm=0, S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_p3, rhss_deriv_p3 = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                p3prm=1, S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_S1x, rhss_deriv_S1x = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                  p3prm=0, S1xprm=1, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_S1y, rhss_deriv_S1y = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                  p3prm=0, S1xprm=0, S1yprm=1, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_S1z, rhss_deriv_S1z = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                  p3prm=0, S1xprm=0, S1yprm=0, S1zprm=1, S2xprm=0, S2yprm=0, S2zprm=0)
lhss_deriv_S2x, rhss_deriv_S2x = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                  p3prm=0, S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=1, S2yprm=0, S2zprm=0)
lhss_deriv_S2y, rhss_deriv_S2y = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                  p3prm=0, S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=1, S2zprm=0)
lhss_deriv_S2z, rhss_deriv_S2z = deriv_onevar(lhss_deriv, rhss_deriv, xprm=0, yprm=0, zprm=0, p1prm=0, p2prm=0,
                                                  p3prm=0, S1xprm=0, S1yprm=0, S1zprm=0, S2xprm=0, S2yprm=0, S2zprm=1)
lhss_temp_vars = [lhss_deriv_x,lhss_deriv_y,lhss_deriv_z,lhss_deriv_p1,lhss_deriv_p2,lhss_deriv_p3,lhss_deriv_S1x,lhss_deriv_S1y,lhss_deriv_S1z,lhss_deriv_S2x,lhss_deriv_S2y,lhss_deriv_S2z]
rhss_temp_vars = [rhss_deriv_x,rhss_deriv_y,rhss_deriv_z,rhss_deriv_p1,rhss_deriv_p2,rhss_deriv_p3,rhss_deriv_S1x,rhss_deriv_S1y,rhss_deriv_S1z,rhss_deriv_S2x,rhss_deriv_S2y,rhss_deriv_S2z]

for j in range(len(dynamic_variables)):
    variable = dynamic_variables[j]
    lhss_temp = lhss_temp_vars[j]
    rhss_temp = rhss_temp_vars[j]
    file.write("def v4P_compute_ham_%s_deriv(m1, m2, tortoise, x, y, z, p1, p2, p3, S1x, S1y, S1z, S2x, S2y, S2z):\n"%(str(variable)))
    cfile.write("double ham_%s_deriv(double m1,double m2,int tortoise,"%(str(variable)) +
            "double x,"+
            "double y,"+
            "double z,"+
            "double p1,"+
            "double p2,"+
            "double p3,"+
            "double S1x,"+
            "double S1y,"+
            "double S1z,"+
            "double S2x,"+
            "double S2y,"+
            "double S2z"+
            "){\n")
    
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_np = right_side.replace("sqrt(","np.sqrt(").replace("log(","np.log(").replace("log(1+","log1p(").replace("pi",
                                                "np.pi").replace("sign(","np.sign(").replace("Abs(",
                                                "np.abs(").replace("Rational(","np.true_divide(")
        file.write("    " + lr[i].lhs + " = " + right_side_in_np)
        #if lrcount == 0:
        right_side_in_c = sp.ccode(custom_parse_expr(str(right_side)))
        right_side_in_c = right_side_in_c.replace("pi",
                                                "M_PI").replace("tortoise","(double)tortoise")
        cfile.write("    double " + lr[i].lhs + " = " + right_side_in_c + ";\n")
    #lrcount += 1
    file.write("\n")
    cfile.write("\n")
    for i in range(len(lhss_temp)):
        right_side = str(rhss_temp[i]).replace("prm","_prm"+str(variable))
        right_side_in_np = right_side.replace("sqrt(","np.sqrt(").replace("log(","np.log(").replace("log(1+","log1p(").replace("pi",
                                                "np.pi").replace("sign(","np.sign(").replace("Abs(",
                                                "np.abs(").replace("Rational(","np.true_divide(")
        file.write("    " + str(lhss_temp[i]).replace("prm", "_prm" + str(variable)) + " = " + right_side_in_np + "\n")
        right_side_in_c = sp.ccode(custom_parse_expr(right_side))
        right_side_in_c = right_side_in_c.replace("log(1+","log1p(").replace("pi",
                                                "M_PI").replace("tortoise","(double)tortoise")
        cfile.write("    double " + str(lhss_temp[i]).replace("prm", "_prm" + str(variable)) + " = " + right_side_in_c + ";\n")
        if(variable == 'S2z'):
            print(lhss_temp[i])
    file.write("    return Hreal_prm%s\n\n"%(variable))
    cfile.write("    return Hreal_prm%s;\n}\n"%(variable))
file.close()
cfile.close()

# %% [markdown]
# <a id='code_validation'></a>
#
# # Step 10: Validate against LALSuite and trusted `SEOBNR_Derivative_Routine` NRPy+ module \[Back to [top](#toc)\]
# $$\label{code_validation}$$
#
# We validate the output of this notebook against known LALSuite values of the Hamiltonian partial derivatives and the output of the `SEOBNR_Derivative_Routine` NRPy+ module.  We note that due to cancellations in the deriavtive terms, various versions of SymPy may result in relative errors that differ as much as an order of magnitude.  Furthermore, even changing the set of input pararameters can affect the relative error by as many as two orders of magnitude.  Therefore we look for agreement with LALSuite to at least 10 significant digits.
#
# When comparing the notebook output to that of the NRPy+ module, we compare term-by-term using SymPy to check that each right-hand side side is equivalent.

# %%
## Validate against LALSuite
import numpy as np
outputdir = "Derivatives"

import Derivatives.hamiltonian_first_derivatives as dH
#from Derivatives.lalhamiltonian_first_derivatives import ham_first_derivs as dH

for index in range(1):
    print("for index %d"%index)
    validationfile = 'outputv4Pindex'+str(index)+'.txt'
    validationfile_pert = 'outputv4Pindex'+str(index)+'pert.txt'
    with open(os.path.join(outputdir,validationfile)) as datfile, open(os.path.join(outputdir,validationfile_pert)) as pertdatfile:
        data_lines = datfile.readlines()
        pertdata_lines = pertdatfile.readlines()
        for i in range(len(pertdata_lines)//3):
            valuepairs = data_lines[3*i].strip('{}\n').split(',')
            valuepairspert = pertdata_lines[3*i].strip('{}\n').split(',')
            derivpairs = data_lines[3*i+1].strip('{}\n').split(',')
            derivpairspert = pertdata_lines[3*i+1].strip('{}\n').split(',')
            values = dict()
            derivs = dict()
            valuespert = dict()
            derivspert = dict()
            for j in range(len(valuepairs)):
                pair = valuepairs[j].split(': ')
                pairpert = valuepairspert[j].split(': ')
                values[pair[0].strip(" ''")] = float(pair[1])
                valuespert[pairpert[0].strip(" ''")] = float(pairpert[1])
            for j in range(len(derivpairs)):
                pair = derivpairs[j].split(': ')
                pairpert = derivpairspert[j].split(': ')
                derivs[pair[0].strip(" ''")] = float(pair[1])
                derivspert[pairpert[0].strip(" ''")] = float(pairpert[1])
            
            m1 , m2 = values['m1'], values['m2']
            eta = m1*m2/(m1 + m2)/(m1 + m2)
            x_deriv = dH.v4P_compute_ham_x_deriv(values['m1'],values['m2'],2,values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            y_deriv = dH.v4P_compute_ham_y_deriv(values['m1'],values['m2'],2,values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            z_deriv = dH.v4P_compute_ham_z_deriv(values['m1'],values['m2'],2,values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            px_deriv = dH.v4P_compute_ham_p1_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            py_deriv = dH.v4P_compute_ham_p2_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            pz_deriv = dH.v4P_compute_ham_p3_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            S1x_deriv = dH.v4P_compute_ham_S1x_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            S1y_deriv = dH.v4P_compute_ham_S1y_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            S1z_deriv = dH.v4P_compute_ham_S1z_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            S2x_deriv = dH.v4P_compute_ham_S2x_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            S2y_deriv = dH.v4P_compute_ham_S2y_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            S2z_deriv = dH.v4P_compute_ham_S2z_deriv(values['m1'],values['m2'],values['tortoise'],values['x'],values['y'],values['z'],values['p1'],values['p2'],values['p3'],values['S1x'],values['S1y'],values['S1z'],values['S2x'],values['S2y'],values['S2z'])
            
            nrpy_derivs = [x_deriv,y_deriv,z_deriv,px_deriv,py_deriv,pz_deriv,S1x_deriv,S1y_deriv,S1z_deriv,S2x_deriv,S2y_deriv,S2z_deriv]
            for j in range(len(dynamic_variables)):
                var = str(dynamic_variables[j])
                #print(var,derivs['dHreal_d'+var])
                if(derivs['dHreal_d'+var] == 0):
                    Erel = np.abs(nrpy_derivs[j]/eta - derivs['dHreal_d'+var])
                    Erelpert = np.abs(derivs['dHreal_d'+var]-derivspert['dHreal_d'+var])
                    if Erel > Erelpert and Erel > 1e-15:
                        print("in line %d: abs error in %s derivative is %.2e, allowed is %.2e"%(i,var,Erel,Erelpert))
                        print(nrpy_derivs[j]/eta,derivs['dHreal_d'+var])
                else:
                    Erel = np.abs((nrpy_derivs[j]/eta - derivs['dHreal_d'+var])/derivs['dHreal_d'+var])
                    Erelpert = np.abs((derivs['dHreal_d'+var]-derivspert['dHreal_d'+var])/derivs['dHreal_d'+var])
                    if Erel > Erelpert:
                        if Erelpert != 0:
                            print("In line %d: ratio of Erel to allowed in %s derivative is %.2e"%(i,var,Erel/Erelpert))
                            print(nrpy_derivs[j]/eta,derivs['dHreal_d'+var])
                        else:
                            print("in line %d: abs error in %s derivative is %.2e, allowed is %.2e"%(i,var,Erel,Erelpert))
                            print(nrpy_derivs[j]/eta,derivs['dHreal_d'+var])
# Out:
# for index 0
# In line 0: ratio of Erel to allowed in x derivative is 2.21e+06
# 0.0023901373641795156 0.0023905340564481484
# in line 0: abs error in y derivative is 1.00e+00, allowed is 0.00e+00
# 3.071514380156699e-12 -3.5122275458358363e-09
# In line 0: ratio of Erel to allowed in z derivative is 1.41e+06
# -6.676558100087982e-10 -7.307873565546668e-07
# in line 0: abs error in p1 derivative is 1.00e+00, allowed is 0.00e+00
# 4.264364868738341e-15 4.866773650746836e-09
# In line 0: ratio of Erel to allowed in p2 derivative is 3.25e+06
# 0.20292735373031207 0.2029068898314602
# In line 0: ratio of Erel to allowed in p3 derivative is 2.94e+07
# 0.0009354195290479322 0.001045973586658481
# In line 0: ratio of Erel to allowed in S1x derivative is 1.81e+07
# 4.8343257902058865e-08 5.115222788498478e-06
# In line 0: ratio of Erel to allowed in S1y derivative is 4.33e+07
# -1.0344231505505362e-07 -3.6210958476140678e-06
# In line 0: ratio of Erel to allowed in S1z derivative is 1.02e+09
# 9.97175464774144e-07 0.0012618852689300448
# In line 0: ratio of Erel to allowed in S2x derivative is 2.50e+15
# 3.5458415332366195e-08 1.2752375795344051e-05
# In line 0: ratio of Erel to allowed in S2y derivative is 2.39e+15
# -5.315296188683894e-08 -4.106209332555011e-06
# In line 0: ratio of Erel to allowed in S2z derivative is 3.17e+09
# 2.4041412470851092e-06 0.002556646697196019
# In line 1: ratio of Erel to allowed in x derivative is 2.76e+05
# 0.0023901372967457635 0.002390533988508787
# In line 1: ratio of Erel to allowed in y derivative is 4.75e+04
# 3.071514435488403e-12 -3.511783456625987e-09
# In line 1: ratio of Erel to allowed in z derivative is 9.86e+06
# -6.676557828982722e-10 -7.30787430569535e-07
# In line 1: ratio of Erel to allowed in p1 derivative is 6.58e+04
# 4.264364692092581e-15 4.866847665615145e-09
# In line 1: ratio of Erel to allowed in p2 derivative is 7.37e+11
# 0.20292735384457775 0.20290688994255054
# In line 1: ratio of Erel to allowed in p3 derivative is 6.75e+07
# 0.0009354195295718792 0.001045973575351846
# In line 1: ratio of Erel to allowed in S1x derivative is 7.12e+06
# 4.8343255605434e-08 5.115223348962241e-06
# In line 1: ratio of Erel to allowed in S1y derivative is 4.83e+06
# -1.0344231004188543e-07 -3.6210957661589127e-06
# In line 1: ratio of Erel to allowed in S1z derivative is 1.27e+09
# 9.971754421423947e-07 0.0012618852333803597
# In line 1: ratio of Erel to allowed in S2x derivative is 1.97e+06
# 3.545841374446979e-08 1.2752370153190641e-05
# In line 1: ratio of Erel to allowed in S2y derivative is 6.29e+05
# -5.3152959791954395e-08 -4.106215780730338e-06
# In line 1: ratio of Erel to allowed in S2z derivative is 3.17e+09
# 2.404141180166611e-06 0.0025566466238480245
# In line 2: ratio of Erel to allowed in x derivative is 4.69e+05
# 0.0023901373654476544 0.0023905340574149835
# In line 2: ratio of Erel to allowed in y derivative is 5.94e+03
# 3.0715147501795443e-12 -3.5122275458358363e-09
# In line 2: ratio of Erel to allowed in z derivative is 9.86e+06
# -6.676558198890659e-10 -7.30787430569535e-07
# in line 2: abs error in p1 derivative is 1.00e+00, allowed is 0.00e+00
# 4.264364927527484e-15 4.866773650746836e-09
# In line 2: ratio of Erel to allowed in p2 derivative is 4.21e+06
# 0.202927356589952 0.2029068926937396
# In line 2: ratio of Erel to allowed in p3 derivative is 1.27e+07
# 0.0009354195282910394 0.001045973574153842
# In line 2: ratio of Erel to allowed in S1x derivative is 5.57e+06
# 4.834325786925787e-08 5.1152239780454485e-06
# In line 2: ratio of Erel to allowed in S1y derivative is 1.14e+06
# -1.0344231515174405e-07 -3.621095776476331e-06
# In line 2: ratio of Erel to allowed in S1z derivative is 1.10e+10
# 9.97175482026908e-07 0.0012618852872093949
# In line 2: ratio of Erel to allowed in S2x derivative is 1.58e+07
# 3.5458415301376634e-08 1.2752376601365967e-05
# In line 2: ratio of Erel to allowed in S2y derivative is 7.18e+05
# -5.3152961987864414e-08 -4.106209332555011e-06
# In line 2: ratio of Erel to allowed in S2z derivative is 3.96e+08
# 2.404141281255866e-06 0.002556646729436896
# In line 3: ratio of Erel to allowed in x derivative is 2.23e+06
# 0.0023901373641795503 0.0023905340581625916
# In line 3: ratio of Erel to allowed in y derivative is 5.94e+03
# 3.0715146111174027e-12 -3.512301560704145e-09
# in line 3: abs error in z derivative is 9.99e-01, allowed is 0.00e+00
# -6.676558100086784e-10 -7.30787430569535e-07
# In line 3: ratio of Erel to allowed in p1 derivative is 8.22e+03
# 4.264364868923257e-15 4.867365769693302e-09
# In line 3: ratio of Erel to allowed in p2 derivative is 4.08e+05
# 0.20292735373030862 0.20290688984262503
# In line 3: ratio of Erel to allowed in p3 derivative is 1.32e+08
# 0.0009354195429852521 0.0010459735912659288
# In line 3: ratio of Erel to allowed in S1x derivative is 4.86e+06
# 4.834325786514308e-08 5.115226003155466e-06
# In line 3: ratio of Erel to allowed in S1y derivative is 3.41e+08
# -1.0344231522368152e-07 -3.6210957663374224e-06
# In line 3: ratio of Erel to allowed in S1z derivative is 5.68e+08
# 9.971754649814083e-07 0.001261885269908444
# In line 3: ratio of Erel to allowed in S2x derivative is 1.58e+07
# 3.5458415295434864e-08 1.2752369347168726e-05
# In line 3: ratio of Erel to allowed in S2y derivative is 2.39e+15
# -5.3152962137022416e-08 -4.106209332555011e-06
# In line 3: ratio of Erel to allowed in S2z derivative is 2.94e+15
# 2.404141247292623e-06 0.002556646690747843
# In line 4: ratio of Erel to allowed in y derivative is 6.70e+00
# 4.675389483933128e-13 -1.7195874354077505e-09
# In line 4: ratio of Erel to allowed in z derivative is 7.92e+00
# -4.254079470841747e-10 -4.636446041909418e-07
# In line 4: ratio of Erel to allowed in p1 derivative is 7.68e+00
# 2.629033462486357e-15 3.030020678806977e-09
# In line 4: ratio of Erel to allowed in S1x derivative is 4.24e+00
# 1.8740279852795833e-08 1.8615278795431416e-06
# In line 4: ratio of Erel to allowed in S1z derivative is 1.40e+01
# 8.910446189198315e-07 0.001033782679751298
# In line 4: ratio of Erel to allowed in S2x derivative is 5.26e+00
# 1.4077339577238478e-08 5.415200208247484e-06
# In line 4: ratio of Erel to allowed in S2y derivative is 2.28e+00
# -1.9530255237420842e-08 1.3847835345082162e-06
# In line 4: ratio of Erel to allowed in S2z derivative is 1.38e+01
# 1.9353751069411004e-06 0.00208523751824341
# In line 5: ratio of Erel to allowed in y derivative is 1.28e+01
# 1.3676920887275342e-12 -2.3615924031143245e-09
# In line 5: ratio of Erel to allowed in z derivative is 1.86e+01
# -5.306164254470913e-10 -5.789839718772782e-07
# In line 5: ratio of Erel to allowed in p1 derivative is 1.80e+01
# 3.3303775053140613e-15 3.822127799442873e-09
# In line 5: ratio of Erel to allowed in p3 derivative is 1.11e+00
# 0.0006170101877832426 0.0007015433640942931
# In line 5: ratio of Erel to allowed in S1x derivative is 9.06e+00
# 2.9596185824653214e-08 3.1015546745235915e-06
# In line 5: ratio of Erel to allowed in S1y derivative is 3.69e+00
# -6.23487320074793e-08 -1.4219533375862547e-06
# In line 5: ratio of Erel to allowed in S1z derivative is 3.93e+01
# 9.553571934501843e-07 0.0011431302302211928
# In line 5: ratio of Erel to allowed in S2x derivative is 1.07e+01
# 2.203801377957248e-08 8.211286204318215e-06
# In line 5: ratio of Erel to allowed in S2y derivative is 1.27e+00
# -3.2404328249741076e-08 -7.44981876188433e-07
# In line 5: ratio of Erel to allowed in S2z derivative is 3.85e+01
# 2.156003765919084e-06 0.0023114381602407086
# In line 6: ratio of Erel to allowed in x derivative is 2.76e+05
# 0.0023901372967457635 0.002390533988508787
# In line 6: ratio of Erel to allowed in y derivative is 4.75e+04
# 3.071514435488403e-12 -3.511783456625987e-09
# In line 6: ratio of Erel to allowed in z derivative is 9.86e+06
# -6.676557828982722e-10 -7.30787430569535e-07
# In line 6: ratio of Erel to allowed in p1 derivative is 6.58e+04
# 4.264364692092581e-15 4.866847665615145e-09
# In line 6: ratio of Erel to allowed in p2 derivative is 7.37e+11
# 0.20292735384457775 0.20290688994255054
# In line 6: ratio of Erel to allowed in p3 derivative is 6.75e+07
# 0.0009354195295718792 0.001045973575351846
# In line 6: ratio of Erel to allowed in S1x derivative is 7.12e+06
# 4.8343255605434e-08 5.115223348962241e-06
# In line 6: ratio of Erel to allowed in S1y derivative is 4.83e+06
# -1.0344231004188543e-07 -3.6210957661589127e-06
# In line 6: ratio of Erel to allowed in S1z derivative is 1.27e+09
# 9.971754421423947e-07 0.0012618852333803597
# In line 6: ratio of Erel to allowed in S2x derivative is 1.97e+06
# 3.545841374446979e-08 1.2752370153190641e-05
# In line 6: ratio of Erel to allowed in S2y derivative is 6.29e+05
# -5.3152959791954395e-08 -4.106215780730338e-06
# In line 6: ratio of Erel to allowed in S2z derivative is 3.17e+09
# 2.404141180166611e-06 0.0025566466238480245
# In line 7: ratio of Erel to allowed in x derivative is 4.69e+05
# 0.0023901373654476544 0.0023905340574149835
# In line 7: ratio of Erel to allowed in y derivative is 5.94e+03
# 3.0715147501795443e-12 -3.5122275458358363e-09
# In line 7: ratio of Erel to allowed in z derivative is 9.86e+06
# -6.676558198890659e-10 -7.30787430569535e-07
# in line 7: abs error in p1 derivative is 1.00e+00, allowed is 0.00e+00
# 4.264364927527484e-15 4.866773650746836e-09
# In line 7: ratio of Erel to allowed in p2 derivative is 4.21e+06
# 0.202927356589952 0.2029068926937396
# In line 7: ratio of Erel to allowed in p3 derivative is 1.27e+07
# 0.0009354195282910394 0.001045973574153842
# In line 7: ratio of Erel to allowed in S1x derivative is 5.57e+06
# 4.834325786925787e-08 5.1152239780454485e-06
# In line 7: ratio of Erel to allowed in S1y derivative is 1.14e+06
# -1.0344231515174405e-07 -3.621095776476331e-06
# In line 7: ratio of Erel to allowed in S1z derivative is 1.10e+10
# 9.97175482026908e-07 0.0012618852872093949
# In line 7: ratio of Erel to allowed in S2x derivative is 1.58e+07
# 3.5458415301376634e-08 1.2752376601365967e-05
# In line 7: ratio of Erel to allowed in S2y derivative is 7.18e+05
# -5.3152961987864414e-08 -4.106209332555011e-06
# In line 7: ratio of Erel to allowed in S2z derivative is 3.96e+08
# 2.404141281255866e-06 0.002556646729436896
# In line 8: ratio of Erel to allowed in x derivative is 2.23e+06
# 0.0023901373641795503 0.0023905340581625916
# In line 8: ratio of Erel to allowed in y derivative is 5.94e+03
# 3.0715146111174027e-12 -3.512301560704145e-09
# in line 8: abs error in z derivative is 9.99e-01, allowed is 0.00e+00
# -6.676558100086784e-10 -7.30787430569535e-07
# In line 8: ratio of Erel to allowed in p1 derivative is 8.22e+03
# 4.264364868923257e-15 4.867365769693302e-09
# In line 8: ratio of Erel to allowed in p2 derivative is 4.08e+05
# 0.20292735373030862 0.20290688984262503
# In line 8: ratio of Erel to allowed in p3 derivative is 1.32e+08
# 0.0009354195429852521 0.0010459735912659288
# In line 8: ratio of Erel to allowed in S1x derivative is 4.86e+06
# 4.834325786514308e-08 5.115226003155466e-06
# In line 8: ratio of Erel to allowed in S1y derivative is 3.41e+08
# -1.0344231522368152e-07 -3.6210957663374224e-06
# In line 8: ratio of Erel to allowed in S1z derivative is 5.68e+08
# 9.971754649814083e-07 0.001261885269908444
# In line 8: ratio of Erel to allowed in S2x derivative is 1.58e+07
# 3.5458415295434864e-08 1.2752369347168726e-05
# In line 8: ratio of Erel to allowed in S2y derivative is 2.39e+15
# -5.3152962137022416e-08 -4.106209332555011e-06
# In line 8: ratio of Erel to allowed in S2z derivative is 2.94e+15
# 2.404141247292623e-06 0.002556646690747843
# In line 9: ratio of Erel to allowed in y derivative is 6.70e+00
# 4.675394828009917e-13 -1.7190693313295924e-09
# In line 9: ratio of Erel to allowed in z derivative is 7.92e+00
# -4.254079475911703e-10 -4.6364453017607344e-07
# In line 9: ratio of Erel to allowed in p1 derivative is 7.68e+00
# 2.6290334624840707e-15 3.030020678806977e-09
# In line 9: ratio of Erel to allowed in S1x derivative is 4.24e+00
# 1.8740279632937046e-08 1.8615281842773254e-06
# In line 9: ratio of Erel to allowed in S1z derivative is 1.40e+01
# 8.910446189420354e-07 0.001033782679598931
# In line 9: ratio of Erel to allowed in S2x derivative is 5.26e+00
# 1.4077339357387756e-08 5.415206656422811e-06
# In line 9: ratio of Erel to allowed in S2y derivative is 2.28e+00
# -1.9530255662051522e-08 1.3847827284863001e-06
# In line 9: ratio of Erel to allowed in S2z derivative is 1.38e+01
# 1.9353751069627426e-06 0.0020852375126012568
# In line 10: ratio of Erel to allowed in y derivative is 1.27e+01
# 1.3676927006581166e-12 -2.3621845220607915e-09
# In line 10: ratio of Erel to allowed in z derivative is 1.86e+01
# -5.306164253636043e-10 -5.789839718772782e-07
# In line 10: ratio of Erel to allowed in p1 derivative is 1.79e+01
# 3.330377505466774e-15 3.822793933257647e-09
# In line 10: ratio of Erel to allowed in p3 derivative is 1.11e+00
# 0.0006170101877852316 0.0007015433582917855
# In line 10: ratio of Erel to allowed in S1x derivative is 9.06e+00
# 2.9596185243280282e-08 3.1015541674954486e-06
# In line 10: ratio of Erel to allowed in S1y derivative is 3.69e+00
# -6.234873192225689e-08 -1.4219558737733792e-06
# In line 10: ratio of Erel to allowed in S1z derivative is 3.93e+01
# 9.553571930769418e-07 0.0011431302310283456
# In line 10: ratio of Erel to allowed in S2x derivative is 1.07e+01
# 2.203801319784616e-08 8.211286204318215e-06
# In line 10: ratio of Erel to allowed in S2y derivative is 1.27e+00
# -3.240432816306408e-08 -7.44976234035022e-07
# In line 10: ratio of Erel to allowed in S2z derivative is 3.85e+01
# 2.1560037655885695e-06 0.0023114381602407086
# In line 11: ratio of Erel to allowed in y derivative is 2.33e+01
# 2.0783402228874194e-12 -2.8368418725221996e-09
# In line 11: ratio of Erel to allowed in z derivative is 3.87e+01
# -5.928549826107779e-10 -6.476445305973282e-07
# In line 11: ratio of Erel to allowed in p1 derivative is 3.75e+01
# 3.752129949761213e-15 4.2951568228014976e-09
# In line 11: ratio of Erel to allowed in p3 derivative is 2.50e+00
# 0.0007760611154229246 0.0008722611560578609
# In line 11: ratio of Erel to allowed in S1x derivative is 1.82e+01
# 3.7560224570800586e-08 3.9728255464851445e-06
# In line 11: ratio of Erel to allowed in S1y derivative is 9.72e+00
# -7.977916481664094e-08 -2.3888417539978332e-06
# In line 11: ratio of Erel to allowed in S1z derivative is 8.99e+01
# 9.786862779393806e-07 0.0011987937469114074
# In line 11: ratio of Erel to allowed in S2x derivative is 2.08e+01
# 2.7790841090381035e-08 1.0171709634576587e-05
# In line 11: ratio of Erel to allowed in S2y derivative is 6.03e+00
# -4.1453596811720295e-08 -2.2341895800082057e-06
# In line 11: ratio of Erel to allowed in S2z derivative is 8.81e+01
# 2.2714037372984324e-06 0.002426593149185141
# In line 12: ratio of Erel to allowed in y derivative is 1.04e+01
# 8.43500580635706e-13 -1.986337020791022e-09
# In line 12: ratio of Erel to allowed in z derivative is 1.44e+01
# -4.718737549996422e-10 -5.145119885696658e-07
# In line 12: ratio of Erel to allowed in p1 derivative is 1.38e+01
# 2.9386846743082796e-15 3.3804070653786762e-09
# In line 12: ratio of Erel to allowed in S1x derivative is 6.29e+00
# 2.3326775984926164e-08 2.4007805368149707e-06
# In line 12: ratio of Erel to allowed in S1y derivative is 1.42e+00
# -4.867237103514695e-08 -6.520508556536084e-07
# In line 12: ratio of Erel to allowed in S1z derivative is 3.16e+01
# 9.208320844216831e-07 0.0010825503970810424
# In line 12: ratio of Erel to allowed in S2x derivative is 7.78e+00
# 1.74574041595309e-08 6.6252672081823505e-06
# In line 12: ratio of Erel to allowed in S2z derivative is 3.08e+01
# 2.033765139865994e-06 0.0021864736322951828
# In line 13: ratio of Erel to allowed in y derivative is 1.39e+01
# 1.3653137126082838e-12 -2.355893258254582e-09
# In line 13: ratio of Erel to allowed in z derivative is 2.10e+01
# -5.294283380234814e-10 -5.776841227600471e-07
# In line 13: ratio of Erel to allowed in p1 derivative is 2.01e+01
# 3.322976305773513e-15 3.813764119324029e-09
# In line 13: ratio of Erel to allowed in p3 derivative is 1.12e+00
# 0.0006170113476858911 0.000701449931505575
# In line 13: ratio of Erel to allowed in S1x derivative is 9.41e+00
# 2.9533326812947913e-08 3.0965951802172267e-06
# In line 13: ratio of Erel to allowed in S1y derivative is 3.71e+00
# -6.221732753290027e-08 -1.4208490338916404e-06
# In line 13: ratio of Erel to allowed in S1z derivative is 4.79e+01
# 9.53806881481192e-07 0.0011412044976465488
# In line 13: ratio of Erel to allowed in S2x derivative is 1.12e+01
# 2.1992373458801265e-08 8.197521768060767e-06
# In line 13: ratio of Erel to allowed in S2y derivative is 1.26e+00
# -3.234423442825776e-08 -7.466301910064034e-07
# In line 13: ratio of Erel to allowed in S2z derivative is 4.68e+01
# 2.152385000844843e-06 0.0023075770976377363
# In line 14: ratio of Erel to allowed in y derivative is 2.34e+01
# 2.0783395461848204e-12 -2.8368418725221996e-09
# In line 14: ratio of Erel to allowed in z derivative is 3.87e+01
# -5.928549588142269e-10 -6.476445305973282e-07
# In line 14: ratio of Erel to allowed in p1 derivative is 3.75e+01
# 3.752129792713563e-15 4.295230837669806e-09
# In line 14: ratio of Erel to allowed in p3 derivative is 2.50e+00
# 0.0007760611158297665 0.0008722611491383556
# In line 14: ratio of Erel to allowed in S1x derivative is 1.82e+01
# 3.7560222722794997e-08 3.972823577809714e-06
# In line 14: ratio of Erel to allowed in S1y derivative is 9.72e+00
# -7.977916079481075e-08 -2.3888428097716505e-06
# In line 14: ratio of Erel to allowed in S1z derivative is 8.99e+01
# 9.78686254178279e-07 0.001198793713184597
# In line 14: ratio of Erel to allowed in S2x derivative is 2.08e+01
# 2.7790839785629122e-08 1.0171710440598503e-05
# In line 14: ratio of Erel to allowed in S2y derivative is 6.03e+00
# -4.145359503210975e-08 -2.2341952221616164e-06
# In line 14: ratio of Erel to allowed in S2z derivative is 8.81e+01
# 2.2714036733608e-06 0.0024265930814793
# In line 15: ratio of Erel to allowed in y derivative is 2.33e+01
# 2.078340366265721e-12 -2.836767857653891e-09
# In line 15: ratio of Erel to allowed in z derivative is 3.87e+01
# -5.92854990909388e-10 -6.476451967311428e-07
# In line 15: ratio of Erel to allowed in p1 derivative is 3.73e+01
# 3.7521300008032865e-15 4.295230837669806e-09
# In line 15: ratio of Erel to allowed in p3 derivative is 2.50e+00
# 0.0007760611146809744 0.0008722611483465671
# In line 15: ratio of Erel to allowed in S1x derivative is 1.82e+01
# 3.756022428764446e-08 3.972824164279464e-06
# In line 15: ratio of Erel to allowed in S1y derivative is 9.72e+00
# -7.977916457567912e-08 -2.3888424074934836e-06
# In line 15: ratio of Erel to allowed in S1z derivative is 8.99e+01
# 9.786862932159131e-07 0.0011987937652322175
# In line 15: ratio of Erel to allowed in S2x derivative is 2.08e+01
# 2.779084080884872e-08 1.0171708828554669e-05
# In line 15: ratio of Erel to allowed in S2y derivative is 6.03e+00
# -4.145359657479419e-08 -2.2341895800082057e-06
# In line 15: ratio of Erel to allowed in S2z derivative is 8.81e+01
# 2.2714037684901785e-06 0.0024265931822320397
# In line 16: ratio of Erel to allowed in y derivative is 2.32e+01
# 2.078340440502294e-12 -2.8374339914686666e-09
# In line 16: ratio of Erel to allowed in z derivative is 3.87e+01
# -5.928549825315121e-10 -6.476446046121964e-07
# In line 16: ratio of Erel to allowed in p1 derivative is 3.75e+01
# 3.752129949885313e-15 4.295230837669806e-09
# In line 16: ratio of Erel to allowed in p3 derivative is 2.50e+00
# 0.0007760611269857944 0.0008722611649162099
# In line 16: ratio of Erel to allowed in S1x derivative is 1.82e+01
# 3.7560224208243366e-08 3.972824419938387e-06
# In line 16: ratio of Erel to allowed in S1y derivative is 9.72e+00
# -7.977916488936259e-08 -2.3888428738444278e-06
# In line 16: ratio of Erel to allowed in S1z derivative is 8.99e+01
# 9.786862775622631e-07 0.0011987937459562782
# In line 16: ratio of Erel to allowed in S2x derivative is 2.08e+01
# 2.779084072781558e-08 1.0171708828554669e-05
# In line 16: ratio of Erel to allowed in S2y derivative is 6.03e+00
# -4.145359694339684e-08 -2.2341952221616164e-06
# In line 16: ratio of Erel to allowed in S2z derivative is 8.81e+01
# 2.2714037369214575e-06 0.002426593148379119
# In line 17: ratio of Erel to allowed in y derivative is 6.93e+01
# 2.0330388745106214e-12 -3.6034878784600246e-09
# In line 17: ratio of Erel to allowed in z derivative is 3.98e+01
# -6.662856235700912e-10 -7.28320070919608e-07
# In line 17: ratio of Erel to allowed in p1 derivative is 3.84e+01
# 4.217740274209016e-15 4.831690603168681e-09
# In line 17: ratio of Erel to allowed in p3 derivative is 1.68e+00
# 0.0006868443725600825 0.000789556354955247
# In line 17: ratio of Erel to allowed in S1x derivative is 2.10e+01
# 4.2400484706857304e-08 4.391943745875027e-06
# In line 17: ratio of Erel to allowed in S1y derivative is 5.23e+00
# -8.952728981727104e-08 -1.99576111234237e-06
# In line 17: ratio of Erel to allowed in S1z derivative is 8.20e+01
# 1.0581986290907305e-06 0.0013045925988120531
# In line 17: ratio of Erel to allowed in S2x derivative is 2.37e+01
# 3.124467153879571e-08 1.1245015671956791e-05
# In line 17: ratio of Erel to allowed in S2y derivative is 1.78e+00
# -4.4990163065578e-08 -1.1486537720983847e-06
# In line 17: ratio of Erel to allowed in S2z derivative is 8.10e+01
# 2.4725958396166596e-06 0.002639348109187978
# In line 18: ratio of Erel to allowed in y derivative is 1.03e+02
# 1.583833546866647e-12 -4.722962761623725e-09
# In line 18: ratio of Erel to allowed in z derivative is 3.38e+01
# -6.91762931900453e-10 -7.566930045517968e-07
# In line 18: ratio of Erel to allowed in p1 derivative is 3.28e+01
# 4.3910792097440396e-15 5.0249434243217666e-09
# In line 18: ratio of Erel to allowed in p3 derivative is 1.03e+00
# 0.0004998327865612429 0.0006075497474553964
# In line 18: ratio of Erel to allowed in S1x derivative is 2.09e+01
# 4.619876651132498e-08 4.799664043521774e-06
# In line 18: ratio of Erel to allowed in S1y derivative is 1.34e+00
# -9.6490237568213e-08 -9.148165980613962e-07
# In line 18: ratio of Erel to allowed in S1z derivative is 6.21e+01
# 1.0616416683658703e-06 0.0013235990707639244
# In line 18: ratio of Erel to allowed in S2x derivative is 2.31e+01
# 3.3938127663071116e-08 1.215831507472842e-05
# In line 18: ratio of Erel to allowed in S2y derivative is 1.18e+00
# -4.6282534003495125e-08 1.2571419039097975e-06
# In line 18: ratio of Erel to allowed in S2z derivative is 6.17e+01
# 2.513595241288802e-06 0.002678877931476808
# In line 19: ratio of Erel to allowed in y derivative is 7.74e+00
# 3.639327915342146e-13 -6.129319274350563e-09
# In line 19: ratio of Erel to allowed in z derivative is 1.03e+02
# -7.02782601226324e-10 -7.687970260406018e-07
# In line 19: ratio of Erel to allowed in p1 derivative is 1.05e+02
# 4.4550188560799196e-15 5.098514203420261e-09
# In line 19: ratio of Erel to allowed in S1x derivative is 5.97e+01
# 4.670028326717123e-08 4.834846159671153e-06
# In line 19: ratio of Erel to allowed in S1y derivative is 1.30e+00
# -9.539686945625324e-08 1.4403758137060585e-06
# In line 19: ratio of Erel to allowed in S1z derivative is 1.99e+02
# 1.0754937923531253e-06 0.001340796520218275
# In line 19: ratio of Erel to allowed in S2x derivative is 6.62e+01
# 3.4290153965131585e-08 1.2261623709708404e-05
# In line 19: ratio of Erel to allowed in S2y derivative is 2.50e+00
# -4.234652533703318e-08 6.0516560695944585e-06
# In line 19: ratio of Erel to allowed in S2z derivative is 1.97e+02
# 2.545808424847537e-06 0.002713316716227432
# In line 20: ratio of Erel to allowed in y derivative is 1.14e+02
# -4.0593224828671806e-13 -7.184031147744463e-09
# In line 20: ratio of Erel to allowed in z derivative is 6.72e+02
# -7.132900295559657e-10 -7.804805690625471e-07
# In line 20: ratio of Erel to allowed in p1 derivative is 7.52e+02
# 4.522493380562632e-15 5.1739353542264626e-09
# In line 20: ratio of Erel to allowed in p3 derivative is 1.03e+01
# -0.00012183857781733086 -1.1834969103421943e-05
# In line 20: ratio of Erel to allowed in S1x derivative is 3.45e+02
# 4.798311066224742e-08 4.966903481649727e-06
# In line 20: ratio of Erel to allowed in S1y derivative is 4.14e+01
# -9.671530722410732e-08 2.9480872211271823e-06
# In line 20: ratio of Erel to allowed in S1z derivative is 1.45e+03
# 1.0799730613074984e-06 0.0013509409456092017
# In line 20: ratio of Erel to allowed in S2x derivative is 3.86e+02
# 3.519387154770671e-08 1.2564309119778017e-05
# In line 20: ratio of Erel to allowed in S2y derivative is 5.87e+01
# -4.0649746374544094e-08 9.176491806428544e-06
# In line 20: ratio of Erel to allowed in S2z derivative is 1.43e+03
# 2.566429239423916e-06 0.0027340483656246306
# In line 21: ratio of Erel to allowed in x derivative is 1.10e+00
# 0.0023842827917204936 0.0023847199784305124
# In line 21: ratio of Erel to allowed in y derivative is 1.35e+03
# -3.626296402823992e-13 -7.110904457855819e-09
# In line 21: ratio of Erel to allowed in z derivative is 5.71e+03
# -7.121141990567808e-10 -7.791699877894114e-07
# In line 21: ratio of Erel to allowed in p1 derivative is 5.82e+03
# 4.514685703907638e-15 5.1661637930540865e-09
# In line 21: ratio of Erel to allowed in p2 derivative is 1.32e+00
# 0.21753615093464332 0.21751567845828107
# In line 21: ratio of Erel to allowed in p3 derivative is 1.27e+02
# -0.00010894609498169269 8.555936556373062e-07
# In line 21: ratio of Erel to allowed in S1x derivative is 3.40e+03
# 4.782533498308689e-08 4.950431575777102e-06
# In line 21: ratio of Erel to allowed in S1y derivative is 4.87e+02
# -9.646311455081118e-08 2.8612868496240114e-06
# In line 21: ratio of Erel to allowed in S1z derivative is 1.08e+04
# 1.0796225244244029e-06 0.0013499116609031634
# In line 21: ratio of Erel to allowed in S2x derivative is 3.75e+03
# 3.508277333778224e-08 1.252690647879362e-05
# In line 21: ratio of Erel to allowed in S2y derivative is 6.89e+02
# -4.0676028697906036e-08 8.99168468349032e-06
# In line 21: ratio of Erel to allowed in S2z derivative is 1.08e+04
# 2.564291727074707e-06 0.002731933860626867
# In line 22: ratio of Erel to allowed in x derivative is 2.52e+01
# 0.0023846665319673744 0.0023851037995438478
# In line 22: ratio of Erel to allowed in y derivative is 1.20e+04
# -3.6562178466291094e-13 -7.1161595135057114e-09
# In line 22: ratio of Erel to allowed in z derivative is 1.11e+05
# -7.122316095453627e-10 -7.793005500171073e-07
# In line 22: ratio of Erel to allowed in p1 derivative is 6.98e+04
# 4.515458653018798e-15 5.16645985252732e-09
# In line 22: ratio of Erel to allowed in p2 derivative is 7.00e+01
# 0.21752057529388721 0.21750009968622883
# In line 22: ratio of Erel to allowed in p3 derivative is 6.60e+03
# -0.00010983321777800263 -1.3903145057798496e-08
# In line 22: ratio of Erel to allowed in S1x derivative is 8.57e+04
# 4.783913242311258e-08 4.951834097130804e-06
# In line 22: ratio of Erel to allowed in S1y derivative is 2.20e+04
# -9.648653989388927e-08 2.8673762931829398e-06
# In line 22: ratio of Erel to allowed in S1z derivative is 1.71e+05
# 1.0796785664265177e-06 0.0013500293538217
# In line 22: ratio of Erel to allowed in S2x derivative is 8.91e+04
# 3.509248862271033e-08 1.253014023872012e-05
# In line 22: ratio of Erel to allowed in S2y derivative is 3.04e+04
# -4.067651274788496e-08 9.004803496193148e-06
# In line 22: ratio of Erel to allowed in S2z derivative is 1.71e+05
# 2.564529219022962e-06 0.002732173885087175
# In line 23: ratio of Erel to allowed in x derivative is 6.50e+02
# 0.0023846528384983455 0.0023850901024823155
# In line 23: ratio of Erel to allowed in y derivative is 4.81e+04
# -3.655674973965461e-13 -7.116085498637403e-09
# In line 23: ratio of Erel to allowed in z derivative is 7.01e+05
# -7.122263358059823e-10 -7.792941847384326e-07
# In line 23: ratio of Erel to allowed in p1 derivative is 8.73e+03
# 4.515424439261705e-15 5.1665338673956285e-09
# In line 23: ratio of Erel to allowed in p2 derivative is 2.61e+03
# 0.21752079250648707 0.21750031696391173
# In line 23: ratio of Erel to allowed in p3 derivative is 1.28e+05
# -0.00010981763694734317 1.0603173926374766e-09
# In line 23: ratio of Erel to allowed in S1x derivative is 1.61e+06
# 4.783864679878557e-08 4.951787390272777e-06
# In line 23: ratio of Erel to allowed in S1y derivative is 3.72e+05
# -9.648562674339517e-08 2.8672587017821833e-06
# In line 23: ratio of Erel to allowed in S1z derivative is 4.08e+06
# 1.0796746066526143e-06 0.001350023040579985
# In line 23: ratio of Erel to allowed in S2x derivative is 1.11e+06
# 3.509214677905658e-08 1.2530029007695733e-05
# In line 23: ratio of Erel to allowed in S2y derivative is 6.23e+05
# -4.067631631354296e-08 9.004543957136235e-06
# In line 23: ratio of Erel to allowed in S2z derivative is 4.16e+06
# 2.5645168993510466e-06 0.0027321611233421805
# In line 24: ratio of Erel to allowed in y derivative is 1.82e+01
# -3.655708228857363e-13 -7.1161595135057114e-09
# In line 24: ratio of Erel to allowed in z derivative is 1.78e+03
# -7.122267595248097e-10 -7.792952949614573e-07
# In line 24: ratio of Erel to allowed in p1 derivative is 1.99e+03
# 4.515427179473693e-15 5.1665338673956285e-09
# In line 24: ratio of Erel to allowed in S1x derivative is 2.45e+03
# 4.783868522451534e-08 4.951790509239832e-06
# In line 24: ratio of Erel to allowed in S1y derivative is 4.35e+00
# -9.648569883067328e-08 2.8672677415703355e-06
# In line 24: ratio of Erel to allowed in S1z derivative is 2.38e+03
# 1.0796749341643614e-06 0.0013500235554230668
# In line 24: ratio of Erel to allowed in S2x derivative is 2.38e+03
# 3.5092173939331527e-08 1.2530039485980637e-05
# In line 24: ratio of Erel to allowed in S2y derivative is 6.57e+00
# -4.067633283046227e-08 9.004563301662216e-06
# In line 24: ratio of Erel to allowed in S2z derivative is 2.39e+03
# 2.5645178987621434e-06 0.002732162157468298
# In line 25: ratio of Erel to allowed in y derivative is 8.82e+02
# -5.666239807234268e-15 -6.725731083179198e-09
# In line 25: ratio of Erel to allowed in z derivative is 8.95e+02
# -7.126221076371018e-10 -7.797341291156574e-07
# In line 25: ratio of Erel to allowed in p1 derivative is 8.31e+02
# 4.51793257034184e-15 5.169642491864579e-09
# In line 25: ratio of Erel to allowed in p3 derivative is 1.80e+03
# 1.0042136847315453e-07 0.00010993920965984876
# In line 25: ratio of Erel to allowed in S1x derivative is 1.22e+03
# 4.786288820789242e-08 4.953794781894779e-06
# In line 25: ratio of Erel to allowed in S1y derivative is 1.37e+03
# -9.708133949195661e-08 2.1858938851291618e-06
# In line 25: ratio of Erel to allowed in S1z derivative is 1.19e+03
# 1.0800537776804309e-06 0.0013505909470534596
# In line 25: ratio of Erel to allowed in S2x derivative is 1.19e+03
# 3.5109191347235e-08 1.2535270568214685e-05
# In line 25: ratio of Erel to allowed in S2y derivative is 1.23e+03
# -4.1991278050492466e-08 7.627034770418818e-06
# In line 25: ratio of Erel to allowed in S2z derivative is 1.20e+03
# 2.565570476411782e-06 0.00273330321448384
# In line 26: ratio of Erel to allowed in y derivative is 1.15e+03
# -5.659811108299221e-15 -6.718107551743438e-09
# In line 26: ratio of Erel to allowed in z derivative is 1.19e+03
# -7.118318697477291e-10 -7.788640103238245e-07
# In line 26: ratio of Erel to allowed in p1 derivative is 1.03e+03
# 4.512923517690418e-15 5.163351228058369e-09
# In line 26: ratio of Erel to allowed in p3 derivative is 2.41e+03
# 1.0036652784268618e-07 0.00010987836355425759
# In line 26: ratio of Erel to allowed in S1x derivative is 1.63e+03
# 4.7814496369115954e-08 4.949789916397413e-06
# In line 26: ratio of Erel to allowed in S1y derivative is 1.83e+03
# -9.698124245214419e-08 2.184230042169512e-06
# In line 26: ratio of Erel to allowed in S1z derivative is 1.59e+03
# 1.0791985234334528e-06 0.0013494590311073542
# In line 26: ratio of Erel to allowed in S2x derivative is 1.59e+03
# 3.507516560199849e-08 1.2524806791702758e-05
# In line 26: ratio of Erel to allowed in S2y derivative is 1.64e+03
# -4.195322698849604e-08 7.620819535425483e-06
# In line 26: ratio of Erel to allowed in S2z derivative is 1.60e+03
# 2.563424151322384e-06 0.0027310301416005878
# In line 27: ratio of Erel to allowed in y derivative is 1.89e+03
# -5.664896793308191e-15 -6.723436622261639e-09
# In line 27: ratio of Erel to allowed in z derivative is 1.79e+03
# -7.124244462546671e-10 -7.79517043506909e-07
# In line 27: ratio of Erel to allowed in p1 derivative is 2.00e+03
# 4.5166796586830085e-15 5.168384239103337e-09
# In line 27: ratio of Erel to allowed in p3 derivative is 3.61e+03
# 1.0040765419224912e-07 0.00010992399200033127
# In line 27: ratio of Erel to allowed in S1x derivative is 2.45e+03
# 4.785078502242593e-08 4.9527913475896614e-06
# In line 27: ratio of Erel to allowed in S1y derivative is 2.74e+03
# -9.705630355184554e-08 2.185480921282925e-06
# In line 27: ratio of Erel to allowed in S1z derivative is 2.38e+03
# 1.0798398803546898e-06 0.001350307847902865
# In line 27: ratio of Erel to allowed in S2x derivative is 2.39e+03
# 3.510068158194822e-08 1.2532655833119577e-05
# In line 27: ratio of Erel to allowed in S2y derivative is 2.47e+03
# -4.198176179623175e-08 7.625476730055425e-06
# In line 27: ratio of Erel to allowed in S2z derivative is 2.40e+03
# 2.565033671625871e-06 0.002732734707882045
# In line 28: ratio of Erel to allowed in x derivative is 1.22e+00
# 0.002384301524766308 0.0023847386638815673
# In line 28: ratio of Erel to allowed in y derivative is 3.95e+03
# -5.661606709203894e-15 -6.7198839085828394e-09
# In line 28: ratio of Erel to allowed in z derivative is 3.53e+03
# -7.120293269277232e-10 -7.790817620663877e-07
# In line 28: ratio of Erel to allowed in p1 derivative is 3.67e+03
# 4.514175132535573e-15 5.16512758489777e-09
# In line 28: ratio of Erel to allowed in p2 derivative is 1.47e+00
# 0.2175070708815107 0.21748654287328528
# In line 28: ratio of Erel to allowed in p3 derivative is 7.11e+03
# 1.0038023386123324e-07 0.00010989356938509056
# In line 28: ratio of Erel to allowed in S1x derivative is 4.82e+03
# 4.782658913532671e-08 4.950789074985486e-06
# In line 28: ratio of Erel to allowed in S1y derivative is 5.38e+03
# -9.700625510308042e-08 2.1846457272799005e-06
# In line 28: ratio of Erel to allowed in S1z derivative is 4.69e+03
# 1.0794122531614581e-06 0.0013497418922251727
# In line 28: ratio of Erel to allowed in S2x derivative is 4.71e+03
# 3.508366874108434e-08 1.2527423138841698e-05
# In line 28: ratio of Erel to allowed in S2y derivative is 4.84e+03
# -4.1962736334068086e-08 7.622371933635463e-06
# In line 28: ratio of Erel to allowed in S2z derivative is 4.73e+03
# 2.5639605090449107e-06 0.0027315981750675174
# In line 29: ratio of Erel to allowed in x derivative is 3.95e+01
# 0.002384658770079477 0.0023850960350423767
# In line 29: ratio of Erel to allowed in y derivative is 9.08e+04
# -5.663174526217928e-15 -6.721660265422239e-09
# In line 29: ratio of Erel to allowed in z derivative is 1.18e+05
# -7.12229575852161e-10 -7.793019562996051e-07
# In line 29: ratio of Erel to allowed in p1 derivative is 7.76e+03
# 4.51544443812162e-15 5.167125986342095e-09
# In line 29: ratio of Erel to allowed in p2 derivative is 5.02e+01
# 0.21752099535830477 0.21750046427967648
# In line 29: ratio of Erel to allowed in p3 derivative is 2.30e+05
# 1.0039413164472207e-07 0.00010990898763604824
# In line 29: ratio of Erel to allowed in S1x derivative is 1.50e+05
# 4.7838852053032873e-08 4.9518063622455275e-06
# In line 29: ratio of Erel to allowed in S1y derivative is 2.15e+05
# -9.7031620776598e-08 2.1850678967673954e-06
# In line 29: ratio of Erel to allowed in S1z derivative is 1.54e+05
# 1.0796289860514072e-06 0.0013500287326779295
# In line 29: ratio of Erel to allowed in S2x derivative is 1.52e+05
# 3.5092291269594934e-08 1.2530078981054515e-05
# In line 29: ratio of Erel to allowed in S2y derivative is 1.42e+05
# -4.197237946547302e-08 7.6239493185248355e-06
# In line 29: ratio of Erel to allowed in S2z derivative is 1.55e+05
# 2.5645044114230106e-06 0.0027321741970176556
# In line 30: ratio of Erel to allowed in x derivative is 5.94e+01
# 0.0023846490558165766 0.002385086317875035
# in line 30: abs error in y derivative is 1.00e+00, allowed is 0.00e+00
# -5.6631768899275286e-15 -6.721660265422239e-09
# In line 30: ratio of Erel to allowed in z derivative is 1.78e+05
# -7.122241298531157e-10 -7.792962571547453e-07
# In line 30: ratio of Erel to allowed in p1 derivative is 7.76e+03
# 4.515409920907871e-15 5.16645985252732e-09
# In line 30: ratio of Erel to allowed in p2 derivative is 6.65e+01
# 0.21752061674108553 0.21750008572785812
# In line 30: ratio of Erel to allowed in p3 derivative is 3.49e+05
# 1.003937536878564e-07 0.00010990856948015073
# In line 30: ratio of Erel to allowed in S1x derivative is 2.71e+05
# 4.783851858877187e-08 4.951779185664325e-06
# In line 30: ratio of Erel to allowed in S1y derivative is 2.42e+05
# -9.703093046322005e-08 2.18505945788105e-06
# In line 30: ratio of Erel to allowed in S1z derivative is 2.23e+05
# 1.0796230921022406e-06 0.0013500209297126048
# In line 30: ratio of Erel to allowed in S2x derivative is 2.09e+05
# 3.5092056801601196e-08 1.2529999184884845e-05
# In line 30: ratio of Erel to allowed in S2y derivative is 2.80e+05
# -4.197211670884383e-08 7.623905793341378e-06
# In line 30: ratio of Erel to allowed in S2z derivative is 2.25e+05
# 2.5644896207477524e-06 0.0027321585255335452
# In line 31: ratio of Erel to allowed in x derivative is 7.63e+01
# 0.002384656341508171 0.0023850936055243087
# In line 31: ratio of Erel to allowed in y derivative is 9.08e+04
# -5.662910034797263e-15 -6.722178369500397e-09
# In line 31: ratio of Erel to allowed in z derivative is 2.24e+05
# -7.122282138861311e-10 -7.79300031913029e-07
# In line 31: ratio of Erel to allowed in p1 derivative is 7.76e+03
# 4.515435808787393e-15 5.167125986342095e-09
# In line 31: ratio of Erel to allowed in p2 derivative is 1.02e+02
# 0.21752090070388183 0.21750036963605657
# In line 31: ratio of Erel to allowed in p3 derivative is 4.43e+05
# 1.0039403713038834e-07 0.00010990888429787218
# In line 31: ratio of Erel to allowed in S1x derivative is 3.29e+05
# 4.7838768646169296e-08 4.951796917156704e-06
# In line 31: ratio of Erel to allowed in S1y derivative is 3.58e+05
# -9.703144791313545e-08 2.185064712585471e-06
# In line 31: ratio of Erel to allowed in S1z derivative is 3.02e+05
# 1.0796275122498377e-06 0.0013500267814360422
# In line 31: ratio of Erel to allowed in S2x derivative is 2.82e+05
# 3.509223261188772e-08 1.2530059636528536e-05
# In line 31: ratio of Erel to allowed in S2y derivative is 3.28e+05
# -4.197231349158832e-08 7.623933198086518e-06
# In line 31: ratio of Erel to allowed in S2z derivative is 3.04e+05
# 2.564500713433275e-06 0.002732170278139101
# In line 32: ratio of Erel to allowed in y derivative is 1.93e+03
# -5.6630879387151056e-15 -6.722252384368705e-09
# In line 32: ratio of Erel to allowed in z derivative is 1.79e+03
# -7.122254911317249e-10 -7.792975154075066e-07
# In line 32: ratio of Erel to allowed in p1 derivative is 2.49e+03
# 4.5154185501805196e-15 5.167051971473787e-09
# In line 32: ratio of Erel to allowed in p3 derivative is 3.60e+03
# 1.0039384817780767e-07 0.0001099086745097454
# In line 32: ratio of Erel to allowed in S1x derivative is 2.44e+03
# 4.7838601958221246e-08 4.951785664541981e-06
# In line 32: ratio of Erel to allowed in S1y derivative is 2.74e+03
# -9.703110299992041e-08 2.1850618043263567e-06
# In line 32: ratio of Erel to allowed in S1z derivative is 2.38e+03
# 1.0796245654971133e-06 0.0013500228819015036
# In line 32: ratio of Erel to allowed in S2x derivative is 2.38e+03
# 3.5092115422073614e-08 1.2530020141454656e-05
# In line 32: ratio of Erel to allowed in S2y derivative is 2.46e+03
# -4.197218235674446e-08 7.623908211407126e-06
# In line 32: ratio of Erel to allowed in S2z derivative is 2.39e+03
# 2.5644933183175174e-06 0.002732162449248232
# In line 33: ratio of Erel to allowed in y derivative is 8.82e+02
# -5.666239807234268e-15 -6.725731083179198e-09
# In line 33: ratio of Erel to allowed in z derivative is 8.95e+02
# -7.126221076371018e-10 -7.797341291156574e-07
# In line 33: ratio of Erel to allowed in p1 derivative is 8.31e+02
# 4.51793257034184e-15 5.169642491864579e-09
# In line 33: ratio of Erel to allowed in p3 derivative is 1.80e+03
# 1.0042136847315453e-07 0.00010993920965984876
# In line 33: ratio of Erel to allowed in S1x derivative is 1.22e+03
# 4.786288820789242e-08 4.953794781894779e-06
# In line 33: ratio of Erel to allowed in S1y derivative is 1.37e+03
# -9.708133949195661e-08 2.1858938851291618e-06
# In line 33: ratio of Erel to allowed in S1z derivative is 1.19e+03
# 1.0800537776804309e-06 0.0013505909470534596
# In line 33: ratio of Erel to allowed in S2x derivative is 1.19e+03
# 3.5109191347235e-08 1.2535270568214685e-05
# In line 33: ratio of Erel to allowed in S2y derivative is 1.23e+03
# -4.1991278050492466e-08 7.627034770418818e-06
# In line 33: ratio of Erel to allowed in S2z derivative is 1.20e+03
# 2.565570476411782e-06 0.00273330321448384
# In line 34: ratio of Erel to allowed in y derivative is 1.15e+03
# -5.659811108299221e-15 -6.718107551743438e-09
# In line 34: ratio of Erel to allowed in z derivative is 1.19e+03
# -7.118318697477291e-10 -7.788640103238245e-07
# In line 34: ratio of Erel to allowed in p1 derivative is 1.03e+03
# 4.512923517690418e-15 5.163351228058369e-09
# In line 34: ratio of Erel to allowed in p3 derivative is 2.41e+03
# 1.0036652784268618e-07 0.00010987836355425759
# In line 34: ratio of Erel to allowed in S1x derivative is 1.63e+03
# 4.7814496369115954e-08 4.949789916397413e-06
# In line 34: ratio of Erel to allowed in S1y derivative is 1.83e+03
# -9.698124245214419e-08 2.184230042169512e-06
# In line 34: ratio of Erel to allowed in S1z derivative is 1.59e+03
# 1.0791985234334528e-06 0.0013494590311073542
# In line 34: ratio of Erel to allowed in S2x derivative is 1.59e+03
# 3.507516560199849e-08 1.2524806791702758e-05
# In line 34: ratio of Erel to allowed in S2y derivative is 1.64e+03
# -4.195322698849604e-08 7.620819535425483e-06
# In line 34: ratio of Erel to allowed in S2z derivative is 1.60e+03
# 2.563424151322384e-06 0.0027310301416005878
# In line 35: ratio of Erel to allowed in y derivative is 1.89e+03
# -5.664896793308191e-15 -6.723436622261639e-09
# In line 35: ratio of Erel to allowed in z derivative is 1.79e+03
# -7.124244462546671e-10 -7.79517043506909e-07
# In line 35: ratio of Erel to allowed in p1 derivative is 2.00e+03
# 4.5166796586830085e-15 5.168384239103337e-09
# In line 35: ratio of Erel to allowed in p3 derivative is 3.61e+03
# 1.0040765419224912e-07 0.00010992399200033127
# In line 35: ratio of Erel to allowed in S1x derivative is 2.45e+03
# 4.785078502242593e-08 4.9527913475896614e-06
# In line 35: ratio of Erel to allowed in S1y derivative is 2.74e+03
# -9.705630355184554e-08 2.185480921282925e-06
# In line 35: ratio of Erel to allowed in S1z derivative is 2.38e+03
# 1.0798398803546898e-06 0.001350307847902865
# In line 35: ratio of Erel to allowed in S2x derivative is 2.39e+03
# 3.510068158194822e-08 1.2532655833119577e-05
# In line 35: ratio of Erel to allowed in S2y derivative is 2.47e+03
# -4.198176179623175e-08 7.625476730055425e-06
# In line 35: ratio of Erel to allowed in S2z derivative is 2.40e+03
# 2.565033671625871e-06 0.002732734707882045
# In line 36: ratio of Erel to allowed in x derivative is 1.20e+00
# 0.002384301524766308 0.0023847386638815673
# In line 36: ratio of Erel to allowed in y derivative is 2.93e+03
# -5.661606709203894e-15 -6.7198839085828394e-09
# In line 36: ratio of Erel to allowed in z derivative is 3.47e+03
# -7.120293269277232e-10 -7.790817620663877e-07
# In line 36: ratio of Erel to allowed in p1 derivative is 2.58e+03
# 4.514175132535573e-15 5.16512758489777e-09
# In line 36: ratio of Erel to allowed in p2 derivative is 1.45e+00
# 0.2175070708815107 0.21748654287328528
# In line 36: ratio of Erel to allowed in p3 derivative is 6.99e+03
# 1.0038023386123324e-07 0.00010989356938509056
# In line 36: ratio of Erel to allowed in S1x derivative is 4.73e+03
# 4.782658913532671e-08 4.950789074985486e-06
# In line 36: ratio of Erel to allowed in S1y derivative is 5.28e+03
# -9.700625510308042e-08 2.1846457272799005e-06
# In line 36: ratio of Erel to allowed in S1z derivative is 4.61e+03
# 1.0794122531614581e-06 0.0013497418922251727
# In line 36: ratio of Erel to allowed in S2x derivative is 4.62e+03
# 3.508366874108434e-08 1.2527423138841698e-05
# In line 36: ratio of Erel to allowed in S2y derivative is 4.79e+03
# -4.1962736334068086e-08 7.622371933635463e-06
# In line 36: ratio of Erel to allowed in S2z derivative is 4.65e+03
# 2.5639605090449107e-06 0.0027315981750675174
# In line 37: ratio of Erel to allowed in x derivative is 1.87e+01
# 0.002384664937774651 0.002385102205734966
# In line 37: ratio of Erel to allowed in y derivative is 9.08e+04
# -5.663205082143169e-15 -6.722178369500397e-09
# In line 37: ratio of Erel to allowed in z derivative is 5.29e+04
# -7.122330330663465e-10 -7.793059531024937e-07
# In line 37: ratio of Erel to allowed in p1 derivative is 4.36e+03
# 4.515466353550866e-15 5.1659417484491615e-09
# In line 37: ratio of Erel to allowed in p2 derivative is 2.31e+01
# 0.21752123574610016 0.2175007046159193
# In line 37: ratio of Erel to allowed in p3 derivative is 1.09e+05
# 1.0039437154269379e-07 0.00010990925514301286
# In line 37: ratio of Erel to allowed in S1x derivative is 7.58e+04
# 4.783906382398496e-08 4.951821821479576e-06
# In line 37: ratio of Erel to allowed in S1y derivative is 8.53e+04
# -9.703205856316608e-08 2.185076497709868e-06
# In line 37: ratio of Erel to allowed in S1z derivative is 7.24e+04
# 1.0796327279014523e-06 0.0013500336843006028
# In line 37: ratio of Erel to allowed in S2x derivative is 7.18e+04
# 3.509244018651544e-08 1.2530128148391382e-05
# In line 37: ratio of Erel to allowed in S2y derivative is 8.06e+04
# -4.1972545790643785e-08 7.623966244985069e-06
# In line 37: ratio of Erel to allowed in S2z derivative is 7.29e+04
# 2.56451380191329e-06 0.0027321841384919665
# In line 38: ratio of Erel to allowed in x derivative is 2.63e+01
# 0.0023846428881832793 0.0023850801472091736
# In line 38: ratio of Erel to allowed in y derivative is 1.30e+04
# -5.6629443674943566e-15 -6.722252384368705e-09
# In line 38: ratio of Erel to allowed in z derivative is 7.62e+04
# -7.122206723761929e-10 -7.792921863369884e-07
# In line 38: ratio of Erel to allowed in p1 derivative is 6.98e+04
# 4.515388005819535e-15 5.167125986342095e-09
# In line 38: ratio of Erel to allowed in p2 derivative is 3.07e+01
# 0.21752037635459803 0.21749984540780623
# In line 38: ratio of Erel to allowed in p3 derivative is 1.54e+05
# 1.0039351378111389e-07 0.00010990830318197476
# In line 38: ratio of Erel to allowed in S1x derivative is 1.03e+05
# 4.7838306393317366e-08 4.951760158485172e-06
# In line 38: ratio of Erel to allowed in S1y derivative is 1.21e+05
# -9.703049262478475e-08 2.1850509144637743e-06
# In line 38: ratio of Erel to allowed in S1z derivative is 1.00e+05
# 1.0796193500752418e-06 0.0013500159798577967
# In line 38: ratio of Erel to allowed in S2x derivative is 1.05e+05
# 3.50919074591821e-08 1.2529957271745218e-05
# In line 38: ratio of Erel to allowed in S2y derivative is 1.16e+05
# -4.1971950327504215e-08 7.6238824187058185e-06
# In line 38: ratio of Erel to allowed in S2z derivative is 1.01e+05
# 2.564480230153984e-06 0.002732148589701388
# In line 39: ratio of Erel to allowed in x derivative is 3.68e+01
# 0.0023846594253480215 0.0023850966925785585
# In line 39: ratio of Erel to allowed in y derivative is 1.01e+04
# -5.662066697167286e-15 -6.722252384368705e-09
# In line 39: ratio of Erel to allowed in z derivative is 1.10e+05
# -7.122299427893118e-10 -7.793024744036832e-07
# In line 39: ratio of Erel to allowed in p1 derivative is 7.76e+03
# 4.515446766459403e-15 5.16645985252732e-09
# In line 39: ratio of Erel to allowed in p2 derivative is 4.65e+01
# 0.2175210208976161 0.21750048980389095
# In line 39: ratio of Erel to allowed in p3 derivative is 2.14e+05
# 1.0039415713631623e-07 0.0001099090159098203
# In line 39: ratio of Erel to allowed in S1x derivative is 1.44e+05
# 4.783887424675565e-08 4.951807777692463e-06
# In line 39: ratio of Erel to allowed in S1y derivative is 2.12e+05
# -9.703166697553404e-08 2.1850676314007313e-06
# In line 39: ratio of Erel to allowed in S1z derivative is 1.43e+05
# 1.0796293833798227e-06 0.001350029257565191
# In line 39: ratio of Erel to allowed in S2x derivative is 1.42e+05
# 3.509230678558278e-08 1.25300781750326e-05
# In line 39: ratio of Erel to allowed in S2y derivative is 1.42e+05
# -4.1972396823823114e-08 7.6239493185248355e-06
# In line 39: ratio of Erel to allowed in S2z derivative is 1.45e+05
# 2.564505408874198e-06 0.002732175243234103
# In line 40: ratio of Erel to allowed in x derivative is 8.55e+01
# 0.0023846484005523344 0.002385085662286277
# In line 40: ratio of Erel to allowed in y derivative is 1.14e+04
# -5.663224135133168e-15 -6.722252384368705e-09
# In line 40: ratio of Erel to allowed in z derivative is 2.10e+05
# -7.122237625599077e-10 -7.792951469317207e-07
# In line 40: ratio of Erel to allowed in p1 derivative is 8.73e+03
# 4.515407592593737e-15 5.1665338673956285e-09
# In line 40: ratio of Erel to allowed in p2 derivative is 9.28e+01
# 0.21752059120186495 0.21750006021730178
# In line 40: ratio of Erel to allowed in p3 derivative is 5.03e+05
# 1.0039372821216598e-07 0.00010990854279507132
# In line 40: ratio of Erel to allowed in S1x derivative is 3.80e+05
# 4.783849610016016e-08 4.9517775362381675e-06
# In line 40: ratio of Erel to allowed in S1y derivative is 3.13e+05
# -9.703088414641119e-08 2.1850566268467725e-06
# In line 40: ratio of Erel to allowed in S1z derivative is 3.18e+05
# 1.0796226945701236e-06 0.0013500204056549948
# In line 40: ratio of Erel to allowed in S2x derivative is 2.72e+05
# 3.509204099065536e-08 1.2529994348753348e-05
# In line 40: ratio of Erel to allowed in S2y derivative is 4.14e+05
# -4.19720992323249e-08 7.623900151187968e-06
# In line 40: ratio of Erel to allowed in S2z derivative is 3.20e+05
# 2.5644886230979493e-06 0.0027321574720629016
# In line 41: ratio of Erel to allowed in x derivative is 1.52e+02
# 0.002384653912940592 0.0023850911764839266
# In line 41: ratio of Erel to allowed in z derivative is 1.37e+02
# -7.122268530984855e-10 -7.792994397940827e-07
# In line 41: ratio of Erel to allowed in p2 derivative is 1.57e+02
# 0.2175208060495377 0.21750027502791486
# In line 41: ratio of Erel to allowed in p3 derivative is 1.21e+06
# 1.0039394266883582e-07 0.0001099087794038088
# In line 41: ratio of Erel to allowed in S1x derivative is 2.63e+04
# 4.783868522451542e-08 4.951790509239832e-06
# In line 41: ratio of Erel to allowed in S1y derivative is 5.64e+03
# -9.703127586238358e-08 2.1850643031423594e-06
# In line 41: ratio of Erel to allowed in S1z derivative is 1.18e+06
# 1.079626039492565e-06 0.0013500248292525282
# In line 41: ratio of Erel to allowed in S2x derivative is 1.10e+04
# 3.509217393933166e-08 1.2530039485980637e-05
# In line 41: ratio of Erel to allowed in S2y derivative is 1.94e+04
# -4.1972248330150725e-08 7.623924331845444e-06
# In line 41: ratio of Erel to allowed in S2z derivative is 9.82e+05
# 2.5644970164922777e-06 0.00273216636087259
# In line 42: ratio of Erel to allowed in x derivative is 1.33e+02
# 0.0023846566081972887 0.0023850944455363126
# In line 42: ratio of Erel to allowed in z derivative is 1.06e+02
# -7.16940386166005e-10 -7.849823013827972e-07
# In line 42: ratio of Erel to allowed in p2 derivative is 1.31e+02
# 0.217520668509278 0.21750013749490563
# In line 42: ratio of Erel to allowed in S1x derivative is 1.92e+04
# 4.783868326840008e-08 4.9519794328541354e-06
# In line 42: ratio of Erel to allowed in S1y derivative is 3.34e+00
# -9.703127081305716e-08 2.1846589169918634e-06
# In line 42: ratio of Erel to allowed in S1z derivative is 2.21e+06
# 1.0796251860396302e-06 0.001350023869768884
# In line 42: ratio of Erel to allowed in S2x derivative is 8.23e+03
# 3.50921741701508e-08 1.253117114075053e-05
# In line 42: ratio of Erel to allowed in S2y derivative is 5.55e+00
# -4.197224929445029e-08 7.623522126909422e-06
# In line 42: ratio of Erel to allowed in S2z derivative is 1.13e+06
# 2.5644948341623757e-06 0.0027321639468369523
# In line 43: ratio of Erel to allowed in x derivative is 1.55e+02
# 0.002384654214003461 0.002385091541621478
# In line 43: ratio of Erel to allowed in z derivative is 7.03e+02
# -8.664488752592443e-10 -7.775668997567209e-07
# In line 43: ratio of Erel to allowed in p2 derivative is 1.25e+02
# 0.21752076296431921 0.21750028741859084
# In line 43: ratio of Erel to allowed in p3 derivative is 8.23e+02
# -0.000109818749556896 -1.7796556642610693e-11
# In line 43: ratio of Erel to allowed in S1x derivative is 5.13e+02
# 4.783868473323086e-08 4.9517267843034065e-06
# In line 43: ratio of Erel to allowed in S1y derivative is 5.17e+02
# -9.648569866217212e-08 2.86738662281615e-06
# In line 43: ratio of Erel to allowed in S1z derivative is 3.35e+05
# 1.0796748377493774e-06 0.0013500234440424344
# In line 43: ratio of Erel to allowed in S2x derivative is 4.81e+02
# 3.5092173333983185e-08 1.2529658237614427e-05
# In line 43: ratio of Erel to allowed in S2y derivative is 5.71e+02
# -4.067633340870324e-08 9.004674532686607e-06
# In line 43: ratio of Erel to allowed in S2z derivative is 3.39e+05
# 2.5645176539105623e-06 0.0027321618971232198
# In line 44: ratio of Erel to allowed in x derivative is 1.18e+02
# 0.002384657440778425 0.0023850947678852583
# In line 44: ratio of Erel to allowed in z derivative is 1.40e+03
# -8.653429646292725e-10 -7.764614876985358e-07
# In line 44: ratio of Erel to allowed in p2 derivative is 6.82e+01
# 0.21752059308044977 0.21750011760809781
# In line 44: ratio of Erel to allowed in p3 derivative is 1.64e+03
# -0.00010975063093136038 1.3326175383376076e-07
# In line 44: ratio of Erel to allowed in S1x derivative is 1.03e+03
# 4.784075506523993e-08 4.942168273890928e-06
# In line 44: ratio of Erel to allowed in S1y derivative is 1.04e+03
# -9.648514730790973e-08 2.8731209143521856e-06
# In line 44: ratio of Erel to allowed in S1z derivative is 4.72e+05
# 1.0796780902702447e-06 0.0013500276544423605
# In line 44: ratio of Erel to allowed in S2x derivative is 9.61e+02
# 3.509346741579148e-08 1.2503677733199936e-05
# In line 44: ratio of Erel to allowed in S2y derivative is 1.14e+03
# -4.067525707312131e-08 9.020512057311691e-06
# In line 44: ratio of Erel to allowed in S2z derivative is 4.74e+05
# 2.56452556538997e-06 0.00273217033214257

# %% [markdown]
# <a id='spherical_orit'></a>
#
# # Step 11: Spherical Orbit Test  \[Back to [top](#toc)\]
# $$\label{spherical_orbit}$$
#
# In this test we construct a spherical orbit for a set of initial conditions and then perturb the initial conditions to assess a measure of intrinsic error.

# %%
from scipy.optimize import root

m1 = 23.
m1pert = 23.*(1. + 1.e-15)
m2 = 10.
f = 20.
S1 = np.array([0.0, 0.0, -0.03])
S2 = np.array([0.0, 0.0, 0.06])


EMgamma = 0.577215664901532860606512090082402431
# Geomtrized solar mass $\mathcal{M}_{\odot}$
Msol = 4.925491025543575903411922162094833998e-6

#Convert the spins to dimensionless quantities
S1 *= m1*m1
S2 *= m2*m2

# Binary system total mass $M$
M = m1 + m2
Mpert = m1pert + m2

# Inverse mass terms used repeatedly when computing initial conditions
Minv = np.divide(1,M)
Minvpert = np.divide(1,M)
Msqinv = Minv*Minv
Msqinvpert = Minvpert*Minvpert

# Symmetric mass ratio $\eta$
eta = m1*m2*Msqinv
etapert = m1pert*m2*Msqinvpert

# Normalized, dimensionless spin vectors
S1hat = Msqinv*S1
S2hat = Msqinv*S2

S1hatpert = Msqinvpert*S1
S2hatpert = Msqinvpert*S2

# Omega: initial orbital angular frequency
omega = M*Msol*np.pi*f
omegapert = Mpert*Msol*np.pi*f

v = np.cbrt(omega)
vpert = np.cbrt(omegapert)
vsq = v*v
vsqpert = vpert*vpert

# Inital root guess
root_guess = [np.divide(1,v*v), v*2, 0.]
root_guesspert = [np.divide(1,vpert*vpert),vpert*2,0.]

# This is the same initial guess given to GSL in LALSuite

# Define the function of which we want to find the roots
def root_func(F,m1,m2,S1hat,S2hat,omega,eta):
    #Recompute Hamiltonian derivatives using latest minimization guess
    Ham_derivs = dH(m1, m2, 2, F[0], 0.0, 0.0, 0.0, F[1], F[2], S1hat[0], S1hat[1], S1hat[2], S2hat[0],
                          S2hat[1], S2hat[2])
    return [Ham_derivs[0]/eta+(-Ham_derivs[5]*F[2]/eta-Ham_derivs[4]*F[1]/eta)/F[0], -Ham_derivs[5]/F[0]/eta, Ham_derivs[4]/F[0]/eta-omega]

soln = root(root_func, root_guess, args=(m1,m2,S1hat,S2hat,omega,eta), method='hybr', jac=None, tol=None, callback=None)
solnpert = root(root_func,root_guesspert, args = (m1pert,m2,S1hatpert,S2hatpert,omegapert,etapert), method='hybr', jac=None, tol=None, callback=None)

if not(soln.success):
    print("The root finder failed with error message: %s" % soln.message)
    sys.exit(1)

r, py , pz = soln.x[0] , soln.x[1], soln.x[2]
rpert, pypert, pzpert = solnpert.x[0] , solnpert.x[1] , solnpert.x[2]

Erel = [np.abs((r - rpert)/r), np.abs((py - pypert)/py), np.abs((pz - pzpert))]


LAL_init_conds = {'r': 2.1296908267405176e+01, 'py': 2.3354017824522000e-01, 'pz': 0.0000000000000000e+00}
LAL_init_condspert = {'r': 2.1296908268016757e+01, 'py': 2.3354017824291295e-01, 'pz': 0.0000000000000000e+00}

Erel_LAL = [np.abs((LAL_init_conds['r'] - LAL_init_condspert['r'])/LAL_init_conds['r']), np.abs((LAL_init_conds['py'] - LAL_init_condspert['py'])/LAL_init_conds['py']), np.abs((LAL_init_conds['pz'] - LAL_init_condspert['pz']))]

print(r,py,pz)

labels = ['r','py','pz']
for i in range(3):
    print("Self-agreement in %s in nrpy is %.3e and in LAL is %.3e"%(labels[i],Erel[i],Erel_LAL[i]))
    
print("Erel in radius between LAL and nrpy is %.3e" % np.abs((LAL_init_conds['r'] - r)/(0.5*(LAL_init_conds['r'] + r))))
print("Erel in azimuthal momentum between LAL and nrpy is %.3e" % np.abs((LAL_init_conds['py'] - py)/(0.5*(LAL_init_conds['py'] + py))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a7ba7ed3bd99> in <module>
#      60     return [Ham_derivs[0]/eta+(-Ham_derivs[5]*F[2]/eta-Ham_derivs[4]*F[1]/eta)/F[0], -Ham_derivs[5]/F[0]/eta, Ham_derivs[4]/F[0]/eta-omega]
#      61
# ---> 62 soln = root(root_func, root_guess, args=(m1,m2,S1hat,S2hat,omega,eta), method='hybr', jac=None, tol=None, callback=None)
#      63 solnpert = root(root_func,root_guesspert, args = (m1pert,m2,S1hatpert,S2hatpert,omegapert,etapert), method='hybr', jac=None, tol=None, callback=None)
#      64
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_root.py in root(fun, x0, args, method, jac, tol, callback, options)
#     185
#     186     if meth == 'hybr':
# --> 187         sol = _root_hybr(fun, x0, args=args, jac=jac, **options)
#     188     elif meth == 'lm':
#     189         sol = _root_leastsq(fun, x0, args=args, jac=jac, **options)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     224     if not isinstance(args, tuple):
#     225         args = (args,)
# --> 226     shape, dtype = _check_func('fsolve', 'func', func, x0, args, n, (n,))
#     227     if epsfcn is None:
#     228         epsfcn = finfo(dtype).eps
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# <ipython-input-12-a7ba7ed3bd99> in root_func(F, m1, m2, S1hat, S2hat, omega, eta)
#      56 def root_func(F,m1,m2,S1hat,S2hat,omega,eta):
#      57     #Recompute Hamiltonian derivatives using latest minimization guess
# ---> 58     Ham_derivs = dH(m1, m2, 2, F[0], 0.0, 0.0, 0.0, F[1], F[2], S1hat[0], S1hat[1], S1hat[2], S2hat[0],
#      59                           S2hat[1], S2hat[2])
#      60     return [Ham_derivs[0]/eta+(-Ham_derivs[5]*F[2]/eta-Ham_derivs[4]*F[1]/eta)/F[0], -Ham_derivs[5]/F[0]/eta, Ham_derivs[4]/F[0]/eta-omega]
#
# TypeError: 'module' object is not callable

# %% [markdown]
# # Step 12: Derivatives for Initial Conditions
#
# In this section we use the above first derivatives to generate the relevant first and second derivatives for initial conditions

# %%
ic_sd_vars = [x,py,pz]

outputdirinitconds = "InitialConditions"
lhss_initconds_derivs = []
rhss_initconds_derivs = []
with open(os.path.join(outputdir,'partial_derivatives_initconds.txt-VALIDATION'), 'w') as output:
    for i in range(len(lr)):
        right_side = lr[i].rhs
        right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(")
        output.write(str(lr[i].lhs)+" = "+right_side_in_sp)
    for i in range(len(lhss_deriv)):
        if(("prmx" in str(lhss_deriv[i])) or ("prmp2" in str(lhss_deriv[i])) or ("prmp3" in str(lhss_deriv[i]))):
            right_side = str(rhss_deriv[i])
            lhss_initconds_derivs.append(str(lhss_deriv[i]))
            rhss_initconds_derivs.append(str(rhss_deriv[i]))
            right_side_in_sp = right_side.replace("sqrt(","sp.sqrt(").replace("log(","sp.log(").replace("pi",
                                                "sp.pi").replace("sign(","sp.sign(").replace("Abs(",
                                                "sp.Abs(").replace("Rational(","sp.Rational(").replace("prm",
                                                "_prm")
            output.write(str(lhss_deriv[i]).replace("prm","_prm")+" = "+right_side_in_sp+"\n")
